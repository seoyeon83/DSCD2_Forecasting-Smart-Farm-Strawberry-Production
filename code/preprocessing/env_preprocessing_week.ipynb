# %% [markdown]
# ### 환경 데이터 일 단위 -> 주 단위 병합 코드

# %%
import pandas as pd

# %%
df = pd.read_csv("2020/환경데이터_스무딩_완료.csv")
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71528 entries, 0 to 71527
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   realTime      71528 non-null  object
#  1   name          71528 non-null  int64
#  2   do            71528 non-null  object
#  3   city          71528 non-null  object
#  4   item          71528 non-null  object
#  5   cul_time      71528 non-null  int64
#  6   Measure_time  71212 non-null  object
#  7   temp_ex       70424 non-null  float64
#  8   s_am          70583 non-null  float64
#  9   as_am         70582 non-null  float64
#  10  temp_int      70424 non-null  float64
#  11  hum_int       70424 non-null  float64
#  12  CO2           70424 non-null  float64
#  13  st            70424 non-null  float64
# dtypes: float64(7), int64(2), object(5)
# memory usage: 7.6+ MB
#          realTime  name  do city item  cul_time    Measure_time  temp_ex  \
# 0  2020.9.15 0:00    11  충남   부여   딸기         1  2020.9.15 0:00     18.1
# 1  2020.9.15 1:00    11  충남   부여   딸기         1  2020.9.15 1:00     18.2
# 2  2020.9.15 2:00    11  충남   부여   딸기         1  2020.9.15 2:00     18.2
# 3  2020.9.15 3:00    11  충남   부여   딸기         1  2020.9.15 3:00     18.4
# 4  2020.9.15 4:00    11  충남   부여   딸기         1  2020.9.15 4:00     18.0
#
#    s_am  as_am  temp_int    hum_int         CO2         st
# 0   0.0    0.0      19.8  92.000000  549.000000  15.831841
# 1   0.0    0.0      19.6  92.500000  534.500000  15.831841
# 2   0.0    0.0      19.9  93.333333  536.333333  15.831841
# 3   0.0    0.0      20.0  94.666667  530.333333  15.831841
# 4   0.0    0.0      19.6  95.666667  567.666667  15.831841

# %% [markdown]
# ### 주차 별로 합치는 코드 (기반)
# 1. 각 농가 별로 진행
# 2. 각 농가의 realTime 기준 7일 안까지 가져오기
# 3. 사용할 컬럼(온도_외부, 일사량_외부(?), 온도_내부, 상대습도_내부, 잔존CO2, 토양온도)를 일별 최대(max), 최소(min), 평균(mean)로 샘플링하고, 다시 한 번 주 별로 평균을 내어 샘플링한다.
# 4. 이때, 딕셔너리 활용
# 5. 최종 측정일이 모두 23시까지 있는 것이 아닌 것 유의하기

# %%
## 일별

import pandas as pd

# 데이터
df = pd.read_csv("2020/1.환경/2020_환경_딸기_2차_농가_선정.csv", encoding="ANSI")

# 선정한 변수
cols = ["realTime", "온도_외부", "온도_내부", "상대습도_내부", "잔존CO2", "토양온도"]


# 일별 데이터 저장할 딕셔너리
data = {"농가명":[], "date":[],
        "온도_외부_max":[], "온도_외부_min":[], "온도_외부_mean":[], 
        "온도_내부_max":[], "온도_내부_min":[], "온도_내부_mean":[],
        "상대습도_내부_max":[], "상대습도_내부_min":[], "상대습도_내부_mean":[],
        "잔존CO2_max":[], "잔존CO2_min":[], "잔존CO2_mean":[],
        "토양온도_max":[], "토양온도_min":[], "토양온도_mean":[]}

# 농가 id
farm_id = df["농가명"].unique()

# 농가 별
for f in farm_id :
    farm_df = df[df["농가명"]==f][cols]

    # 일 별로
    for i in range(0, farm_df.shape[0], 24) :
        sub_df = farm_df.iloc[i : i + 24]
        date = sub_df["realTime"].tolist()[0]

        # 데이터 추가
        data[f"농가명"].append(f)
        data[f"date"].append(date)
        # data[f"week_start_date"].append(sub_df.iloc[0]["realTime"])

        # 변수 별
        for c in cols[1:] : # realTime 제외
            data[f"{c}_max"].append(sub_df[c].max())
            data[f"{c}_min"].append(sub_df[c].min())
            data[f"{c}_mean"].append(sub_df[c].mean())


date_df = pd.DataFrame.from_dict(data=data, orient='columns')
date_df.to_csv("2020/1.환경/2020_환경_딸기_2차 농가_선정_일별.csv", encoding="ANSI", index=False)

# %%
df.columns
# Out:
# Index(['농가명', 'date', '온도_외부_max', '온도_외부_min', '온도_외부_mean', '온도_내부_max',
#        '온도_내부_min', '온도_내부_mean', '상대습도_내부_max', '상대습도_내부_min', '상대습도_내부_mean',
#        '잔존CO2_max', '잔존CO2_min', '잔존CO2_mean', '토양온도_max', '토양온도_min',
#        '토양온도_mean'],
#       dtype='object')

# %%
sub_df
# Out:
#                 date  온도_외부_max  온도_외부_min  온도_외부_mean  온도_내부_max  온도_내부_min  \
# 217  2021-04-20 0:00       25.6        3.4   14.545833       25.5        6.1
# 218  2021-04-21 0:00       29.9        7.6   18.204167       30.7        8.6
# 219  2021-04-22 0:00       28.6       13.1   20.545833       30.9       13.9
# 220  2021-04-23 0:00       23.2       17.2   19.895833       26.0       15.5
# 221  2021-04-24 0:00       26.3       11.3   18.266667       28.6       12.5
# 222  2021-04-25 0:00       26.3        7.2   16.991667       27.6       13.7
# 223  2021-04-26 0:00       24.1        9.6   16.562500       23.7       10.6
#
#      온도_내부_mean  상대습도_내부_max  상대습도_내부_min  상대습도_내부_mean  잔존CO2_max  잔존CO2_min  \
# 217   16.041667        100.0         27.0     65.416667     1361.0      453.0
# 218   18.679167        100.0         19.0     58.583333     1111.0      451.0
# 219   20.341667        100.0         22.0     56.041667      672.0      445.0
# 220   19.450000         89.0         26.0     38.541667      642.0      427.0
# 221   18.700000        100.0         20.0     52.625000      583.0      430.0
# 222   20.000000        100.0         27.0     66.041667      637.0      442.0
# 223   16.800000        100.0         30.0     68.541667      780.0      444.0
#
#      잔존CO2_mean  토양온도_max  토양온도_min  토양온도_mean
# 217  641.681818      18.1      11.7  15.108333
# 218  587.608696      20.0      13.4  16.983333
# 219  540.739130      20.5      16.4  18.441667
# 220  470.375000      19.6      17.3  18.337500
# 221  490.166667      20.0      15.6  17.512500
# 222  508.454545      19.2      13.7  16.750000
# 223  539.086957      18.7      15.1  16.766667

# %%
import pandas as pd

# 데이터
df = pd.read_csv("2020/1.환경/2020_환경_딸기_2차 농가_선정_일별.csv", encoding="ANSI")

# 변수
cols = ["date", 
        '온도_외부_max', '온도_외부_min', '온도_외부_mean', 
        '온도_내부_max', '온도_내부_min', '온도_내부_mean', 
        '상대습도_내부_max', '상대습도_내부_min', '상대습도_내부_mean',
        '잔존CO2_max', '잔존CO2_min', '잔존CO2_mean', 
        '토양온도_max', '토양온도_min', '토양온도_mean']

# 주별 데이터 저장할 딕셔너리
data = {"농가명":[], "week":[], "week_start_date":[],
        "온도_외부_max":[], "온도_외부_min":[], "온도_외부_mean":[], 
        "온도_내부_max":[], "온도_내부_min":[], "온도_내부_mean":[],
        "상대습도_내부_max":[], "상대습도_내부_min":[], "상대습도_내부_mean":[],
        "잔존CO2_max":[], "잔존CO2_min":[], "잔존CO2_mean":[],
        "토양온도_max":[], "토양온도_min":[], "토양온도_mean":[]}


# 농가 id
farm_id = df["농가명"].unique()

# 농가 별
for f in farm_id :
    farm_df = df[df["농가명"]==f][cols]
    week = 1

    # 주차 별
    for i in range(0, farm_df.shape[0], 7) :
        # 확인용 출력
        print(i, week)
        print(farm_df.iloc[i])
        # print(farm_df.iloc[i + 24 * 6 + 23])

        sub_df = farm_df.iloc[i : i + 7]

        # 데이터 추가
        data[f"농가명"].append(f)
        data[f"week"].append(week)
        data[f"week_start_date"].append(sub_df.iloc[0]["date"])

        # 변수 별
        for c in cols[1:] : # realTime 제외
            data[c].append(sub_df[c].mean())
    
        week += 1

week_df = pd.DataFrame.from_dict(data=data, orient='columns')
week_df.to_csv("2020/1.환경/2020_환경_딸기_2차 농가 선정_주별_a.csv", encoding="ANSI", index=False)
# Out:
# 0 1
# date            2020-09-15 0:00
# 온도_외부_max                  29.2
# 온도_외부_min                  16.6
# 온도_외부_mean            22.754167
# 온도_내부_max                  29.4
# 온도_내부_min                  18.0
# 온도_내부_mean            23.170833
# 상대습도_내부_max                99.0
# 상대습도_내부_min                42.0
# 상대습도_내부_mean          75.791667
# 잔존CO2_max                 841.0
# 잔존CO2_min                 458.0
# 잔존CO2_mean           533.608696
# 토양온도_max                    NaN
# 토양온도_min                    NaN
# 토양온도_mean                   NaN
# Name: 0, dtype: object
# 7 2
# date            2020-09-22 0:00
# 온도_외부_max                  25.0
# 온도_외부_min                  12.4
# 온도_외부_mean            18.316667
# 온도_내부_max                  20.8
# 온도_내부_min                  19.2
# 온도_내부_mean            19.545455
# 상대습도_내부_max                85.0
# 상대습도_내부_min                26.0
# 상대습도_내부_mean              61.25
# 잔존CO2_max                 695.0
# 잔존CO2_min                 453.0
# 잔존CO2_mean               554.75
# 토양온도_max                    NaN
# 토양온도_min                    NaN
# 토양온도_mean                   NaN
# Name: 7, dtype: object
# 14 3
# date            2020-09-29 0:00
# 온도_외부_max                  26.3
# 온도_외부_min                  10.2
# 온도_외부_mean              17.7875
# 온도_내부_max                   NaN
# 온도_내부_min                   NaN
# 온도_내부_mean                  NaN
# 상대습도_내부_max                81.0
# 상대습도_내부_min                 3.0
# 상대습도_내부_mean             50.625
# 잔존CO2_max                 913.0
# 잔존CO2_min                 435.0
# 잔존CO2_mean            575.73913
# 토양온도_max                    NaN
# 토양온도_min                    NaN
# 토양온도_mean                   NaN
# Name: 14, dtype: object
# 21 4
# date            2020-10-06 0:00
# 온도_외부_max                  21.3
# 온도_외부_min                   6.0
# 온도_외부_mean            13.754167
# 온도_내부_max                   NaN
# 온도_내부_min                   NaN
# 온도_내부_mean                  NaN
# 상대습도_내부_max                83.0
# 상대습도_내부_min                17.0
# 상대습도_내부_mean          52.333333
# 잔존CO2_max                1357.0
# 잔존CO2_min                 446.0
# 잔존CO2_mean           607.708333
# 토양온도_max                    NaN
# 토양온도_min                    NaN
# 토양온도_mean                   NaN
# Name: 21, dtype: object
# 28 5
# date            2020-10-13 0:00
# 온도_외부_max                  18.8
# 온도_외부_min                   5.9
# 온도_외부_mean            11.758333
# 온도_내부_max                   NaN
# 온도_내부_min                   NaN
# 온도_내부_mean                  NaN
# 상대습도_내부_max                88.0
# 상대습도_내부_min                22.0
# 상대습도_내부_mean          61.208333
# 잔존CO2_max                 612.0
# 잔존CO2_min                 435.0
# 잔존CO2_mean               517.55
# 토양온도_max                    NaN
# 토양온도_min                    NaN
# 토양온도_mean                   NaN
# Name: 28, dtype: object
# 35 6
# date            2020-10-20 0:00
# 온도_외부_max                  23.2
# 온도_외부_min                   4.6
# 온도_외부_mean            12.204167
# 온도_내부_max                  28.1
# 온도_내부_min                  11.7
# 온도_내부_mean                17.65
# 상대습도_내부_max                82.0
# 상대습도_내부_min                16.0
# 상대습도_내부_mean          57.291667
# 잔존CO2_max                1321.0
# 잔존CO2_min                 465.0
# 잔존CO2_mean           638.086957
# 토양온도_max                    NaN
# 토양온도_min                    NaN
# 토양온도_mean                   NaN
# Name: 35, dtype: object
# 42 7
# date            2020-10-27 0:00
# 온도_외부_max                  22.2
# 온도_외부_min                   3.5
# 온도_외부_mean               11.675
# 온도_내부_max                  25.8
# 온도_내부_min                  12.3
# 온도_내부_mean            17.358333
# 상대습도_내부_max                82.0
# 상대습도_내부_min                21.0
# 상대습도_내부_mean          61.708333
# 잔존CO2_max                1155.0
# 잔존CO2_min                 448.0
# 잔존CO2_mean           656.714286
# 토양온도_max                    NaN
# 토양온도_min                    NaN
# 토양온도_mean                   NaN
# Name: 42, dtype: object
# 49 8
# date            2020-11-03 0:00
# 온도_외부_max                  12.3
# 온도_외부_min                  -0.1
# 온도_외부_mean               6.6625
# 온도_내부_max                  25.1
# 온도_내부_min                  13.0
# 온도_내부_mean            17.054167
# 상대습도_내부_max                79.0
# 상대습도_내부_min                22.0
# 상대습도_내부_mean          60.041667
# 잔존CO2_max                1396.0
# 잔존CO2_min                 361.0
# 잔존CO2_mean           589.333333
# 토양온도_max                    NaN
# 토양온도_min                    NaN
# 토양온도_mean                   NaN
# Name: 49, dtype: object
# 56 9
# date            2020-11-10 0:00
# 온도_외부_max                  14.9
# 온도_외부_min                   0.3
# 온도_외부_mean               7.2375
# 온도_내부_max                  23.8
# 온도_내부_min                  10.4
# 온도_내부_mean              15.8125
# 상대습도_내부_max                86.0
# 상대습도_내부_min                21.0
# 상대습도_내부_mean          62.416667
# 잔존CO2_max                1297.0
# 잔존CO2_min                 380.0
# 잔존CO2_mean           568.454545
# 토양온도_max                   19.4
# 토양온도_min                   12.8
# 토양온도_mean                 16.15
# Name: 56, dtype: object
# 63 10
# date            2020-11-17 0:00
# 온도_외부_max                  20.3
# 온도_외부_min                   5.7
# 온도_외부_mean                13.25
# 온도_내부_max                  23.6
# 온도_내부_min                  13.8
# 온도_내부_mean            17.491667
# 상대습도_내부_max               100.0
# 상대습도_내부_min                48.0
# 상대습도_내부_mean              86.75
# 잔존CO2_max                 797.0
# 잔존CO2_min                 395.0
# 잔존CO2_mean           593.391304
# 토양온도_max                   19.5
# 토양온도_min                   16.7
# 토양온도_mean             18.279167
# Name: 63, dtype: object
# 70 11
# date            2020-11-24 0:00
# 온도_외부_max                  11.2
# 온도_외부_min                  -0.3
# 온도_외부_mean             4.883333
# 온도_내부_max                  25.0
# 온도_내부_min                  12.0
# 온도_내부_mean                16.25
# 상대습도_내부_max                94.0
# 상대습도_내부_min                34.0
# 상대습도_내부_mean          76.791667
# 잔존CO2_max                1392.0
# 잔존CO2_min                 349.0
# 잔존CO2_mean           712.428571
# 토양온도_max                   21.7
# 토양온도_min                   17.1
# 토양온도_mean               18.9875
# Name: 70, dtype: object
# 77 12
# date            2020-12-01 0:00
# 온도_외부_max                   8.3
# 온도_외부_min                  -5.7
# 온도_외부_mean                0.775
# 온도_내부_max                  24.8
# 온도_내부_min                   9.6
# 온도_내부_mean              14.5125
# 상대습도_내부_max                85.0
# 상대습도_내부_min                31.0
# 상대습도_내부_mean          71.916667
# 잔존CO2_max                1382.0
# 잔존CO2_min                 286.0
# 잔존CO2_mean                685.6
# 토양온도_max                   21.4
# 토양온도_min                   15.9
# 토양온도_mean                18.325
# Name: 77, dtype: object
# 84 13
# date            2020-12-08 0:00
# 온도_외부_max                   6.3
# 온도_외부_min                  -5.0
# 온도_외부_mean             0.079167
# 온도_내부_max                  24.3
# 온도_내부_min                   9.4
# 온도_내부_mean            13.304167
# 상대습도_내부_max                93.0
# 상대습도_내부_min                23.0
# 상대습도_내부_mean          71.666667
# 잔존CO2_max                1360.0
# 잔존CO2_min                 345.0
# 잔존CO2_mean                686.9
# 토양온도_max                   19.2
# 토양온도_min                   15.7
# 토양온도_mean             17.483333
# Name: 84, dtype: object
# 91 14
# date            2020-12-15 0:00
# 온도_외부_max                   0.0
# 온도_외부_min                 -11.0
# 온도_외부_mean            -5.820833
# 온도_내부_max                  22.3
# 온도_내부_min                   8.0
# 온도_내부_mean            12.520833
# 상대습도_내부_max                85.0
# 상대습도_내부_min                46.0
# 상대습도_내부_mean          74.583333
# 잔존CO2_max                1393.0
# 잔존CO2_min                 295.0
# 잔존CO2_mean                940.5
# 토양온도_max                   19.9
# 토양온도_min                   16.0
# 토양온도_mean             17.533333
# Name: 91, dtype: object
# 98 15
# date            2020-12-22 0:00
# 온도_외부_max                   8.1
# 온도_외부_min                  -6.7
# 온도_외부_mean            -0.654167
# 온도_내부_max                  23.6
# 온도_내부_min                   6.4
# 온도_내부_mean            13.454167
# 상대습도_내부_max                97.0
# 상대습도_내부_min                68.0
# 상대습도_내부_mean          89.041667
# 잔존CO2_max                1294.0
# 잔존CO2_min                 368.0
# 잔존CO2_mean                726.9
# 토양온도_max                   19.6
# 토양온도_min                   16.0
# 토양온도_mean               17.6625
# Name: 98, dtype: object
# 105 16
# date            2020-12-29 0:00
# 온도_외부_max                   7.1
# 온도_외부_min                  -2.2
# 온도_외부_mean             1.254167
# 온도_내부_max                  21.2
# 온도_내부_min                   9.3
# 온도_내부_mean            12.270833
# 상대습도_내부_max               100.0
# 상대습도_내부_min                86.0
# 상대습도_내부_mean          97.208333
# 잔존CO2_max                1184.0
# 잔존CO2_min                 667.0
# 잔존CO2_mean           843.684211
# 토양온도_max                   18.4
# 토양온도_min                   15.4
# 토양온도_mean             17.179167
# Name: 105, dtype: object
# 112 17
# date            2021-01-05 0:00
# 온도_외부_max                   1.0
# 온도_외부_min                  -9.8
# 온도_외부_mean                -2.25
# 온도_내부_max                  20.5
# 온도_내부_min                   8.1
# 온도_내부_mean            12.120833
# 상대습도_내부_max               100.0
# 상대습도_내부_min                70.0
# 상대습도_내부_mean          91.333333
# 잔존CO2_max                1096.0
# 잔존CO2_min                 757.0
# 잔존CO2_mean                870.8
# 토양온도_max                   18.8
# 토양온도_min                   15.6
# 토양온도_mean             17.395833
# Name: 112, dtype: object
# 119 18
# date            2021-01-12 0:00
# 온도_외부_max                   2.9
# 온도_외부_min                  -7.1
# 온도_외부_mean            -2.283333
# 온도_내부_max                  23.4
# 온도_내부_min                   6.5
# 온도_내부_mean            11.716667
# 상대습도_내부_max               100.0
# 상대습도_내부_min                72.0
# 상대습도_내부_mean          92.458333
# 잔존CO2_max                 879.0
# 잔존CO2_min                 720.0
# 잔존CO2_mean           771.285714
# 토양온도_max                   17.2
# 토양온도_min                   11.4
# 토양온도_mean               13.3875
# Name: 119, dtype: object
# 126 19
# date            2021-01-19 0:00
# 온도_외부_max                   1.8
# 온도_외부_min                 -11.6
# 온도_외부_mean            -4.954167
# 온도_내부_max                  28.7
# 온도_내부_min                   6.7
# 온도_내부_mean                12.65
# 상대습도_내부_max               100.0
# 상대습도_내부_min                59.0
# 상대습도_내부_mean          86.083333
# 잔존CO2_max                1252.0
# 잔존CO2_min                 587.0
# 잔존CO2_mean           787.923077
# 토양온도_max                   20.1
# 토양온도_min                   11.5
# 토양온도_mean             14.191667
# Name: 126, dtype: object
# 133 20
# date            2021-01-26 0:00
# 온도_외부_max                   8.7
# 온도_외부_min                   2.3
# 온도_외부_mean             5.091667
# 온도_내부_max                  18.3
# 온도_내부_min                  10.4
# 온도_내부_mean            12.016667
# 상대습도_내부_max               100.0
# 상대습도_내부_min                91.0
# 상대습도_내부_mean          99.416667
# 잔존CO2_max                1212.0
# 잔존CO2_min                 687.0
# 잔존CO2_mean           892.428571
# 토양온도_max                   14.9
# 토양온도_min                   12.8
# 토양온도_mean             13.654167
# Name: 133, dtype: object
# 140 21
# date            2021-02-02 0:00
# 온도_외부_max                   2.5
# 온도_외부_min                  -4.5
# 온도_외부_mean            -1.508333
# 온도_내부_max                  25.5
# 온도_내부_min                   7.5
# 온도_내부_mean            13.120833
# 상대습도_내부_max               100.0
# 상대습도_내부_min                62.0
# 상대습도_내부_mean             88.875
# 잔존CO2_max                 985.0
# 잔존CO2_min                 513.0
# 잔존CO2_mean           737.444444
# 토양온도_max                   19.9
# 토양온도_min                   11.9
# 토양온도_mean                14.625
# Name: 140, dtype: object
# 147 22
# date            2021-02-09 0:00
# 온도_외부_max                   6.9
# 온도_외부_min                  -8.9
# 온도_외부_mean               -1.825
# 온도_내부_max                  28.2
# 온도_내부_min                   6.3
# 온도_내부_mean            14.066667
# 상대습도_내부_max                97.0
# 상대습도_내부_min                61.0
# 상대습도_내부_mean          85.583333
# 잔존CO2_max                 955.0
# 잔존CO2_min                 596.0
# 잔존CO2_mean           744.444444
# 토양온도_max                   19.5
# 토양온도_min                   11.5
# 토양온도_mean             14.729167
# Name: 147, dtype: object
# 154 23
# date            2021-02-16 0:00
# 온도_외부_max                   2.4
# 온도_외부_min                  -8.2
# 온도_외부_mean            -3.058333
# 온도_내부_max                  21.1
# 온도_내부_min                   7.6
# 온도_내부_mean            11.079167
# 상대습도_내부_max               100.0
# 상대습도_내부_min                69.0
# 상대습도_내부_mean               93.0
# 잔존CO2_max                1394.0
# 잔존CO2_min                 468.0
# 잔존CO2_mean                769.7
# 토양온도_max                   15.8
# 토양온도_min                   11.9
# 토양온도_mean             13.120833
# Name: 154, dtype: object
# 161 24
# date            2021-02-23 0:00
# 온도_외부_max                   8.6
# 온도_외부_min                  -4.7
# 온도_외부_mean               1.9875
# 온도_내부_max                  24.7
# 온도_내부_min                   8.1
# 온도_내부_mean            14.354167
# 상대습도_내부_max                97.0
# 상대습도_내부_min                50.0
# 상대습도_내부_mean          83.666667
# 잔존CO2_max                1365.0
# 잔존CO2_min                 336.0
# 잔존CO2_mean               717.25
# 토양온도_max                   18.6
# 토양온도_min                   12.4
# 토양온도_mean             14.929167
# Name: 161, dtype: object
# 168 25
# date            2021-03-02 0:00
# 온도_외부_max                   9.0
# 온도_외부_min                   0.4
# 온도_외부_mean              4.80625
# 온도_내부_max                  25.6
# 온도_내부_min                   8.8
# 온도_내부_mean              13.8875
# 상대습도_내부_max               100.0
# 상대습도_내부_min                67.0
# 상대습도_내부_mean          93.208333
# 잔존CO2_max                1347.0
# 잔존CO2_min                 342.0
# 잔존CO2_mean           616.727273
# 토양온도_max                   17.4
# 토양온도_min                   12.5
# 토양온도_mean             14.283333
# Name: 168, dtype: object
# 175 26
# date            2021-03-09 0:00
# 온도_외부_max                  14.7
# 온도_외부_min                   1.3
# 온도_외부_mean             6.608333
# 온도_내부_max                  20.8
# 온도_내부_min                   8.1
# 온도_내부_mean            13.308333
# 상대습도_내부_max               100.0
# 상대습도_내부_min                46.0
# 상대습도_내부_mean               85.5
# 잔존CO2_max                1331.0
# 잔존CO2_min                 425.0
# 잔존CO2_mean           689.782609
# 토양온도_max                   16.9
# 토양온도_min                   12.5
# 토양온도_mean             14.333333
# Name: 175, dtype: object
# 182 27
# date            2021-03-16 0:00
# 온도_외부_max                  17.4
# 온도_외부_min                   2.1
# 온도_외부_mean                 11.3
# 온도_내부_max                  24.0
# 온도_내부_min                   9.4
# 온도_내부_mean            15.191667
# 상대습도_내부_max               100.0
# 상대습도_내부_min                22.0
# 상대습도_내부_mean              70.75
# 잔존CO2_max                1305.0
# 잔존CO2_min                 407.0
# 잔존CO2_mean           605.913043
# 토양온도_max                   18.3
# 토양온도_min                   14.4
# 토양온도_mean             15.779167
# Name: 182, dtype: object
# 189 28
# date            2021-03-23 0:00
# 온도_외부_max                  16.1
# 온도_외부_min                  -1.1
# 온도_외부_mean             7.020833
# 온도_내부_max                  21.6
# 온도_내부_min                   8.8
# 온도_내부_mean            13.941667
# 상대습도_내부_max               100.0
# 상대습도_내부_min                33.0
# 상대습도_내부_mean               75.5
# 잔존CO2_max                1392.0
# 잔존CO2_min                 441.0
# 잔존CO2_mean                642.6
# 토양온도_max                   17.4
# 토양온도_min                   11.9
# 토양온도_mean             14.154167
# Name: 189, dtype: object
# 196 29
# date            2021-03-30 0:00
# 온도_외부_max                  20.3
# 온도_외부_min                   4.3
# 온도_외부_mean            12.141667
# 온도_내부_max                  26.3
# 온도_내부_min                   8.4
# 온도_내부_mean                15.75
# 상대습도_내부_max               100.0
# 상대습도_내부_min                19.0
# 상대습도_내부_mean             57.625
# 잔존CO2_max                1299.0
# 잔존CO2_min                 441.0
# 잔존CO2_mean           574.695652
# 토양온도_max                   19.7
# 토양온도_min                   12.4
# 토양온도_mean             15.258333
# Name: 196, dtype: object
# 203 30
# date            2021-04-06 0:00
# 온도_외부_max                  21.5
# 온도_외부_min                   3.3
# 온도_외부_mean               12.025
# 온도_내부_max                  29.5
# 온도_내부_min                   8.7
# 온도_내부_mean            16.666667
# 상대습도_내부_max               100.0
# 상대습도_내부_min                22.0
# 상대습도_내부_mean          74.291667
# 잔존CO2_max                 858.0
# 잔존CO2_min                 320.0
# 잔존CO2_mean           576.458333
# 토양온도_max                   19.4
# 토양온도_min                   13.4
# 토양온도_mean                  16.2
# Name: 203, dtype: object
# 210 31
# date            2021-04-13 0:00
# 온도_외부_max                  15.7
# 온도_외부_min                   4.6
# 온도_외부_mean             9.781818
# 온도_내부_max                  24.3
# 온도_내부_min                   7.9
# 온도_내부_mean            15.683333
# 상대습도_내부_max               100.0
# 상대습도_내부_min                36.0
# 상대습도_내부_mean          81.416667
# 잔존CO2_max                1357.0
# 잔존CO2_min                 435.0
# 잔존CO2_mean           556.956522
# 토양온도_max                   18.8
# 토양온도_min                   14.7
# 토양온도_mean               16.2125
# Name: 210, dtype: object
# 217 32
# date            2021-04-20 0:00
# 온도_외부_max                  25.6
# 온도_외부_min                   3.4
# 온도_외부_mean            14.545833
# 온도_내부_max                  25.5
# 온도_내부_min                   6.1
# 온도_내부_mean            16.041667
# 상대습도_내부_max               100.0
# 상대습도_내부_min                27.0
# 상대습도_내부_mean          65.416667
# 잔존CO2_max                1361.0
# 잔존CO2_min                 453.0
# 잔존CO2_mean           641.681818
# 토양온도_max                   18.1
# 토양온도_min                   11.7
# 토양온도_mean             15.108333
# Name: 217, dtype: object
# 0 1
# date            2020-09-10 0:00
# 온도_외부_max                   NaN
# 온도_외부_min                   NaN
# 온도_외부_mean                  NaN
# 온도_내부_max                   NaN
# 온도_내부_min                   NaN
# 온도_내부_mean                  NaN
# 상대습도_내부_max                 NaN
# 상대습도_내부_min                 NaN
# 상대습도_내부_mean                NaN
# 잔존CO2_max                   NaN
# 잔존CO2_min                   NaN
# 잔존CO2_mean                  NaN
# 토양온도_max                    NaN
# 토양온도_min                    NaN
# 토양온도_mean                   NaN
# Name: 224, dtype: object
# 7 2
# date            2020-09-17 0:00
# 온도_외부_max                   NaN
# 온도_외부_min                   NaN
# 온도_외부_mean                  NaN
# 온도_내부_max                   NaN
# 온도_내부_min                   NaN
# 온도_내부_mean                  NaN
# 상대습도_내부_max                 NaN
# 상대습도_내부_min                 NaN
# 상대습도_내부_mean                NaN
# 잔존CO2_max                   NaN
# 잔존CO2_min                   NaN
# 잔존CO2_mean                  NaN
# 토양온도_max                    NaN
# 토양온도_min                    NaN
# 토양온도_mean                   NaN
# Name: 231, dtype: object
# 14 3
# date            2020-09-24 0:00
# 온도_외부_max                  27.9
# 온도_외부_min                  15.4
# 온도_외부_mean            21.116667
# 온도_내부_max                  33.4
# 온도_내부_min                  17.2
# 온도_내부_mean            23.841667
# 상대습도_내부_max                96.9
# 상대습도_내부_min                90.8
# 상대습도_내부_mean          94.054167
# 잔존CO2_max                 504.0
# 잔존CO2_min                 420.0
# 잔존CO2_mean              452.375
# 토양온도_max                   36.3
# 토양온도_min                   16.3
# 토양온도_mean             23.766667
# Name: 238, dtype: object
# 21 4
# date            2020-10-01 0:00
# 온도_외부_max                  24.4
# 온도_외부_min                  15.2
# 온도_외부_mean                 18.9
# 온도_내부_max                  29.9
# 온도_내부_min                  19.3
# 온도_내부_mean            23.216667
# 상대습도_내부_max                96.4
# 상대습도_내부_min                90.0
# 상대습도_내부_mean          94.383333
# 잔존CO2_max                 637.0
# 잔존CO2_min                 432.0
# 잔존CO2_mean           528.333333
# 토양온도_max                   31.3
# 토양온도_min                   18.2
# 토양온도_mean                22.475
# Name: 245, dtype: object
# 28 5
# date            2020-10-08 0:00
# 온도_외부_max                   NaN
# 온도_외부_min                   NaN
# 온도_외부_mean                  NaN
# 온도_내부_max                   NaN
# 온도_내부_min                   NaN
# 온도_내부_mean                  NaN
# 상대습도_내부_max                 NaN
# 상대습도_내부_min                 NaN
# 상대습도_내부_mean                NaN
# 잔존CO2_max                   NaN
# 잔존CO2_min                   NaN
# 잔존CO2_mean                  NaN
# 토양온도_max                    NaN
# 토양온도_min                    NaN
# 토양온도_mean                   NaN
# Name: 252, dtype: object
# 35 6
# date            2020-10-15 0:00
# 온도_외부_max                   NaN
# 온도_외부_min                   NaN
# 온도_외부_mean                  NaN
# 온도_내부_max                   NaN
# 온도_내부_min                   NaN
# 온도_내부_mean                  NaN
# 상대습도_내부_max                 NaN
# 상대습도_내부_min                 NaN
# 상대습도_내부_mean                NaN
# 잔존CO2_max                   NaN
# 잔존CO2_min                   NaN
# 잔존CO2_mean                  NaN
# 토양온도_max                    NaN
# 토양온도_min                    NaN
# 토양온도_mean                   NaN
# Name: 259, dtype: object
# 42 7
# date            2020-10-22 0:00
# 온도_외부_max                  19.6
# 온도_외부_min                   6.2
# 온도_외부_mean            12.904167
# 온도_내부_max                  26.7
# 온도_내부_min                  16.0
# 온도_내부_mean            20.333333
# 상대습도_내부_max                93.7
# 상대습도_내부_min                75.1
# 상대습도_내부_mean          87.420833
# 잔존CO2_max                 645.0
# 잔존CO2_min                 445.0
# 잔존CO2_mean              544.625
# 토양온도_max                   28.9
# 토양온도_min                   14.5
# 토양온도_mean             19.670833
# Name: 266, dtype: object
# 49 8
# date            2020-10-29 0:00
# 온도_외부_max                  18.0
# 온도_외부_min                  -0.5
# 온도_외부_mean             7.320833
# 온도_내부_max                  28.2
# 온도_내부_min                  15.3
# 온도_내부_mean            20.883333
# 상대습도_내부_max                91.1
# 상대습도_내부_min                80.4
# 상대습도_내부_mean          86.458333
# 잔존CO2_max                 681.0
# 잔존CO2_min                 454.0
# 잔존CO2_mean           548.458333
# 토양온도_max                   30.7
# 토양온도_min                   14.3
# 토양온도_mean             20.570833
# Name: 273, dtype: object
# 56 9
# date            2020-11-05 0:00
# 온도_외부_max                  16.9
# 온도_외부_min                  -2.5
# 온도_외부_mean                6.475
# 온도_내부_max                  28.3
# 온도_내부_min                  13.8
# 온도_내부_mean            19.270833
# 상대습도_내부_max                95.3
# 상대습도_내부_min                82.5
# 상대습도_내부_mean             89.025
# 잔존CO2_max                 845.0
# 잔존CO2_min                 427.0
# 잔존CO2_mean           571.541667
# 토양온도_max                   29.3
# 토양온도_min                   12.6
# 토양온도_mean             18.620833
# Name: 280, dtype: object
# 63 10
# date            2020-11-12 0:00
# 온도_외부_max                  19.3
# 온도_외부_min                  -0.8
# 온도_외부_mean             7.233333
# 온도_내부_max                  25.1
# 온도_내부_min                  13.4
# 온도_내부_mean            18.404167
# 상대습도_내부_max                95.6
# 상대습도_내부_min                84.1
# 상대습도_내부_mean               89.9
# 잔존CO2_max                1221.0
# 잔존CO2_min                 436.0
# 잔존CO2_mean           684.190476
# 토양온도_max                   26.1
# 토양온도_min                   12.7
# 토양온도_mean             17.741667
# Name: 287, dtype: object
# 70 11
# date            2020-11-19 0:00
# 온도_외부_max                  21.0
# 온도_외부_min                  10.9
# 온도_외부_mean            16.620833
# 온도_내부_max                  20.7
# 온도_내부_min                  16.5
# 온도_내부_mean               18.975
# 상대습도_내부_max                96.3
# 상대습도_내부_min                92.3
# 상대습도_내부_mean          94.208333
# 잔존CO2_max                 816.0
# 잔존CO2_min                 430.0
# 잔존CO2_mean           572.458333
# 토양온도_max                   19.8
# 토양온도_min                   15.5
# 토양온도_mean             18.045833
# Name: 294, dtype: object
# 77 12
# date            2020-11-26 0:00
# 온도_외부_max                  13.3
# 온도_외부_min                   1.6
# 온도_외부_mean                6.325
# 온도_내부_max                  24.9
# 온도_내부_min                  12.4
# 온도_내부_mean            16.554167
# 상대습도_내부_max                94.9
# 상대습도_내부_min                85.5
# 상대습도_내부_mean          90.679167
# 잔존CO2_max                 978.0
# 잔존CO2_min                 381.0
# 잔존CO2_mean              612.125
# 토양온도_max                   28.0
# 토양온도_min                   11.1
# 토양온도_mean             15.808333
# Name: 301, dtype: object
# 84 13
# date            2020-12-03 0:00
# 온도_외부_max                   7.1
# 온도_외부_min                  -4.1
# 온도_외부_mean             0.733333
# 온도_내부_max                  21.5
# 온도_내부_min                  10.9
# 온도_내부_mean            14.579167
# 상대습도_내부_max                94.2
# 상대습도_내부_min                85.1
# 상대습도_내부_mean            90.6375
# 잔존CO2_max                1265.0
# 잔존CO2_min                 348.0
# 잔존CO2_mean           605.833333
# 토양온도_max                   23.7
# 토양온도_min                    9.6
# 토양온도_mean             13.929167
# Name: 308, dtype: object
# 91 14
# date            2020-12-10 0:00
# 온도_외부_max                  10.6
# 온도_외부_min                   1.6
# 온도_외부_mean                5.125
# 온도_내부_max                  26.8
# 온도_내부_min                  12.7
# 온도_내부_mean            16.670833
# 상대습도_내부_max                95.7
# 상대습도_내부_min                89.8
# 상대습도_내부_mean             93.225
# 잔존CO2_max                 603.0
# 잔존CO2_min                 353.0
# 잔존CO2_mean           499.583333
# 토양온도_max                   27.6
# 토양온도_min                   11.6
# 토양온도_mean             15.870833
# Name: 315, dtype: object
# 98 15
# date            2020-12-17 0:00
# 온도_외부_max                   3.6
# 온도_외부_min                 -11.2
# 온도_외부_mean            -5.145833
# 온도_내부_max                  25.4
# 온도_내부_min                  10.1
# 온도_내부_mean                 14.1
# 상대습도_내부_max                96.8
# 상대습도_내부_min                87.8
# 상대습도_내부_mean            92.0625
# 잔존CO2_max                 905.0
# 잔존CO2_min                 327.0
# 잔존CO2_mean                447.0
# 토양온도_max                   28.4
# 토양온도_min                    9.3
# 토양온도_mean             13.295833
# Name: 322, dtype: object
# 105 16
# date            2020-12-24 0:00
# 온도_외부_max                   9.5
# 온도_외부_min                  -4.4
# 온도_외부_mean             2.145833
# 온도_내부_max                  26.1
# 온도_내부_min                  11.5
# 온도_내부_mean               15.275
# 상대습도_내부_max                96.7
# 상대습도_내부_min                89.4
# 상대습도_내부_mean            92.9625
# 잔존CO2_max                1226.0
# 잔존CO2_min                 348.0
# 잔존CO2_mean           610.454545
# 토양온도_max                   28.3
# 토양온도_min                   10.1
# 토양온도_mean                14.475
# Name: 329, dtype: object
# 112 17
# date            2020-12-31 0:00
# 온도_외부_max                  -2.2
# 온도_외부_min                 -14.8
# 온도_외부_mean              -8.3625
# 온도_내부_max                  24.4
# 온도_내부_min                   8.3
# 온도_내부_mean              12.8375
# 상대습도_내부_max                95.3
# 상대습도_내부_min                89.2
# 상대습도_내부_mean          92.454167
# 잔존CO2_max                1382.0
# 잔존CO2_min                 380.0
# 잔존CO2_mean           618.772727
# 토양온도_max                   26.8
# 토양온도_min                    7.2
# 토양온도_mean                 12.15
# Name: 336, dtype: object
# 119 18
# date            2021-01-07 0:00
# 온도_외부_max                  -4.1
# 온도_외부_min                 -18.8
# 온도_외부_mean           -10.666667
# 온도_내부_max                  15.0
# 온도_내부_min                   9.1
# 온도_내부_mean            10.995833
# 상대습도_내부_max                94.1
# 상대습도_내부_min                88.0
# 상대습도_내부_mean          91.341667
# 잔존CO2_max                1240.0
# 잔존CO2_min                 380.0
# 잔존CO2_mean                683.8
# 토양온도_max                   13.3
# 토양온도_min                    6.7
# 토양온도_mean              9.466667
# Name: 343, dtype: object
# 126 19
# date            2021-01-14 0:00
# 온도_외부_max                  11.0
# 온도_외부_min                  -5.2
# 온도_외부_mean             1.354167
# 온도_내부_max                  26.6
# 온도_내부_min                  10.2
# 온도_내부_mean            14.733333
# 상대습도_내부_max                96.3
# 상대습도_내부_min                88.4
# 상대습도_내부_mean             92.625
# 잔존CO2_max                1284.0
# 잔존CO2_min                 390.0
# 잔존CO2_mean               574.55
# 토양온도_max                   26.3
# 토양온도_min                    9.1
# 토양온도_mean               13.5375
# Name: 350, dtype: object
# 133 20
# date            2021-01-21 0:00
# 온도_외부_max                  10.4
# 온도_외부_min                  -2.0
# 온도_외부_mean             4.441667
# 온도_내부_max                  21.9
# 온도_내부_min                  10.5
# 온도_내부_mean            14.358333
# 상대습도_내부_max                95.7
# 상대습도_내부_min                89.3
# 상대습도_내부_mean             92.875
# 잔존CO2_max                 928.0
# 잔존CO2_min                 419.0
# 잔존CO2_mean           597.166667
# 토양온도_max                   22.3
# 토양온도_min                    9.2
# 토양온도_mean             13.008333
# Name: 357, dtype: object
# 140 21
# date            2021-01-28 0:00
# 온도_외부_max                   2.8
# 온도_외부_min                  -5.5
# 온도_외부_mean            -1.520833
# 온도_내부_max                  18.5
# 온도_내부_min                  10.4
# 온도_내부_mean              13.4125
# 상대습도_내부_max                94.3
# 상대습도_내부_min                90.1
# 상대습도_내부_mean          92.295833
# 잔존CO2_max                 675.0
# 잔존CO2_min                 247.0
# 잔존CO2_mean           588.181818
# 토양온도_max                   19.2
# 토양온도_min                    8.0
# 토양온도_mean             11.833333
# Name: 364, dtype: object
# 147 22
# date            2021-02-04 0:00
# 온도_외부_max                   NaN
# 온도_외부_min                   NaN
# 온도_외부_mean                  NaN
# 온도_내부_max                   NaN
# 온도_내부_min                   NaN
# 온도_내부_mean                  NaN
# 상대습도_내부_max                 NaN
# 상대습도_내부_min                 NaN
# 상대습도_내부_mean                NaN
# 잔존CO2_max                   NaN
# 잔존CO2_min                   NaN
# 잔존CO2_mean                  NaN
# 토양온도_max                    NaN
# 토양온도_min                    NaN
# 토양온도_mean                   NaN
# Name: 371, dtype: object
# 154 23
# date            2021-02-11 0:00
# 온도_외부_max                  12.9
# 온도_외부_min                  -3.0
# 온도_외부_mean             3.666667
# 온도_내부_max                  27.0
# 온도_내부_min                  10.0
# 온도_내부_mean              16.1375
# 상대습도_내부_max                96.2
# 상대습도_내부_min                88.2
# 상대습도_내부_mean          92.316667
# 잔존CO2_max                 979.0
# 잔존CO2_min                 399.0
# 잔존CO2_mean                588.9
# 토양온도_max                   26.7
# 토양온도_min                    9.1
# 토양온도_mean                 15.35
# Name: 378, dtype: object
# 161 24
# date            2021-02-18 0:00
# 온도_외부_max                   1.5
# 온도_외부_min                 -10.8
# 온도_외부_mean            -4.741667
# 온도_내부_max                  25.5
# 온도_내부_min                  10.5
# 온도_내부_mean                14.75
# 상대습도_내부_max                95.9
# 상대습도_내부_min                87.7
# 상대습도_내부_mean          91.995833
# 잔존CO2_max                1340.0
# 잔존CO2_min                 347.0
# 잔존CO2_mean               533.85
# 토양온도_max                   28.1
# 토양온도_min                    9.6
# 토양온도_mean                 14.45
# Name: 385, dtype: object
# 168 25
# date            2021-02-25 0:00
# 온도_외부_max                   9.6
# 온도_외부_min                  -3.2
# 온도_외부_mean                  3.0
# 온도_내부_max                  20.2
# 온도_내부_min                  11.4
# 온도_내부_mean              14.9375
# 상대습도_내부_max                95.0
# 상대습도_내부_min                88.4
# 상대습도_내부_mean            92.8125
# 잔존CO2_max                1250.0
# 잔존CO2_min                 365.0
# 잔존CO2_mean           619.166667
# 토양온도_max                   19.7
# 토양온도_min                    9.4
# 토양온도_mean             13.691667
# Name: 392, dtype: object
# 175 26
# date            2021-03-04 0:00
# 온도_외부_max                  10.8
# 온도_외부_min                  -0.1
# 온도_외부_mean                4.675
# 온도_내부_max                  23.1
# 온도_내부_min                  11.8
# 온도_내부_mean              15.9375
# 상대습도_내부_max                95.1
# 상대습도_내부_min                90.9
# 상대습도_내부_mean          93.395833
# 잔존CO2_max                1016.0
# 잔존CO2_min                 354.0
# 잔존CO2_mean               553.25
# 토양온도_max                   23.3
# 토양온도_min                   10.8
# 토양온도_mean             15.129167
# Name: 399, dtype: object
# 182 27
# date            2021-03-11 0:00
# 온도_외부_max                  18.8
# 온도_외부_min                  -0.8
# 온도_외부_mean                 8.85
# 온도_내부_max                  23.7
# 온도_내부_min                  10.6
# 온도_내부_mean            16.508333
# 상대습도_내부_max                97.3
# 상대습도_내부_min                85.6
# 상대습도_내부_mean            93.0375
# 잔존CO2_max                1345.0
# 잔존CO2_min                 437.0
# 잔존CO2_mean           594.555556
# 토양온도_max                   24.3
# 토양온도_min                    9.5
# 토양온도_mean             15.658333
# Name: 406, dtype: object
# 189 28
# date            2021-03-18 0:00
# 온도_외부_max                  20.1
# 온도_외부_min                   0.0
# 온도_외부_mean             9.779167
# 온도_내부_max                  25.0
# 온도_내부_min                  10.3
# 온도_내부_mean            16.679167
# 상대습도_내부_max                96.0
# 상대습도_내부_min                88.8
# 상대습도_내부_mean               93.1
# 잔존CO2_max                 929.0
# 잔존CO2_min                 430.0
# 잔존CO2_mean           549.333333
# 토양온도_max                   26.0
# 토양온도_min                    9.3
# 토양온도_mean             15.945833
# Name: 413, dtype: object
# 196 29
# date            2021-03-25 0:00
# 온도_외부_max                  20.6
# 온도_외부_min                   1.1
# 온도_외부_mean               10.175
# 온도_내부_max                  28.1
# 온도_내부_min                   7.4
# 온도_내부_mean            16.783333
# 상대습도_내부_max                96.4
# 상대습도_내부_min                85.6
# 상대습도_내부_mean          91.704167
# 잔존CO2_max                 564.0
# 잔존CO2_min                 393.0
# 잔존CO2_mean           502.041667
# 토양온도_max                   28.3
# 토양온도_min                    6.4
# 토양온도_mean             16.520833
# Name: 420, dtype: object
# 203 30
# date            2021-04-01 0:00
# 온도_외부_max                  21.9
# 온도_외부_min                   5.1
# 온도_외부_mean            14.216667
# 온도_내부_max                  28.0
# 온도_내부_min                   9.8
# 온도_내부_mean                17.65
# 상대습도_내부_max                95.9
# 상대습도_내부_min                86.8
# 상대습도_내부_mean          92.970833
# 잔존CO2_max                 584.0
# 잔존CO2_min                 417.0
# 잔존CO2_mean               498.25
# 토양온도_max                   26.5
# 토양온도_min                    7.8
# 토양온도_mean             16.316667
# Name: 427, dtype: object
# 210 31
# date            2021-04-08 0:00
# 온도_외부_max                  20.1
# 온도_외부_min                   2.6
# 온도_외부_mean              9.91875
# 온도_내부_max                  25.9
# 온도_내부_min                   7.0
# 온도_내부_mean              15.0625
# 상대습도_내부_max                94.9
# 상대습도_내부_min                87.3
# 상대습도_내부_mean             90.975
# 잔존CO2_max                 535.0
# 잔존CO2_min                 418.0
# 잔존CO2_mean               501.75
# 토양온도_max                   24.3
# 토양온도_min                    5.6
# 토양온도_mean                14.025
# Name: 434, dtype: object
# 217 32
# date            2021-04-15 0:00
# 온도_외부_max                  18.9
# 온도_외부_min                  -0.6
# 온도_외부_mean             8.954167
# 온도_내부_max                  25.1
# 온도_내부_min                   4.8
# 온도_내부_mean              14.3125
# 상대습도_내부_max                94.8
# 상대습도_내부_min                87.3
# 상대습도_내부_mean             91.325
# 잔존CO2_max                 507.0
# 잔존CO2_min                 413.0
# 잔존CO2_mean               464.75
# 토양온도_max                   27.6
# 토양온도_min                    3.8
# 토양온도_mean             14.233333
# Name: 441, dtype: object
# 224 33
# date            2021-04-22 0:00
# 온도_외부_max                  29.1
# 온도_외부_min                  13.0
# 온도_외부_mean               20.225
# 온도_내부_max                  30.1
# 온도_내부_min                  14.9
# 온도_내부_mean            21.404167
# 상대습도_내부_max                96.2
# 상대습도_내부_min                90.8
# 상대습도_내부_mean              93.35
# 잔존CO2_max                 516.0
# 잔존CO2_min                 447.0
# 잔존CO2_mean           481.458333
# 토양온도_max                   29.4
# 토양온도_min                   13.8
# 토양온도_mean             20.604167
# Name: 448, dtype: object
# 231 34
# date            2021-04-29 0:00
# 온도_외부_max                  18.6
# 온도_외부_min                   9.1
# 온도_외부_mean               14.625
# 온도_내부_max                  24.5
# 온도_내부_min                  13.0
# 온도_내부_mean            18.470833
# 상대습도_내부_max                95.7
# 상대습도_내부_min                87.9
# 상대습도_내부_mean          92.720833
# 잔존CO2_max                 608.0
# 잔존CO2_min                 425.0
# 잔존CO2_mean              510.125
# 토양온도_max                   25.3
# 토양온도_min                   11.9
# 토양온도_mean             17.470833
# Name: 455, dtype: object
# 238 35
# date            2021-05-06 0:00
# 온도_외부_max                  22.1
# 온도_외부_min                   3.7
# 온도_외부_mean               13.325
# 온도_내부_max                  27.7
# 온도_내부_min                   7.6
# 온도_내부_mean            17.220833
# 상대습도_내부_max                96.1
# 상대습도_내부_min                88.0
# 상대습도_내부_mean            92.3625
# 잔존CO2_max                 495.0
# 잔존CO2_min                 431.0
# 잔존CO2_mean           466.916667
# 토양온도_max                   27.2
# 토양온도_min                    6.5
# 토양온도_mean             16.620833
# Name: 462, dtype: object
# 245 36
# date            2021-05-13 0:00
# 온도_외부_max                  31.4
# 온도_외부_min                  12.8
# 온도_외부_mean            21.695833
# 온도_내부_max                  33.8
# 온도_내부_min                  14.6
# 온도_내부_mean              23.5875
# 상대습도_내부_max                96.8
# 상대습도_내부_min                89.3
# 상대습도_내부_mean          93.966667
# 잔존CO2_max                 536.0
# 잔존CO2_min                 463.0
# 잔존CO2_mean               493.75
# 토양온도_max                   36.6
# 토양온도_min                   13.5
# 토양온도_mean                22.925
# Name: 469, dtype: object
# 252 37
# date            2021-05-20 0:00
# 온도_외부_max                  20.4
# 온도_외부_min                  16.0
# 온도_외부_mean            17.358824
# 온도_내부_max                  21.7
# 온도_내부_min                  17.5
# 온도_내부_mean            19.394118
# 상대습도_내부_max                95.8
# 상대습도_내부_min                91.5
# 상대습도_내부_mean          93.647059
# 잔존CO2_max                 487.0
# 잔존CO2_min                 420.0
# 잔존CO2_mean           457.647059
# 토양온도_max                   21.2
# 토양온도_min                   16.2
# 토양온도_mean             18.311765
# Name: 476, dtype: object
# 0 1
# date            2020-09-13 0:00
# 온도_외부_max                  26.9
# 온도_외부_min                  18.7
# 온도_외부_mean            21.579167
# 온도_내부_max                  27.4
# 온도_내부_min                  19.9
# 온도_내부_mean            22.891667
# 상대습도_내부_max                94.7
# 상대습도_내부_min                65.3
# 상대습도_내부_mean          84.670833
# 잔존CO2_max                 476.0
# 잔존CO2_min                 389.0
# 잔존CO2_mean           426.916667
# 토양온도_max                   27.3
# 토양온도_min                   19.8
# 토양온도_mean             22.595833
# Name: 477, dtype: object
# 7 2
# date            2020-09-20 0:00
# 온도_외부_max                  25.8
# 온도_외부_min                  13.4
# 온도_외부_mean              18.3875
# 온도_내부_max                  29.4
# 온도_내부_min                  15.3
# 온도_내부_mean            20.254167
# 상대습도_내부_max                94.5
# 상대습도_내부_min                55.4
# 상대습도_내부_mean          81.108333
# 잔존CO2_max                 577.0
# 잔존CO2_min                 399.0
# 잔존CO2_mean           479.666667
# 토양온도_max                   29.4
# 토양온도_min                   15.8
# 토양온도_mean             20.495833
# Name: 484, dtype: object
# 14 3
# date            2020-09-27 0:00
# 온도_외부_max                  26.0
# 온도_외부_min                  12.9
# 온도_외부_mean              19.0875
# 온도_내부_max                  29.5
# 온도_내부_min                  13.6
# 온도_내부_mean            20.329167
# 상대습도_내부_max                93.6
# 상대습도_내부_min                55.0
# 상대습도_내부_mean          80.441667
# 잔존CO2_max                 607.0
# 잔존CO2_min                 387.0
# 잔존CO2_mean           482.083333
# 토양온도_max                   28.3
# 토양온도_min                   13.4
# 토양온도_mean             20.079167
# Name: 491, dtype: object
# 21 4
# date            2020-10-04 0:00
# 온도_외부_max                  20.4
# 온도_외부_min                  13.5
# 온도_외부_mean            18.358333
# 온도_내부_max                  22.4
# 온도_내부_min                  14.4
# 온도_내부_mean               19.375
# 상대습도_내부_max                96.1
# 상대습도_내부_min                77.6
# 상대습도_내부_mean          87.770833
# 잔존CO2_max                 559.0
# 잔존CO2_min                 417.0
# 잔존CO2_mean           470.791667
# 토양온도_max                   22.5
# 토양온도_min                   14.3
# 토양온도_mean             19.333333
# Name: 498, dtype: object
# 28 5
# date            2020-10-11 0:00
# 온도_외부_max                  23.6
# 온도_외부_min                  10.7
# 온도_외부_mean            16.729167
# 온도_내부_max                  26.3
# 온도_내부_min                  12.8
# 온도_내부_mean            18.458333
# 상대습도_내부_max                96.1
# 상대습도_내부_min                66.4
# 상대습도_내부_mean          85.216667
# 잔존CO2_max                 669.0
# 잔존CO2_min                 394.0
# 잔존CO2_mean              493.625
# 토양온도_max                   26.3
# 토양온도_min                   12.5
# 토양온도_mean             18.304167
# Name: 505, dtype: object
# 35 6
# date            2020-10-18 0:00
# 온도_외부_max                  20.7
# 온도_외부_min                   2.9
# 온도_외부_mean            11.370833
# 온도_내부_max                  26.0
# 온도_내부_min                  11.1
# 온도_내부_mean                 16.3
# 상대습도_내부_max                96.1
# 상대습도_내부_min                42.8
# 상대습도_내부_mean          78.858333
# 잔존CO2_max                 727.0
# 잔존CO2_min                 416.0
# 잔존CO2_mean           548.458333
# 토양온도_max                   27.0
# 토양온도_min                   10.5
# 토양온도_mean             16.008333
# Name: 512, dtype: object
# 42 7
# date            2020-10-25 0:00
# 온도_외부_max                  19.6
# 온도_외부_min                   3.3
# 온도_외부_mean            10.758333
# 온도_내부_max                  27.0
# 온도_내부_min                   9.6
# 온도_내부_mean              15.7625
# 상대습도_내부_max                96.5
# 상대습도_내부_min                56.5
# 상대습도_내부_mean          82.620833
# 잔존CO2_max                 715.0
# 잔존CO2_min                 400.0
# 잔존CO2_mean           538.333333
# 토양온도_max                   27.1
# 토양온도_min                    9.0
# 토양온도_mean             15.229167
# Name: 519, dtype: object
# 49 8
# date            2020-11-01 0:00
# 온도_외부_max                  13.6
# 온도_외부_min                  10.6
# 온도_외부_mean            12.091667
# 온도_내부_max                  20.3
# 온도_내부_min                  14.1
# 온도_내부_mean                15.55
# 상대습도_내부_max                96.4
# 상대습도_내부_min                85.2
# 상대습도_내부_mean            93.8625
# 잔존CO2_max                 769.0
# 잔존CO2_min                 476.0
# 잔존CO2_mean           631.291667
# 토양온도_max                   20.1
# 토양온도_min                   13.9
# 토양온도_mean             15.370833
# Name: 526, dtype: object
# 56 9
# date            2020-11-08 0:00
# 온도_외부_max                  15.8
# 온도_외부_min                   3.0
# 온도_외부_mean             8.308333
# 온도_내부_max                  24.7
# 온도_내부_min                  11.4
# 온도_내부_mean            15.495833
# 상대습도_내부_max                95.0
# 상대습도_내부_min                54.3
# 상대습도_내부_mean          83.345833
# 잔존CO2_max                 893.0
# 잔존CO2_min                 385.0
# 잔존CO2_mean                591.0
# 토양온도_max                   23.7
# 토양온도_min                   10.7
# 토양온도_mean             15.091667
# Name: 533, dtype: object
# 63 10
# date            2020-11-15 0:00
# 온도_외부_max                  19.1
# 온도_외부_min                   4.6
# 온도_외부_mean              10.2875
# 온도_내부_max                  26.2
# 온도_내부_min                  11.6
# 온도_내부_mean            16.595833
# 상대습도_내부_max                95.7
# 상대습도_내부_min                61.7
# 상대습도_내부_mean          87.145833
# 잔존CO2_max                 903.0
# 잔존CO2_min                 391.0
# 잔존CO2_mean           596.208333
# 토양온도_max                   25.8
# 토양온도_min                   11.8
# 토양온도_mean             16.558333
# Name: 540, dtype: object
# 70 11
# date            2020-11-22 0:00
# 온도_외부_max                  10.5
# 온도_외부_min                   4.1
# 온도_외부_mean               8.7375
# 온도_내부_max                  16.5
# 온도_내부_min                  11.1
# 온도_내부_mean                13.75
# 상대습도_내부_max                96.1
# 상대습도_내부_min                85.3
# 상대습도_내부_mean          93.108333
# 잔존CO2_max                 996.0
# 잔존CO2_min                 439.0
# 잔존CO2_mean              612.875
# 토양온도_max                   16.3
# 토양온도_min                   11.3
# 토양온도_mean                 13.75
# Name: 547, dtype: object
# 77 12
# date            2020-11-29 0:00
# 온도_외부_max                   5.6
# 온도_외부_min                   1.8
# 온도_외부_mean             3.270833
# 온도_내부_max                  19.1
# 온도_내부_min                   7.7
# 온도_내부_mean            12.245833
# 상대습도_내부_max                96.7
# 상대습도_내부_min                78.9
# 상대습도_내부_mean               92.4
# 잔존CO2_max                1031.0
# 잔존CO2_min                 387.0
# 잔존CO2_mean           569.541667
# 토양온도_max                   19.1
# 토양온도_min                    7.3
# 토양온도_mean             12.229167
# Name: 554, dtype: object
# 84 13
# date            2020-12-06 0:00
# 온도_외부_max                  10.0
# 온도_외부_min                  -2.6
# 온도_외부_mean             2.391667
# 온도_내부_max                  24.4
# 온도_내부_min                   8.4
# 온도_내부_mean               13.225
# 상대습도_내부_max                95.9
# 상대습도_내부_min                74.2
# 상대습도_내부_mean          90.266667
# 잔존CO2_max                 996.0
# 잔존CO2_min                 400.0
# 잔존CO2_mean           618.541667
# 토양온도_max                   24.2
# 토양온도_min                    8.3
# 토양온도_mean             13.254167
# Name: 561, dtype: object
# 91 14
# date            2020-12-13 0:00
# 온도_외부_max                   9.6
# 온도_외부_min                  -2.4
# 온도_외부_mean             2.129167
# 온도_내부_max                  17.3
# 온도_내부_min                   9.4
# 온도_내부_mean                 11.2
# 상대습도_내부_max                96.6
# 상대습도_내부_min                84.6
# 상대습도_내부_mean          93.891667
# 잔존CO2_max                1005.0
# 잔존CO2_min                 470.0
# 잔존CO2_mean               648.75
# 토양온도_max                   17.3
# 토양온도_min                    9.3
# 토양온도_mean             11.233333
# Name: 568, dtype: object
# 98 15
# date            2020-12-20 0:00
# 온도_외부_max                   3.3
# 온도_외부_min                  -7.5
# 온도_외부_mean              -2.1875
# 온도_내부_max                  26.1
# 온도_내부_min                   9.4
# 온도_내부_mean            13.345833
# 상대습도_내부_max                96.7
# 상대습도_내부_min                77.7
# 상대습도_내부_mean          90.233333
# 잔존CO2_max                 905.0
# 잔존CO2_min                 439.0
# 잔존CO2_mean              594.375
# 토양온도_max                   25.5
# 토양온도_min                    9.3
# 토양온도_mean             13.229167
# Name: 575, dtype: object
# 105 16
# date            2020-12-27 0:00
# 온도_외부_max                   7.0
# 온도_외부_min                  -1.3
# 온도_외부_mean             2.529167
# 온도_내부_max                  16.2
# 온도_내부_min                   9.2
# 온도_내부_mean            11.454167
# 상대습도_내부_max                95.9
# 상대습도_내부_min                89.0
# 상대습도_내부_mean          93.658333
# 잔존CO2_max                 905.0
# 잔존CO2_min                 532.0
# 잔존CO2_mean           646.708333
# 토양온도_max                   16.2
# 토양온도_min                    9.5
# 토양온도_mean             11.583333
# Name: 582, dtype: object
# 112 17
# date            2021-01-03 0:00
# 온도_외부_max                   0.7
# 온도_외부_min                  -6.7
# 온도_외부_mean                -3.05
# 온도_내부_max                  17.9
# 온도_내부_min                   9.1
# 온도_내부_mean            11.416667
# 상대습도_내부_max                96.3
# 상대습도_내부_min                84.3
# 상대습도_내부_mean          92.316667
# 잔존CO2_max                 908.0
# 잔존CO2_min                 359.0
# 잔존CO2_mean           562.083333
# 토양온도_max                   17.9
# 토양온도_min                    9.0
# 토양온도_mean               11.4375
# Name: 589, dtype: object
# 119 18
# date            2021-01-10 0:00
# 온도_외부_max                  -0.5
# 온도_외부_min                 -17.0
# 온도_외부_mean            -8.929167
# 온도_내부_max                  21.0
# 온도_내부_min                   8.5
# 온도_내부_mean              11.8625
# 상대습도_내부_max                94.9
# 상대습도_내부_min                83.2
# 상대습도_내부_mean          90.729167
# 잔존CO2_max                 911.0
# 잔존CO2_min                 444.0
# 잔존CO2_mean           585.958333
# 토양온도_max                   20.9
# 토양온도_min                    8.3
# 토양온도_mean             11.758333
# Name: 596, dtype: object
# 126 19
# date            2021-01-17 0:00
# 온도_외부_max                   1.4
# 온도_외부_min                  -7.2
# 온도_외부_mean            -2.504167
# 온도_내부_max                  24.5
# 온도_내부_min                   9.1
# 온도_내부_mean              13.8125
# 상대습도_내부_max                95.6
# 상대습도_내부_min                76.3
# 상대습도_내부_mean          90.516667
# 잔존CO2_max                 885.0
# 잔존CO2_min                 424.0
# 잔존CO2_mean              567.875
# 토양온도_max                   24.2
# 토양온도_min                    9.0
# 토양온도_mean             13.708333
# Name: 603, dtype: object
# 133 20
# date            2021-01-24 0:00
# 온도_외부_max                  13.7
# 온도_외부_min                   3.0
# 온도_외부_mean                7.675
# 온도_내부_max                  24.8
# 온도_내부_min                   9.6
# ...
# 잔존CO2_min                 355.0
# 잔존CO2_mean           409.791667
# 토양온도_max                   27.7
# 토양온도_min                   12.4
# 토양온도_mean             19.354167
# Name: 2773, dtype: object
# 154 23
# date            2020-11-05 0:00
# 온도_외부_max                  16.7
# 온도_외부_min                  -2.9
# 온도_외부_mean             6.645833
# 온도_내부_max                  26.9
# 온도_내부_min                   6.9
# 온도_내부_mean            15.695833
# 상대습도_내부_max                96.5
# 상대습도_내부_min                76.6
# 상대습도_내부_mean               89.8
# 잔존CO2_max                 993.0
# 잔존CO2_min                 350.0
# 잔존CO2_mean               490.25
# 토양온도_max                   24.4
# 토양온도_min                   11.8
# 토양온도_mean             17.679167
# Name: 2780, dtype: object
# 161 24
# date            2020-11-12 0:00
# 온도_외부_max                  19.4
# 온도_외부_min                  -1.1
# 온도_외부_mean             7.091667
# 온도_내부_max                  24.6
# 온도_내부_min                   7.9
# 온도_내부_mean              14.3625
# 상대습도_내부_max                95.8
# 상대습도_내부_min                76.3
# 상대습도_내부_mean          89.541667
# 잔존CO2_max                 893.0
# 잔존CO2_min                 337.0
# 잔존CO2_mean                504.5
# 토양온도_max                   22.4
# 토양온도_min                   12.2
# 토양온도_mean             16.720833
# Name: 2787, dtype: object
# 168 25
# date            2020-11-19 0:00
# 온도_외부_max                  22.3
# 온도_외부_min                  13.5
# 온도_외부_mean            19.383333
# 온도_내부_max                  24.4
# 온도_내부_min                  13.9
# 온도_내부_mean            19.641667
# 상대습도_내부_max               100.0
# 상대습도_내부_min                87.0
# 상대습도_내부_mean          95.245833
# 잔존CO2_max                 386.0
# 잔존CO2_min                 313.0
# 잔존CO2_mean           347.083333
# 토양온도_max                   22.5
# 토양온도_min                   17.7
# 토양온도_mean             20.029167
# Name: 2794, dtype: object
# 175 26
# date            2020-11-26 0:00
# 온도_외부_max                  13.5
# 온도_외부_min                   2.4
# 온도_외부_mean                 7.45
# 온도_내부_max                  21.9
# 온도_내부_min                   8.9
# 온도_내부_mean              13.4375
# 상대습도_내부_max               100.0
# 상대습도_내부_min                77.3
# 상대습도_내부_mean          95.304167
# 잔존CO2_max                1111.0
# 잔존CO2_min                 317.0
# 잔존CO2_mean           460.333333
# 토양온도_max                   20.1
# 토양온도_min                   12.3
# 토양온도_mean                15.225
# Name: 2801, dtype: object
# 182 27
# date            2020-12-03 0:00
# 온도_외부_max                   9.4
# 온도_외부_min                  -0.6
# 온도_외부_mean               4.9125
# 온도_내부_max                  20.9
# 온도_내부_min                   8.4
# 온도_내부_mean            13.520833
# 상대습도_내부_max               100.0
# 상대습도_내부_min                82.4
# 상대습도_내부_mean               95.9
# 잔존CO2_max                 993.0
# 잔존CO2_min                 287.0
# 잔존CO2_mean              476.625
# 토양온도_max                   19.0
# 토양온도_min                   11.7
# 토양온도_mean             14.995833
# Name: 2808, dtype: object
# 189 28
# date            2020-12-10 0:00
# 온도_외부_max                  12.3
# 온도_외부_min                  -1.0
# 온도_외부_mean               4.1625
# 온도_내부_max                  19.5
# 온도_내부_min                   9.0
# 온도_내부_mean            12.029167
# 상대습도_내부_max                94.7
# 상대습도_내부_min                53.1
# 상대습도_내부_mean          86.841667
# 잔존CO2_max                1132.0
# 잔존CO2_min                 303.0
# 잔존CO2_mean           563.291667
# 토양온도_max                   16.6
# 토양온도_min                   11.8
# 토양온도_mean             13.570833
# Name: 2815, dtype: object
# 196 29
# date            2020-12-17 0:00
# 온도_외부_max                   4.5
# 온도_외부_min                  -3.6
# 온도_외부_mean            -0.279167
# 온도_내부_max                  21.2
# 온도_내부_min                   7.4
# 온도_내부_mean            12.179167
# 상대습도_내부_max                91.0
# 상대습도_내부_min                56.9
# 상대습도_내부_mean          82.291667
# 잔존CO2_max                1283.0
# 잔존CO2_min                 319.0
# 잔존CO2_mean           530.909091
# 토양온도_max                   20.2
# 토양온도_min                   11.1
# 토양온도_mean             15.008333
# Name: 2822, dtype: object
# 203 30
# date            2020-12-24 0:00
# 온도_외부_max                  11.4
# 온도_외부_min                  -2.0
# 온도_외부_mean             3.716667
# 온도_내부_max                  20.8
# 온도_내부_min                   8.6
# 온도_내부_mean              12.9375
# 상대습도_내부_max                95.1
# 상대습도_내부_min                47.0
# 상대습도_내부_mean          83.995833
# 잔존CO2_max                1242.0
# 잔존CO2_min                 307.0
# 잔존CO2_mean                579.0
# 토양온도_max                   20.2
# 토양온도_min                   12.4
# 토양온도_mean                 15.85
# Name: 2829, dtype: object
# 210 31
# date            2020-12-31 0:00
# 온도_외부_max                   2.4
# 온도_외부_min                  -7.2
# 온도_외부_mean            -2.670833
# 온도_내부_max                  23.9
# 온도_내부_min                   7.5
# 온도_내부_mean            13.333333
# 상대습도_내부_max                94.3
# 상대습도_내부_min                58.8
# 상대습도_내부_mean          82.729167
# 잔존CO2_max                1311.0
# 잔존CO2_min                 338.0
# 잔존CO2_mean           659.208333
# 토양온도_max                   22.1
# 토양온도_min                   11.5
# 토양온도_mean                16.075
# Name: 2836, dtype: object
# 217 32
# date            2021-01-07 0:00
# 온도_외부_max                  -1.9
# 온도_외부_min                 -13.5
# 온도_외부_mean            -6.891667
# 온도_내부_max                  22.3
# 온도_내부_min                   8.2
# 온도_내부_mean            11.891667
# 상대습도_내부_max                97.0
# 상대습도_내부_min                63.2
# 상대습도_내부_mean             86.125
# 잔존CO2_max                1334.0
# 잔존CO2_min                 484.0
# 잔존CO2_mean           710.318182
# 토양온도_max                   21.4
# 토양온도_min                   12.2
# 토양온도_mean               15.5375
# Name: 2843, dtype: object
# 224 33
# date            2021-01-14 0:00
# 온도_외부_max                  13.0
# 온도_외부_min                  -5.0
# 온도_외부_mean             2.283333
# 온도_내부_max                  25.5
# 온도_내부_min                   8.1
# 온도_내부_mean            14.820833
# 상대습도_내부_max                95.2
# 상대습도_내부_min                50.0
# 상대습도_내부_mean             83.725
# 잔존CO2_max                1373.0
# 잔존CO2_min                 364.0
# 잔존CO2_mean           760.263158
# 토양온도_max                   23.6
# 토양온도_min                   12.6
# 토양온도_mean             17.520833
# Name: 2850, dtype: object
# 231 34
# date            2021-01-21 0:00
# 온도_외부_max                  12.3
# 온도_외부_min                  -5.9
# 온도_외부_mean             2.695833
# 온도_내부_max                  25.2
# 온도_내부_min                   8.1
# 온도_내부_mean            14.533333
# 상대습도_내부_max                96.5
# 상대습도_내부_min                76.3
# 상대습도_내부_mean          91.270833
# 잔존CO2_max                1188.0
# 잔존CO2_min                 443.0
# 잔존CO2_mean           764.947368
# 토양온도_max                   21.9
# 토양온도_min                   12.9
# 토양온도_mean             17.116667
# Name: 2857, dtype: object
# 238 35
# date            2021-01-28 0:00
# 온도_외부_max                  10.5
# 온도_외부_min                  -3.3
# 온도_외부_mean                0.975
# 온도_내부_max                  26.3
# 온도_내부_min                   9.8
# 온도_내부_mean            14.391667
# 상대습도_내부_max                93.8
# 상대습도_내부_min                44.6
# 상대습도_내부_mean               83.9
# 잔존CO2_max                1371.0
# 잔존CO2_min                 361.0
# 잔존CO2_mean                672.5
# 토양온도_max                   22.6
# 토양온도_min                   14.6
# 토양온도_mean             18.229167
# Name: 2864, dtype: object
# 245 36
# date            2021-02-04 0:00
# 온도_외부_max                   7.8
# 온도_외부_min                  -2.8
# 온도_외부_mean                2.725
# 온도_내부_max                  26.2
# 온도_내부_min                  10.3
# 온도_내부_mean              15.8125
# 상대습도_내부_max                95.9
# 상대습도_내부_min                45.0
# 상대습도_내부_mean          81.416667
# 잔존CO2_max                1096.0
# 잔존CO2_min                 358.0
# 잔존CO2_mean           684.521739
# 토양온도_max                   24.7
# 토양온도_min                   14.3
# 토양온도_mean             18.816667
# Name: 2871, dtype: object
# 252 37
# date            2021-02-11 0:00
# 온도_외부_max                  12.4
# 온도_외부_min                  -2.4
# 온도_외부_mean             4.233333
# 온도_내부_max                  22.0
# 온도_내부_min                   9.1
# 온도_내부_mean                13.75
# 상대습도_내부_max                98.9
# 상대습도_내부_min                47.9
# 상대습도_내부_mean          82.470833
# 잔존CO2_max                1312.0
# 잔존CO2_min                 332.0
# 잔존CO2_mean           635.782609
# 토양온도_max                   19.3
# 토양온도_min                   13.9
# 토양온도_mean             16.895833
# Name: 2878, dtype: object
# 259 38
# date            2021-02-18 0:00
# 온도_외부_max                   1.0
# 온도_외부_min                  -5.9
# 온도_외부_mean            -2.695833
# 온도_내부_max                  26.1
# 온도_내부_min                   8.4
# 온도_내부_mean                14.75
# 상대습도_내부_max                98.7
# 상대습도_내부_min                75.6
# 상대습도_내부_mean               91.3
# 잔존CO2_max                 802.0
# 잔존CO2_min                 325.0
# 잔존CO2_mean           539.166667
# 토양온도_max                   24.3
# 토양온도_min                   13.6
# 토양온도_mean             18.191667
# Name: 2885, dtype: object
# 266 39
# date            2021-02-25 0:00
# 온도_외부_max                   8.3
# 온도_외부_min                  -1.9
# 온도_외부_mean             3.558333
# 온도_내부_max                  18.3
# 온도_내부_min                   7.9
# 온도_내부_mean            11.441667
# 상대습도_내부_max                94.5
# 상대습도_내부_min                78.8
# 상대습도_내부_mean          86.733333
# 잔존CO2_max                1233.0
# 잔존CO2_min                 300.0
# 잔존CO2_mean           696.894737
# 토양온도_max                   17.9
# 토양온도_min                   13.0
# 토양온도_mean               15.5375
# Name: 2892, dtype: object
# 273 40
# date            2021-03-04 0:00
# 온도_외부_max                   9.2
# 온도_외부_min                   0.6
# 온도_외부_mean               4.8625
# 온도_내부_max                  18.8
# 온도_내부_min                   9.2
# 온도_내부_mean              12.0125
# 상대습도_내부_max                96.7
# 상대습도_내부_min                84.8
# 상대습도_내부_mean          93.045833
# 잔존CO2_max                1182.0
# 잔존CO2_min                 306.0
# 잔존CO2_mean           640.428571
# 토양온도_max                   18.5
# 토양온도_min                   14.2
# 토양온도_mean             16.045833
# Name: 2899, dtype: object
# 280 41
# date            2021-03-11 0:00
# 온도_외부_max                  17.4
# 온도_외부_min                   0.5
# 온도_외부_mean               8.5625
# 온도_내부_max                  25.3
# 온도_내부_min                   8.8
# 온도_내부_mean            15.258333
# 상대습도_내부_max                98.6
# 상대습도_내부_min                36.6
# 상대습도_내부_mean            76.3625
# 잔존CO2_max                 716.0
# 잔존CO2_min                 336.0
# 잔존CO2_mean               514.75
# 토양온도_max                   22.7
# 토양온도_min                   13.4
# 토양온도_mean                17.625
# Name: 2906, dtype: object
# 287 42
# date            2021-03-18 0:00
# 온도_외부_max                  19.2
# 온도_외부_min                   2.2
# 온도_외부_mean            10.554167
# 온도_내부_max                  24.8
# 온도_내부_min                   9.7
# 온도_내부_mean            15.833333
# 상대습도_내부_max                91.4
# 상대습도_내부_min                44.1
# 상대습도_내부_mean          72.741667
# 잔존CO2_max                 606.0
# 잔존CO2_min                 336.0
# 잔존CO2_mean               440.25
# 토양온도_max                   25.3
# 토양온도_min                   13.4
# 토양온도_mean             18.429167
# Name: 2913, dtype: object
# 294 43
# date            2021-03-25 0:00
# 온도_외부_max                  21.8
# 온도_외부_min                   1.6
# 온도_외부_mean              11.4625
# 온도_내부_max                  26.9
# 온도_내부_min                   9.2
# 온도_내부_mean            16.433333
# 상대습도_내부_max                98.1
# 상대습도_내부_min                36.4
# 상대습도_내부_mean              77.35
# 잔존CO2_max                 543.0
# 잔존CO2_min                 346.0
# 잔존CO2_mean               429.75
# 토양온도_max                   23.6
# 토양온도_min                   12.6
# 토양온도_mean             17.429167
# Name: 2920, dtype: object
# 301 44
# date            2021-04-01 0:00
# 온도_외부_max                  19.9
# 온도_외부_min                   5.7
# 온도_외부_mean            13.266667
# 온도_내부_max                  23.9
# 온도_내부_min                   8.3
# 온도_내부_mean            15.720833
# 상대습도_내부_max                94.1
# 상대습도_내부_min                43.9
# 상대습도_내부_mean              67.15
# 잔존CO2_max                 417.0
# 잔존CO2_min                 320.0
# 잔존CO2_mean           364.333333
# 토양온도_max                   20.7
# 토양온도_min                   12.9
# 토양온도_mean               16.9875
# Name: 2927, dtype: object
# 308 45
# date            2021-04-08 0:00
# 온도_외부_max                  21.3
# 온도_외부_min                   5.7
# 온도_외부_mean                 13.2
# 온도_내부_max                  25.8
# 온도_내부_min                   7.0
# 온도_내부_mean            15.483333
# 상대습도_내부_max                93.4
# 상대습도_내부_min                33.5
# 상대습도_내부_mean               65.6
# 잔존CO2_max                 373.0
# 잔존CO2_min                 313.0
# 잔존CO2_mean           345.333333
# 토양온도_max                   24.4
# 토양온도_min                   11.9
# 토양온도_mean             17.595833
# Name: 2934, dtype: object
# 315 46
# date            2021-04-15 0:00
# 온도_외부_max                  17.9
# 온도_외부_min                   0.7
# 온도_외부_mean             9.858333
# 온도_내부_max                  24.1
# 온도_내부_min                   5.0
# 온도_내부_mean            14.179167
# 상대습도_내부_max               100.0
# 상대습도_내부_min                80.1
# 상대습도_내부_mean          97.241667
# 잔존CO2_max                 413.0
# 잔존CO2_min                 322.0
# 잔존CO2_mean           375.416667
# 토양온도_max                   20.2
# 토양온도_min                   11.2
# 토양온도_mean             16.016667
# Name: 2941, dtype: object
# 322 47
# date            2021-04-22 0:00
# 온도_외부_max                  24.7
# 온도_외부_min                  11.6
# 온도_외부_mean            17.883333
# 온도_내부_max                  29.4
# 온도_내부_min                  13.1
# 온도_내부_mean            19.220833
# 상대습도_내부_max                91.5
# 상대습도_내부_min                39.1
# 상대습도_내부_mean          70.379167
# 잔존CO2_max                 423.0
# 잔존CO2_min                 340.0
# 잔존CO2_mean              378.875
# 토양온도_max                   22.1
# 토양온도_min                   16.3
# 토양온도_mean             19.395833
# Name: 2948, dtype: object
# 329 48
# date            2021-04-29 0:00
# 온도_외부_max                  23.5
# 온도_외부_min                  10.7
# 온도_외부_mean            16.195833
# 온도_내부_max                  28.7
# 온도_내부_min                  11.0
# 온도_내부_mean              17.8625
# 상대습도_내부_max                88.5
# 상대습도_내부_min                32.3
# 상대습도_내부_mean          64.041667
# 잔존CO2_max                 370.0
# 잔존CO2_min                 326.0
# 잔존CO2_mean           348.458333
# 토양온도_max                   23.8
# 토양온도_min                   14.8
# 토양온도_mean             18.883333
# Name: 2955, dtype: object
# 336 49
# date            2021-05-06 0:00
# 온도_외부_max                  21.2
# 온도_외부_min                   2.7
# 온도_외부_mean              12.8375
# 온도_내부_max                  26.6
# 온도_내부_min                   4.3
# 온도_내부_mean            15.863636
# 상대습도_내부_max                93.7
# 상대습도_내부_min                41.9
# 상대습도_내부_mean          70.558333
# 잔존CO2_max                 379.0
# 잔존CO2_min                 270.0
# 잔존CO2_mean                329.5
# 토양온도_max                   19.3
# 토양온도_min                   10.7
# 토양온도_mean               15.7125
# Name: 2962, dtype: object
# 343 50
# date            2021-05-13 0:00
# 온도_외부_max                  30.4
# 온도_외부_min                  11.0
# 온도_외부_mean               20.075
# 온도_내부_max                  34.2
# 온도_내부_min                  11.6
# 온도_내부_mean                 22.0
# 상대습도_내부_max                96.0
# 상대습도_내부_min                46.3
# 상대습도_내부_mean               74.8
# 잔존CO2_max                 410.0
# 잔존CO2_min                 335.0
# 잔존CO2_mean           362.208333
# 토양온도_max                   26.4
# 토양온도_min                   16.4
# 토양온도_mean                 21.35
# Name: 2969, dtype: object
# 350 51
# date            2021-05-20 0:00
# 온도_외부_max                  16.7
# 온도_외부_min                  15.3
# 온도_외부_mean            15.966667
# 온도_내부_max                  21.6
# 온도_내부_min                  16.3
# 온도_내부_mean            18.245833
# 상대습도_내부_max                98.9
# 상대습도_내부_min                85.4
# 상대습도_내부_mean          93.758333
# 잔존CO2_max                 431.0
# 잔존CO2_min                 327.0
# 잔존CO2_mean           374.458333
# 토양온도_max                   23.0
# 토양온도_min                   19.2
# 토양온도_mean               20.3375
# Name: 2976, dtype: object

# %%
date_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2983 entries, 0 to 2982
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   농가명           2983 non-null   int64
#  1   date          2983 non-null   object
#  2   온도_외부_max     2852 non-null   float64
#  3   온도_외부_min     2852 non-null   float64
#  4   온도_외부_mean    2852 non-null   float64
#  5   온도_내부_max     2809 non-null   float64
#  6   온도_내부_min     2809 non-null   float64
#  7   온도_내부_mean    2809 non-null   float64
#  8   상대습도_내부_max   2821 non-null   float64
#  9   상대습도_내부_min   2821 non-null   float64
#  10  상대습도_내부_mean  2821 non-null   float64
#  11  잔존CO2_max     2823 non-null   float64
#  12  잔존CO2_min     2823 non-null   float64
#  13  잔존CO2_mean    2823 non-null   float64
#  14  토양온도_max      2656 non-null   float64
#  15  토양온도_min      2656 non-null   float64
#  16  토양온도_mean     2656 non-null   float64
# dtypes: float64(15), int64(1), object(1)
# memory usage: 396.3+ KB

# %%
date_df
# Out:
#       농가명             date  온도_외부_max  온도_외부_min  온도_외부_mean  온도_내부_max  \
# 0      11  2020-09-15 0:00       29.2       16.6   22.754167       29.4
# 1      11  2020-09-16 0:00       23.9       19.5   21.545833       25.7
# 2      11  2020-09-17 0:00       24.4       19.6   21.766667       26.8
# 3      11  2020-09-18 0:00       26.1       14.1   20.475000       26.4
# 4      11  2020-09-19 0:00       26.0       12.5   18.462500       28.9
# ...   ...              ...        ...        ...         ...        ...
# 2978   52  2021-05-22 0:00       28.4       12.4   20.812500       33.4
# 2979   52  2021-05-23 0:00       29.1       12.5   21.133333       35.2
# 2980   52  2021-05-24 0:00       27.6       17.8   21.554167       31.7
# 2981   52  2021-05-25 0:00       25.1       11.1   17.362500       31.0
# 2982   52  2021-05-26 0:00       19.6       10.3   13.083333       23.4
#
#       온도_내부_min  온도_내부_mean  상대습도_내부_max  상대습도_내부_min  상대습도_내부_mean  \
# 0          18.0   23.170833         99.0         42.0     75.791667
# 1          20.6   22.762500         99.0         60.0     82.333333
# 2          20.4   22.812500        100.0         67.0     88.166667
# 3          15.9   21.020833         99.0         35.0     69.583333
# 4          14.3   20.529167         92.0         31.0     63.916667
# ...         ...         ...          ...          ...           ...
# 2978       12.9   22.583333         93.6         43.0     69.562500
# 2979       12.9   23.129167         97.8         44.7     74.166667
# 2980       17.8   23.470833         96.3         44.2     72.375000
# 2981       11.7   19.391667         92.5         40.5     67.341667
# 2982       12.3   15.383333         91.6         53.9     79.916667
#
#       잔존CO2_max  잔존CO2_min  잔존CO2_mean  토양온도_max  토양온도_min  토양온도_mean
# 0         841.0      458.0  533.608696       NaN       NaN        NaN
# 1         738.0      470.0  540.565217       NaN       NaN        NaN
# 2         573.0      466.0  518.238095       NaN       NaN        NaN
# 3         561.0      551.0  556.000000       NaN       NaN        NaN
# 4           NaN        NaN         NaN       NaN       NaN        NaN
# ...         ...        ...         ...       ...       ...        ...
# 2978      387.0      323.0  352.000000      27.6      16.4  21.658333
# 2979      446.0      356.0  389.500000      26.5      17.9  22.358333
# 2980      479.0      350.0  400.250000      25.8      20.9  23.137500
# 2981      367.0      334.0  350.250000      24.1      16.7  20.595833
# 2982      376.0      330.0  345.833333      19.1      15.5  16.858333
#
# [2983 rows x 17 columns]

# %% [markdown]
# ### 최종

# %%
import pandas as pd

# 데이터
df = pd.read_csv("2020/환경데이터_스무딩_완료.csv", encoding="ANSI")

# %%
df
# Out:
#                realTime  name  do city item  cul_time      Measure_time  \
# 0        2020.9.15 0:00    11  충남   부여   딸기         1    2020.9.15 0:00
# 1        2020.9.15 1:00    11  충남   부여   딸기         1    2020.9.15 1:00
# 2        2020.9.15 2:00    11  충남   부여   딸기         1    2020.9.15 2:00
# 3        2020.9.15 3:00    11  충남   부여   딸기         1    2020.9.15 3:00
# 4        2020.9.15 4:00    11  충남   부여   딸기         1    2020.9.15 4:00
# ...                 ...   ...  ..  ...  ...       ...               ...
# 71523   2021-05-26 7:00    52  경남   산청   딸기         1   2021-05-26 7:00
# 71524   2021-05-26 8:00    52  경남   산청   딸기         1   2021-05-26 8:00
# 71525   2021-05-26 9:00    52  경남   산청   딸기         1   2021-05-26 9:00
# 71526  2021-05-26 10:00    52  경남   산청   딸기         1  2021-05-26 10:00
# 71527  2021-05-26 11:00    52  경남   산청   딸기         1  2021-05-26 11:00
#
#        temp_ex  s_am  as_am  temp_int  hum_int    CO2         st
# 0         18.1  0.00   0.00      19.8     92.0  549.0  15.831841
# 1         18.2  0.00   0.00      19.6     93.0  520.0  15.831841
# 2         18.2  0.00   0.00      19.9     95.0  540.0  15.831841
# 3         18.4  0.00   0.00      20.0     96.0  531.0  15.831841
# 4         18.0  0.00   0.00      19.6     96.0  632.0  15.831841
# ...        ...   ...    ...       ...      ...    ...        ...
# 71523     12.7  0.00   0.00      14.2     81.5  333.0  15.500000
# 71524     13.4  0.00   0.00      17.6     76.6  346.0  15.600000
# 71525     16.3  0.00   0.00      18.9     64.5  355.0  16.000000
# 71526     18.2  1.51   1.51      22.2     55.6  352.0  16.600000
# 71527     19.6  1.70   3.21      23.4     53.9  376.0  17.600000
#
# [71528 rows x 14 columns]

# %%
# 일사량, 누적 일사량 나누기 100

df["s_am"] = df["s_am"]/100
df["as_am"] = df["as_am"]/100

# %% [markdown]
# #### a case

# %%
## 일별

# import pandas as pd

# 데이터
# df = pd.read_csv("2020/환경데이터_최종.csv", encoding="ANSI")

# 선정한 변수
cols = ["realTime", "temp_ex", "s_am", "temp_int", "hum_int", "CO2", "st"]


# 일별 데이터 저장할 딕셔너리
data = {"id":[], "date":[],
        "temp_ex_max":[], "temp_ex_min":[], "temp_ex_mean":[],
        's_am_max':[], 's_am_min':[], 's_am_mean':[],
        "temp_int_max":[], "temp_int_min":[], "temp_int_mean":[],
        "hum_int_max":[], "hum_int_min":[], "hum_int_mean":[],
        "CO2_max":[], "CO2_min":[], "CO2_mean":[],
        "st_max":[], "st_min":[], "st_mean":[]}

# 농가 id
farm_id = df["name"].unique()

# 농가 별
for f in farm_id :
    farm_df = df[df["name"]==f][cols]

    # 일 별로
    for i in range(0, farm_df.shape[0], 24) :
        sub_df = farm_df.iloc[i : i + 24]
        date = sub_df["realTime"].tolist()[0]

        # 데이터 추가
        data[f"id"].append(f)
        data[f"date"].append(date)
        # data[f"week_start_date"].append(sub_df.iloc[0]["realTime"])

        # 변수 별
        for c in cols[1:] : # realTime 제외
            data[f"{c}_max"].append(sub_df[c].max())
            if c == "s_am" :
                print(f, date)
                data[f"{c}_min"].append(sorted(sub_df[c].unique())[1])
            else : 
                data[f"{c}_min"].append(sub_df[c].min())
            data[f"{c}_mean"].append(sub_df[c].mean())


date_df = pd.DataFrame.from_dict(data=data, orient='columns')
date_df.to_csv("2020/환경데이터_최최종_일별_a.csv", encoding="ANSI", index=False)
# Out:
# 11 2020.9.15 0:00
# 11 2020.9.16 0:00
# 11 2020.9.17 0:00
# 20 2020.10.22 0:00
# 20 2020.10.23 0:00
# 20 2020.10.24 0:00
# 20 2020.10.25 0:00
# 20 2020.10.26 0:00
# 20 2020.10.27 0:00
# 20 2020.10.28 0:00
# 20 2020.10.29 0:00
# 20 2020.10.30 0:00
# 20 2020.10.31 0:00
# 20 2020.11.1 0:00
# 20 2020.11.2 0:00
# 20 2020.11.3 0:00
# 20 2020.11.4 0:00
# 20 2020.11.5 0:00
# 20 2020.11.6 0:00
# 20 2020.11.7 0:00
# 20 2020.11.8 0:00
# 20 2020.11.9 0:00
# 20 2020.11.10 0:00
# 20 2020.11.11 0:00
# 20 2020.11.12 0:00
# 20 2020.11.13 0:00
# 20 2020.11.14 0:00
# 20 2020.11.15 0:00
# 20 2020.11.16 0:00
# 20 2020.11.17 0:00
# 20 2020.11.18 0:00
# 20 2020.11.19 0:00
# 20 2020.11.20 0:00
# 20 2020.11.21 0:00
# 20 2020.11.22 0:00
# 20 2020.11.23 0:00
# 20 2020.11.24 0:00
# 20 2020.11.25 0:00
# 20 2020.11.26 0:00
# 20 2020.11.27 0:00
# 20 2020.11.28 0:00
# 20 2020.11.29 0:00
# 20 2020.11.30 0:00
# 20 2020.12.1 0:00
# 20 2020.12.2 0:00
# 20 2020.12.3 0:00
# 20 2020.12.4 0:00
# 20 2020.12.5 0:00
# 20 2020.12.6 0:00
# 20 2020.12.7 0:00
# 20 2020.12.8 0:00
# 20 2020.12.9 0:00
# 20 2020.12.10 0:00
# 20 2020.12.11 0:00
# 20 2020.12.12 0:00
# 20 2020.12.13 0:00
# 20 2020.12.14 0:00
# 20 2020.12.15 0:00
# 20 2020.12.16 0:00
# 20 2020.12.17 0:00
# 20 2020.12.18 0:00
# 20 2020.12.19 0:00
# 20 2020.12.20 0:00
# 20 2020.12.21 0:00
# 20 2020.12.22 0:00
# 20 2020.12.23 0:00
# 20 2020.12.24 0:00
# 20 2020.12.25 0:00
# 20 2020.12.26 0:00
# 20 2020.12.27 0:00
# 20 2020.12.28 0:00
# 20 2020.12.29 0:00
# 20 2020.12.30 0:00
# 20 2020.12.31 0:00
# 20 2021.1.1 0:00
# 20 2021.1.2 0:00
# 20 2021.1.3 0:00
# 20 2021.1.4 0:00
# 20 2021.1.5 0:00
# 20 2021.1.6 0:00
# 20 2021.1.7 0:00
# 20 2021.1.8 0:00
# 20 2021.1.9 0:00
# 20 2021.1.10 0:00
# 20 2021.1.11 0:00
# 20 2021.1.12 0:00
# 20 2021.1.13 0:00
# 20 2021.1.14 0:00
# 20 2021.1.15 0:00
# 20 2021.1.16 0:00
# 20 2021.1.17 0:00
# 20 2021.1.18 0:00
# 20 2021.1.19 0:00
# 20 2021.1.20 0:00
# 20 2021.1.21 0:00
# 20 2021.1.22 0:00
# 20 2021.1.23 0:00
# 20 2021.1.24 0:00
# 20 2021.1.25 0:00
# 20 2021.1.26 0:00
# 20 2021.1.27 0:00
# 20 2021.1.28 0:00
# 20 2021.1.29 0:00
# 20 2021.1.30 0:00
# 20 2021.1.31 0:00
# 20 2021.2.1 0:00
# 52 2021-05-25 0:00
# 52 2021-05-26 0:00

# %%
## 주별

import pandas as pd

# 데이터
df = pd.read_csv("2020/환경데이터_최최종_일별_a.csv", encoding="ANSI")

# 변수
cols = ["date", 
        'temp_ex_max', 'temp_ex_min', 'temp_ex_mean', 
        's_am_max', 's_am_min', 's_am_mean', 
        'temp_int_max', 'temp_int_min', 'temp_int_mean', 
        'hum_int_max', 'hum_int_min', 'hum_int_mean',
        'CO2_max', 'CO2_min', 'CO2_mean', 
        'st_max', 'st_min', 'st_mean']

# 주별 데이터 저장할 딕셔너리
data = {"id":[], "week":[], "week_start_date":[],
        "temp_ex_max":[], "temp_ex_min":[], "temp_ex_mean":[],
        's_am_max':[], 's_am_min':[], 's_am_mean':[], 
        "temp_int_max":[], "temp_int_min":[], "temp_int_mean":[],
        "hum_int_max":[], "hum_int_min":[], "hum_int_mean":[],
        "CO2_max":[], "CO2_min":[], "CO2_mean":[],
        "st_max":[], "st_min":[], "st_mean":[]}


# 농가 id
farm_id = df["id"].unique()

# 농가 별
for f in farm_id :
    farm_df = df[df["id"]==f][cols]
    week = 1

    # 주차 별
    for i in range(0, farm_df.shape[0], 7) :
        # 확인용 출력
        print(i, week)
        print(farm_df.iloc[i])
        # print(farm_df.iloc[i + 24 * 6 + 23])

        sub_df = farm_df.iloc[i : i + 7]

        # 데이터 추가
        data[f"id"].append(f)
        data[f"week"].append(week)
        data[f"week_start_date"].append(sub_df.iloc[0]["date"])

        # 변수 별
        for c in cols[1:] : # realTime 제외
            data[c].append(sub_df[c].mean())
    
        week += 1

week_df = pd.DataFrame.from_dict(data=data, orient='columns')
week_df.to_csv("2020/환경데이터_최최종_주별_a.csv", encoding="ANSI", index=False)
# Out:
# 0 1
# date             2020.9.15 0:00
# temp_ex_max                29.2
# temp_ex_min                16.6
# temp_ex_mean          22.754167
# s_am_max                   2.53
# s_am_min                   0.03
# s_am_mean                 0.725
# temp_int_max               29.4
# temp_int_min               18.0
# temp_int_mean         23.170833
# hum_int_max                99.0
# hum_int_min                42.0
# hum_int_mean          75.791667
# CO2_max                   841.0
# CO2_min                   458.0
# CO2_mean               534.3125
# st_max                15.831841
# st_min                15.831841
# st_mean               15.831841
# Name: 0, dtype: object
# 7 2
# date             2020.9.22 0:00
# temp_ex_max                25.0
# temp_ex_min                12.4
# temp_ex_mean          18.316667
# s_am_max                   2.85
# s_am_min                   0.02
# s_am_mean              0.754167
# temp_int_max               20.8
# temp_int_min               19.2
# temp_int_mean          19.79678
# hum_int_max                85.0
# hum_int_min                26.0
# hum_int_mean              61.25
# CO2_max                   695.0
# CO2_min                   453.0
# CO2_mean                 554.75
# st_max                15.831841
# st_min                15.831841
# st_mean               15.831841
# Name: 7, dtype: object
# 14 3
# date             2020.9.29 0:00
# temp_ex_max                26.3
# temp_ex_min                10.2
# temp_ex_mean            17.7875
# s_am_max                   2.41
# s_am_min                   0.04
# s_am_mean              0.588333
# temp_int_max          25.387067
# temp_int_min          24.967436
# temp_int_mean         25.177252
# hum_int_max                81.0
# hum_int_min                 3.0
# hum_int_mean             50.625
# CO2_max                   913.0
# CO2_min                   435.0
# CO2_mean                  573.5
# st_max                15.831841
# st_min                15.831841
# st_mean               15.831841
# Name: 14, dtype: object
# 21 4
# date             2020.10.6 0:00
# temp_ex_max                21.3
# temp_ex_min                 6.0
# temp_ex_mean          13.754167
# s_am_max                    2.7
# s_am_min                   0.01
# s_am_mean              0.789583
# temp_int_max           22.32194
# temp_int_min          21.902309
# temp_int_mean         22.112125
# hum_int_max                83.0
# hum_int_min                17.0
# hum_int_mean          52.333333
# CO2_max                  1357.0
# CO2_min                   446.0
# CO2_mean             607.708333
# st_max                15.831841
# st_min                15.831841
# st_mean               15.831841
# Name: 21, dtype: object
# 28 5
# date             2020.10.13 0:00
# temp_ex_max                 18.8
# temp_ex_min                  5.9
# temp_ex_mean           11.758333
# s_am_max                    1.82
# s_am_min                    0.09
# s_am_mean               0.501667
# temp_int_max           19.256813
# temp_int_min           18.837182
# temp_int_mean          19.046998
# hum_int_max                 88.0
# hum_int_min                 22.0
# hum_int_mean           61.208333
# CO2_max                    612.0
# CO2_min                    435.0
# CO2_mean              518.020833
# st_max                 15.831841
# st_min                 15.831841
# st_mean                15.831841
# Name: 28, dtype: object
# 35 6
# date             2020.10.20 0:00
# temp_ex_max                 23.2
# temp_ex_min                  4.6
# temp_ex_mean           12.204167
# s_am_max                    2.49
# s_am_min                    0.06
# s_am_mean               0.570417
# temp_int_max                28.1
# temp_int_min                11.7
# temp_int_mean              17.65
# hum_int_max                 82.0
# hum_int_min                 16.0
# hum_int_mean           57.291667
# CO2_max                   1321.0
# CO2_min                    465.0
# CO2_mean                632.4375
# st_max                 15.831841
# st_min                 15.831841
# st_mean                15.831841
# Name: 35, dtype: object
# 42 7
# date             2020.10.27 0:00
# temp_ex_max                 22.2
# temp_ex_min                  3.5
# temp_ex_mean              11.675
# s_am_max                    2.15
# s_am_min                    0.04
# s_am_mean               0.525417
# temp_int_max                25.8
# temp_int_min                12.3
# temp_int_mean          17.358333
# hum_int_max                 82.0
# hum_int_min                 21.0
# hum_int_mean           61.708333
# CO2_max                   1155.0
# CO2_min                    448.0
# CO2_mean                681.1875
# st_max                 15.831841
# st_min                 15.831841
# st_mean                15.831841
# Name: 42, dtype: object
# 49 8
# date             2020.11.3 0:00
# temp_ex_max                12.3
# temp_ex_min                -0.1
# temp_ex_mean             6.6625
# s_am_max                   1.73
# s_am_min                   0.02
# s_am_mean              0.434583
# temp_int_max               25.1
# temp_int_min               13.0
# temp_int_mean         17.054167
# hum_int_max                79.0
# hum_int_min                22.0
# hum_int_mean          60.041667
# CO2_max                  1396.0
# CO2_min                   361.0
# CO2_mean             589.333333
# st_max                15.831841
# st_min                15.831841
# st_mean               15.831841
# Name: 49, dtype: object
# 56 9
# date             2020.11.10 0:00
# temp_ex_max                 14.9
# temp_ex_min                  0.3
# temp_ex_mean              7.2375
# s_am_max                    2.26
# s_am_min                    0.01
# s_am_mean               0.562083
# temp_int_max                23.8
# temp_int_min                10.4
# temp_int_mean            15.8125
# hum_int_max                 86.0
# hum_int_min                 21.0
# hum_int_mean           62.416667
# CO2_max                   1297.0
# CO2_min                    380.0
# CO2_mean                   568.5
# st_max                      19.4
# st_min                      12.8
# st_mean                    16.15
# Name: 56, dtype: object
# 63 10
# date             2020.11.17 0:00
# temp_ex_max                 20.3
# temp_ex_min                  5.7
# temp_ex_mean               13.25
# s_am_max                    1.32
# s_am_min                    0.06
# s_am_mean               0.206667
# temp_int_max                23.6
# temp_int_min                13.8
# temp_int_mean          17.491667
# hum_int_max                100.0
# hum_int_min                 48.0
# hum_int_mean               86.75
# CO2_max                    797.0
# CO2_min                    395.0
# CO2_mean              591.979167
# st_max                      19.5
# st_min                      16.7
# st_mean                18.279167
# Name: 63, dtype: object
# 70 11
# date             2020.11.24 0:00
# temp_ex_max                 11.2
# temp_ex_min                 -0.3
# temp_ex_mean            4.883333
# s_am_max                    1.45
# s_am_min                    0.17
# s_am_mean               0.348333
# temp_int_max                25.0
# temp_int_min                12.0
# temp_int_mean              16.25
# hum_int_max                 94.0
# hum_int_min                 34.0
# hum_int_mean           76.791667
# CO2_max                   1392.0
# CO2_min                    349.0
# CO2_mean                749.4375
# st_max                      21.7
# st_min                      17.1
# st_mean                  18.9875
# Name: 70, dtype: object
# 77 12
# date             2020.12.1 0:00
# temp_ex_max                 8.3
# temp_ex_min                -5.7
# temp_ex_mean              0.775
# s_am_max                   1.95
# s_am_min                   0.01
# s_am_mean              0.479583
# temp_int_max               24.8
# temp_int_min                9.6
# temp_int_mean           14.5125
# hum_int_max                85.0
# hum_int_min                31.0
# hum_int_mean          71.916667
# CO2_max                  1382.0
# CO2_min                   286.0
# CO2_mean             736.583333
# st_max                     21.4
# st_min                     15.9
# st_mean                  18.325
# Name: 77, dtype: object
# 84 13
# date             2020.12.8 0:00
# temp_ex_max                 6.3
# temp_ex_min                -5.0
# temp_ex_mean           0.079167
# s_am_max                   1.91
# s_am_min                   0.01
# s_am_mean              0.440417
# temp_int_max               24.3
# temp_int_min                9.4
# temp_int_mean         13.304167
# hum_int_max                93.0
# hum_int_min                23.0
# hum_int_mean          71.666667
# CO2_max                  1360.0
# CO2_min                   345.0
# CO2_mean             764.833333
# st_max                     19.2
# st_min                     15.7
# st_mean               17.483333
# Name: 84, dtype: object
# 91 14
# date             2020.12.15 0:00
# temp_ex_max                  0.0
# temp_ex_min                -11.0
# temp_ex_mean           -5.820833
# s_am_max                    1.91
# s_am_min                     0.3
# s_am_mean               0.433333
# temp_int_max                22.3
# temp_int_min                 8.0
# temp_int_mean          12.520833
# hum_int_max                 85.0
# hum_int_min                 46.0
# hum_int_mean           74.583333
# CO2_max                   1393.0
# CO2_min                    295.0
# CO2_mean              928.104167
# st_max                      19.9
# st_min                      16.0
# st_mean                17.533333
# Name: 91, dtype: object
# 98 15
# date             2020.12.22 0:00
# temp_ex_max                  8.1
# temp_ex_min                 -6.7
# temp_ex_mean           -0.654167
# s_am_max                    1.76
# s_am_min                    0.22
# s_am_mean               0.420833
# temp_int_max                23.6
# temp_int_min                 6.4
# temp_int_mean          13.454167
# hum_int_max                 97.0
# hum_int_min                 68.0
# hum_int_mean           89.041667
# CO2_max                   1294.0
# CO2_min                    368.0
# CO2_mean              998.608333
# st_max                      19.6
# st_min                      16.0
# st_mean                  17.6625
# Name: 98, dtype: object
# 105 16
# date             2020.12.29 0:00
# temp_ex_max                  7.1
# temp_ex_min                 -2.2
# temp_ex_mean            1.254167
# s_am_max                    0.35
# s_am_min                    0.02
# s_am_mean               0.067083
# temp_int_max                21.2
# temp_int_min                 9.3
# temp_int_mean          12.270833
# hum_int_max                100.0
# hum_int_min                 86.0
# hum_int_mean           97.208333
# CO2_max                   1184.0
# CO2_min                    667.0
# CO2_mean              825.729167
# st_max                      18.4
# st_min                      15.4
# st_mean                17.179167
# Name: 105, dtype: object
# 112 17
# date             2021.1.5 0:00
# temp_ex_max                1.0
# temp_ex_min               -9.8
# temp_ex_mean             -2.25
# s_am_max                  1.61
# s_am_min                  0.01
# s_am_mean             0.375833
# temp_int_max              20.5
# temp_int_min               8.1
# temp_int_mean        12.120833
# hum_int_max              100.0
# hum_int_min               70.0
# hum_int_mean         91.333333
# CO2_max            1110.266667
# CO2_min                  757.0
# CO2_mean            918.808333
# st_max                    18.8
# st_min                    15.6
# st_mean              17.395833
# Name: 112, dtype: object
# 119 18
# date             2021.1.12 0:00
# temp_ex_max                 2.9
# temp_ex_min                -7.1
# temp_ex_mean          -2.283333
# s_am_max                   1.69
# s_am_min                   0.11
# s_am_mean              0.350417
# temp_int_max               23.4
# temp_int_min                6.5
# temp_int_mean         11.716667
# hum_int_max               100.0
# hum_int_min                72.0
# hum_int_mean          92.458333
# CO2_max             1166.368421
# CO2_min                   720.0
# CO2_mean             932.497807
# st_max                     17.2
# st_min                     11.4
# st_mean                 13.3875
# Name: 119, dtype: object
# 126 19
# date             2021.1.19 0:00
# temp_ex_max                 1.8
# temp_ex_min               -11.6
# temp_ex_mean          -4.954167
# s_am_max                    2.0
# s_am_min                   0.06
# s_am_mean              0.492917
# temp_int_max               28.7
# temp_int_min                6.7
# temp_int_mean             12.65
# hum_int_max               100.0
# hum_int_min                59.0
# hum_int_mean          86.083333
# CO2_max                  1252.0
# CO2_min                   587.0
# CO2_mean             906.666667
# st_max                     20.1
# st_min                     11.5
# st_mean               14.191667
# Name: 126, dtype: object
# 133 20
# date             2021.1.26 0:00
# temp_ex_max                 8.7
# temp_ex_min                 2.3
# temp_ex_mean           5.091667
# s_am_max                   0.86
# s_am_min                   0.04
# s_am_mean              0.117083
# temp_int_max               18.3
# temp_int_min               10.4
# temp_int_mean         12.016667
# hum_int_max               100.0
# hum_int_min                91.0
# hum_int_mean          99.416667
# CO2_max                  1212.0
# CO2_min                   687.0
# CO2_mean               919.8125
# st_max                     14.9
# st_min                     12.8
# st_mean               13.654167
# Name: 133, dtype: object
# 140 21
# date             2021.2.2 0:00
# temp_ex_max                2.5
# temp_ex_min               -4.5
# temp_ex_mean         -1.508333
# s_am_max                  2.34
# s_am_min                  0.01
# s_am_mean             0.585833
# temp_int_max              25.5
# temp_int_min               7.5
# temp_int_mean        13.120833
# hum_int_max              100.0
# hum_int_min               62.0
# hum_int_mean            88.875
# CO2_max                  985.0
# CO2_min                  513.0
# CO2_mean            738.333333
# st_max                    19.9
# st_min                    11.9
# st_mean                 14.625
# Name: 140, dtype: object
# 147 22
# date             2021.2.9 0:00
# temp_ex_max                6.9
# temp_ex_min               -8.9
# temp_ex_mean            -1.825
# s_am_max                  2.39
# s_am_min                  0.03
# s_am_mean             0.632083
# temp_int_max              28.2
# temp_int_min               6.3
# temp_int_mean        14.066667
# hum_int_max               97.0
# hum_int_min               61.0
# hum_int_mean         85.583333
# CO2_max                  955.0
# CO2_min                  596.0
# CO2_mean            742.833333
# st_max                    19.5
# st_min                    11.5
# st_mean              14.729167
# Name: 147, dtype: object
# 154 23
# date             2021.2.16 0:00
# temp_ex_max                 2.4
# temp_ex_min                -8.2
# temp_ex_mean          -3.058333
# s_am_max                   1.36
# s_am_min                   0.05
# s_am_mean              0.319167
# temp_int_max               21.1
# temp_int_min                7.6
# temp_int_mean         11.079167
# hum_int_max               100.0
# hum_int_min                69.0
# hum_int_mean               93.0
# CO2_max                  1394.0
# CO2_min                   468.0
# CO2_mean             872.395833
# st_max                     15.8
# st_min                     11.9
# st_mean               13.120833
# Name: 154, dtype: object
# 161 24
# date             2021.2.23 0:00
# temp_ex_max                 8.6
# temp_ex_min                -4.7
# temp_ex_mean             1.9875
# s_am_max                   2.41
# s_am_min                   0.01
# s_am_mean                  0.67
# temp_int_max               24.7
# temp_int_min                8.1
# temp_int_mean         14.354167
# hum_int_max                97.0
# hum_int_min                50.0
# hum_int_mean          83.666667
# CO2_max                  1365.0
# CO2_min                   336.0
# CO2_mean             766.541667
# st_max                     18.6
# st_min                     12.4
# st_mean               14.929167
# Name: 161, dtype: object
# 168 25
# date             2021.3.2 0:00
# temp_ex_max                9.0
# temp_ex_min                0.4
# temp_ex_mean          4.494833
# s_am_max                  2.33
# s_am_min                  0.01
# s_am_mean                 0.63
# temp_int_max              25.6
# temp_int_min               8.8
# temp_int_mean          13.8875
# hum_int_max              100.0
# hum_int_min               67.0
# hum_int_mean         93.208333
# CO2_max                 1347.0
# CO2_min                  342.0
# CO2_mean                 650.5
# st_max                    17.4
# st_min                    12.5
# st_mean              14.283333
# Name: 168, dtype: object
# 175 26
# date             2021.3.9 0:00
# temp_ex_max               14.7
# temp_ex_min                1.3
# temp_ex_mean          6.608333
# s_am_max                  2.54
# s_am_min                  0.02
# s_am_mean               0.6325
# temp_int_max              20.8
# temp_int_min               8.1
# temp_int_mean        13.308333
# hum_int_max              100.0
# hum_int_min               46.0
# hum_int_mean              85.5
# CO2_max                 1331.0
# CO2_min                  425.0
# CO2_mean            689.291667
# st_max                    16.9
# st_min                    12.5
# st_mean              14.333333
# Name: 175, dtype: object
# 182 27
# date             2021.3.16 0:00
# temp_ex_max                17.4
# temp_ex_min                 2.1
# temp_ex_mean               11.3
# s_am_max                   2.95
# s_am_min                   0.05
# s_am_mean              0.874583
# temp_int_max               24.0
# temp_int_min                9.4
# temp_int_mean         15.191667
# hum_int_max               100.0
# hum_int_min                22.0
# hum_int_mean              70.75
# CO2_max                  1305.0
# CO2_min                   407.0
# CO2_mean             599.645833
# st_max                     18.3
# st_min                     14.4
# st_mean               15.779167
# Name: 182, dtype: object
# 189 28
# date             2021.3.23 0:00
# temp_ex_max                16.1
# temp_ex_min                -1.1
# temp_ex_mean           7.020833
# s_am_max                   2.98
# s_am_min                   0.07
# s_am_mean               0.87375
# temp_int_max               21.6
# temp_int_min                8.8
# temp_int_mean         13.941667
# hum_int_max               100.0
# hum_int_min                33.0
# hum_int_mean               75.5
# CO2_max                  1392.0
# CO2_min                   441.0
# CO2_mean             672.791667
# st_max                     17.4
# st_min                     11.9
# st_mean               14.154167
# Name: 189, dtype: object
# 196 29
# date             2021.3.30 0:00
# temp_ex_max                20.3
# temp_ex_min                 4.3
# temp_ex_mean          12.141667
# s_am_max                   3.23
# s_am_min                   0.03
# s_am_mean               0.99375
# temp_int_max               26.3
# temp_int_min                8.4
# temp_int_mean             15.75
# hum_int_max               100.0
# hum_int_min                19.0
# hum_int_mean             57.625
# CO2_max                  1299.0
# CO2_min                   441.0
# CO2_mean             594.145833
# st_max                     19.7
# st_min                     12.4
# st_mean               15.258333
# Name: 196, dtype: object
# 203 30
# date             2021.4.6 0:00
# temp_ex_max               21.5
# temp_ex_min                3.3
# temp_ex_mean            12.025
# s_am_max                  3.25
# s_am_min                  0.03
# s_am_mean             0.960833
# temp_int_max              29.5
# temp_int_min               8.7
# temp_int_mean        16.666667
# hum_int_max              100.0
# hum_int_min               22.0
# hum_int_mean         74.291667
# CO2_max                  858.0
# CO2_min                  320.0
# CO2_mean            576.458333
# st_max                    19.4
# st_min                    13.4
# st_mean                   16.2
# Name: 203, dtype: object
# 210 31
# date             2021.4.13 0:00
# temp_ex_max                15.7
# temp_ex_min                 4.6
# temp_ex_mean          12.398889
# s_am_max                   3.32
# s_am_min                   0.21
# s_am_mean                 0.985
# temp_int_max               24.3
# temp_int_min                7.9
# temp_int_mean         15.683333
# hum_int_max               100.0
# hum_int_min                36.0
# hum_int_mean          81.416667
# CO2_max                  1357.0
# CO2_min                   435.0
# CO2_mean               555.6875
# st_max                     18.8
# st_min                     14.7
# st_mean                 16.2125
# Name: 210, dtype: object
# 217 32
# date             2021.4.20 0:00
# temp_ex_max                25.6
# temp_ex_min                 3.4
# temp_ex_mean          14.545833
# s_am_max                   3.13
# s_am_min                   0.13
# s_am_mean              0.961667
# temp_int_max               25.5
# temp_int_min                6.1
# temp_int_mean         16.041667
# hum_int_max               100.0
# hum_int_min                27.0
# hum_int_mean          65.416667
# CO2_max                  1361.0
# CO2_min                   453.0
# CO2_mean               655.5625
# st_max                     18.1
# st_min                     11.7
# st_mean               15.108333
# Name: 217, dtype: object
# 0 1
# date             2020.9.10 0:00
# temp_ex_max            7.576641
# temp_ex_min            7.576641
# temp_ex_mean           7.576641
# s_am_max                    2.6
# s_am_min                   0.06
# s_am_mean              0.762083
# temp_int_max          17.466437
# temp_int_min          17.466437
# temp_int_mean         17.466437
# hum_int_max           91.932457
# hum_int_min           91.932457
# hum_int_mean          91.932457
# CO2_max              558.974926
# CO2_min              558.974926
# CO2_mean             558.974926
# st_max                16.667247
# st_min                16.667247
# st_mean               16.667247
# Name: 224, dtype: object
# 7 2
# date             2020.9.17 0:00
# temp_ex_max            7.576641
# temp_ex_min            7.576641
# temp_ex_mean           7.576641
# s_am_max                   1.35
# s_am_min                   0.02
# s_am_mean                 0.325
# temp_int_max          17.466437
# temp_int_min          17.466437
# temp_int_mean         17.466437
# hum_int_max           91.932457
# hum_int_min           91.932457
# hum_int_mean          91.932457
# CO2_max              558.974926
# CO2_min              558.974926
# CO2_mean             558.974926
# st_max                16.667247
# st_min                16.667247
# st_mean               16.667247
# Name: 231, dtype: object
# 14 3
# date             2020.9.24 0:00
# temp_ex_max                27.9
# temp_ex_min                15.4
# temp_ex_mean          21.116667
# s_am_max                   2.63
# s_am_min                   0.01
# s_am_mean              0.730833
# temp_int_max               33.4
# temp_int_min               17.2
# temp_int_mean         23.841667
# hum_int_max                96.9
# hum_int_min                90.8
# hum_int_mean          94.054167
# CO2_max                   504.0
# CO2_min                   420.0
# CO2_mean                452.375
# st_max                     36.3
# st_min                     16.3
# st_mean               23.766667
# Name: 238, dtype: object
# 21 4
# date             2020.10.1 0:00
# temp_ex_max                24.4
# temp_ex_min                15.2
# temp_ex_mean               18.9
# s_am_max                   2.77
# s_am_min                   0.01
# s_am_mean              0.695833
# temp_int_max               29.9
# temp_int_min               19.3
# temp_int_mean         23.216667
# hum_int_max                96.4
# hum_int_min                90.0
# hum_int_mean          94.383333
# CO2_max                   637.0
# CO2_min                   432.0
# CO2_mean             528.333333
# st_max                     31.3
# st_min                     18.2
# st_mean                  22.475
# Name: 245, dtype: object
# 28 5
# date             2020.10.8 0:00
# temp_ex_max           19.822941
# temp_ex_min           19.356176
# temp_ex_mean          19.589559
# s_am_max                   2.74
# s_am_min                   0.01
# s_am_mean                0.7775
# temp_int_max          25.024706
# temp_int_min          24.875882
# temp_int_mean         24.950294
# hum_int_max           91.732353
# hum_int_min           91.427941
# hum_int_mean          91.580147
# CO2_max              472.858824
# CO2_min              472.047059
# CO2_mean             472.452941
# st_max                    25.33
# st_min                   24.985
# st_mean                 25.1575
# Name: 252, dtype: object
# 35 6
# date             2020.10.15 0:00
# temp_ex_max            16.413529
# temp_ex_min            15.946765
# temp_ex_mean           16.180147
# s_am_max                    2.55
# s_am_min                    0.09
# s_am_mean               0.572083
# temp_int_max           23.937647
# temp_int_min           23.788824
# temp_int_mean          23.863235
# hum_int_max            89.508824
# hum_int_min            89.204412
# hum_int_mean           89.356618
# CO2_max               478.788235
# CO2_min               477.976471
# CO2_mean              478.382353
# st_max                     22.81
# st_min                    22.465
# st_mean                  22.6375
# Name: 259, dtype: object
# 42 7
# date             2020.10.22 0:00
# temp_ex_max                 19.6
# temp_ex_min                  6.2
# temp_ex_mean           12.904167
# s_am_max                    1.84
# s_am_min                    0.08
# s_am_mean               0.489583
# temp_int_max                26.7
# temp_int_min                16.0
# temp_int_mean          20.333333
# hum_int_max                 93.7
# hum_int_min                 75.1
# hum_int_mean           87.420833
# CO2_max                    645.0
# CO2_min                    445.0
# CO2_mean                 544.625
# st_max                      28.9
# st_min                      14.5
# st_mean                19.670833
# Name: 266, dtype: object
# 49 8
# date             2020.10.29 0:00
# temp_ex_max                 18.0
# temp_ex_min                 -0.5
# temp_ex_mean            7.320833
# s_am_max                    2.21
# s_am_min                    0.04
# s_am_mean               0.574167
# temp_int_max                28.2
# temp_int_min                15.3
# temp_int_mean          20.883333
# hum_int_max                 91.1
# hum_int_min                 80.4
# hum_int_mean           86.458333
# CO2_max                    681.0
# CO2_min                    454.0
# CO2_mean              548.458333
# st_max                      30.7
# st_min                      14.3
# st_mean                20.570833
# Name: 273, dtype: object
# 56 9
# date             2020.11.5 0:00
# temp_ex_max                16.9
# temp_ex_min                -2.5
# temp_ex_mean              6.475
# s_am_max                   2.14
# s_am_min                   0.01
# s_am_mean               0.47625
# temp_int_max               28.3
# temp_int_min               13.8
# temp_int_mean         19.270833
# hum_int_max                95.3
# hum_int_min                82.5
# hum_int_mean             89.025
# CO2_max                   845.0
# CO2_min                   427.0
# CO2_mean             571.541667
# st_max                     29.3
# st_min                     12.6
# st_mean               18.620833
# Name: 280, dtype: object
# 63 10
# date             2020.11.12 0:00
# temp_ex_max                 19.3
# temp_ex_min                 -0.8
# temp_ex_mean            7.233333
# s_am_max                    2.12
# s_am_min                    0.09
# s_am_mean               0.525417
# temp_int_max                25.1
# temp_int_min                13.4
# temp_int_mean          18.404167
# hum_int_max                 95.6
# hum_int_min                 84.1
# hum_int_mean                89.9
# CO2_max                   1221.0
# CO2_min                    436.0
# CO2_mean              749.979167
# st_max                      26.1
# st_min                      12.7
# st_mean                17.741667
# Name: 287, dtype: object
# 70 11
# date             2020.11.19 0:00
# temp_ex_max                 21.0
# temp_ex_min                 10.9
# temp_ex_mean           16.620833
# s_am_max                    0.23
# s_am_min                    0.02
# s_am_mean                   0.04
# temp_int_max                20.7
# temp_int_min                16.5
# temp_int_mean             18.975
# hum_int_max                 96.3
# hum_int_min                 92.3
# hum_int_mean           94.208333
# CO2_max                    816.0
# CO2_min                    430.0
# CO2_mean              572.458333
# st_max                      19.8
# st_min                      15.5
# st_mean                18.045833
# Name: 294, dtype: object
# 77 12
# date             2020.11.26 0:00
# temp_ex_max                 13.3
# temp_ex_min                  1.6
# temp_ex_mean               6.325
# s_am_max                    1.86
# s_am_min                    0.01
# s_am_mean               0.424167
# temp_int_max                24.9
# temp_int_min                12.4
# temp_int_mean          16.554167
# hum_int_max                 94.9
# hum_int_min                 85.5
# hum_int_mean           90.679167
# CO2_max                    978.0
# CO2_min                    381.0
# CO2_mean                 612.125
# st_max                      28.0
# st_min                      11.1
# st_mean                15.808333
# Name: 301, dtype: object
# 84 13
# date             2020.12.3 0:00
# temp_ex_max                 7.1
# temp_ex_min                -4.1
# temp_ex_mean           0.733333
# s_am_max                   1.95
# s_am_min                   0.01
# s_am_mean              0.415417
# temp_int_max               21.5
# temp_int_min               10.9
# temp_int_mean         14.579167
# hum_int_max                94.2
# hum_int_min                85.1
# hum_int_mean            90.6375
# CO2_max                  1265.0
# CO2_min                   348.0
# CO2_mean                644.875
# st_max                     23.7
# st_min                      9.6
# st_mean               13.929167
# Name: 308, dtype: object
# 91 14
# date             2020.12.10 0:00
# temp_ex_max                 10.6
# temp_ex_min                  1.6
# temp_ex_mean               5.125
# s_am_max                    1.52
# s_am_min                    0.05
# s_am_mean               0.263333
# temp_int_max                26.8
# temp_int_min                12.7
# temp_int_mean          16.670833
# hum_int_max                 95.7
# hum_int_min                 89.8
# hum_int_mean              93.225
# CO2_max                    603.0
# CO2_min                    353.0
# CO2_mean              499.583333
# st_max                      27.6
# st_min                      11.6
# st_mean                15.870833
# Name: 315, dtype: object
# 98 15
# date             2020.12.17 0:00
# temp_ex_max                  3.6
# temp_ex_min                -11.2
# temp_ex_mean           -5.145833
# s_am_max                    1.86
# s_am_min                    0.28
# s_am_mean               0.455417
# temp_int_max                25.4
# temp_int_min                10.1
# temp_int_mean               14.1
# hum_int_max                 96.8
# hum_int_min                 87.8
# hum_int_mean             92.0625
# CO2_max                    905.0
# CO2_min                    327.0
# CO2_mean              454.895833
# st_max                      28.4
# st_min                       9.3
# st_mean                13.295833
# Name: 322, dtype: object
# 105 16
# date             2020.12.24 0:00
# temp_ex_max                  9.5
# temp_ex_min                 -4.4
# temp_ex_mean            2.145833
# s_am_max                    1.71
# s_am_min                    0.16
# s_am_mean               0.377083
# temp_int_max                26.1
# temp_int_min                11.5
# temp_int_mean             15.275
# hum_int_max                 96.7
# hum_int_min                 89.4
# hum_int_mean             92.9625
# CO2_max                   1226.0
# CO2_min                    348.0
# CO2_mean              661.041667
# st_max                      28.3
# st_min                      10.1
# st_mean                   14.475
# Name: 329, dtype: object
# 112 17
# date             2020.12.31 0:00
# temp_ex_max                 -2.2
# temp_ex_min                -14.8
# temp_ex_mean             -8.3625
# s_am_max                    1.88
# s_am_min                    0.01
# s_am_mean                  0.365
# temp_int_max                24.4
# temp_int_min                 8.3
# temp_int_mean            12.8375
# hum_int_max                 95.3
# hum_int_min                 89.2
# hum_int_mean           92.454167
# CO2_max                   1382.0
# CO2_min                    380.0
# CO2_mean                   636.0
# st_max                      26.8
# st_min                       7.2
# st_mean                    12.15
# Name: 336, dtype: object
# 119 18
# date             2021.1.7 0:00
# temp_ex_max               -4.1
# temp_ex_min              -18.8
# temp_ex_mean        -10.666667
# s_am_max                  2.09
# s_am_min                  0.03
# s_am_mean               0.4275
# temp_int_max              15.0
# temp_int_min               9.1
# temp_int_mean        10.995833
# hum_int_max               94.1
# hum_int_min               88.0
# hum_int_mean         91.341667
# CO2_max                 1240.0
# CO2_min                  380.0
# CO2_mean            724.041667
# st_max                    13.3
# st_min                     6.7
# st_mean               9.466667
# Name: 343, dtype: object
# 126 19
# date             2021.1.14 0:00
# temp_ex_max                11.0
# temp_ex_min                -5.2
# temp_ex_mean           1.354167
# s_am_max                   1.85
# s_am_min                   0.03
# s_am_mean                  0.47
# temp_int_max               26.6
# temp_int_min               10.2
# temp_int_mean         14.733333
# hum_int_max                96.3
# hum_int_min                88.4
# hum_int_mean             92.625
# CO2_max                  1284.0
# CO2_min                   390.0
# CO2_mean             638.958333
# st_max                     26.3
# st_min                      9.1
# st_mean                 13.5375
# Name: 350, dtype: object
# 133 20
# date             2021.1.21 0:00
# temp_ex_max                10.4
# temp_ex_min                -2.0
# temp_ex_mean           4.441667
# s_am_max                   0.67
# s_am_min                   0.01
# s_am_mean               0.13375
# temp_int_max               21.9
# temp_int_min               10.5
# temp_int_mean         14.358333
# hum_int_max                95.7
# hum_int_min                89.3
# hum_int_mean             92.875
# CO2_max                   928.0
# CO2_min                   419.0
# CO2_mean             597.166667
# st_max                     22.3
# st_min                      9.2
# st_mean               13.008333
# Name: 357, dtype: object
# 140 21
# date             2021.1.28 0:00
# temp_ex_max                 2.8
# temp_ex_min                -5.5
# temp_ex_mean          -1.520833
# s_am_max                   1.61
# s_am_min                   0.04
# s_am_mean              0.240417
# temp_int_max               18.5
# temp_int_min               10.4
# temp_int_mean           13.4125
# hum_int_max                94.3
# hum_int_min                90.1
# hum_int_mean          92.295833
# CO2_max              936.619048
# CO2_min                   247.0
# CO2_mean             604.513889
# st_max                     19.2
# st_min                      8.0
# st_mean               11.833333
# Name: 364, dtype: object
# 147 22
# date             2021.2.4 0:00
# temp_ex_max           3.642857
# temp_ex_min           2.657143
# temp_ex_mean              3.15
# s_am_max                  2.39
# s_am_min                  0.01
# s_am_mean             0.627917
# temp_int_max         26.414286
# temp_int_min         24.935714
# temp_int_mean           25.675
# hum_int_max          92.762857
# hum_int_min          92.697143
# hum_int_mean             92.73
# CO2_max             534.042857
# CO2_min             514.657143
# CO2_mean                524.35
# st_max               27.068571
# st_min               25.491429
# st_mean                  26.28
# Name: 371, dtype: object
# 154 23
# date             2021.2.11 0:00
# temp_ex_max                12.9
# temp_ex_min                -3.0
# temp_ex_mean           3.666667
# s_am_max                   1.99
# s_am_min                   0.01
# s_am_mean              0.479167
# temp_int_max               27.0
# temp_int_min               10.0
# temp_int_mean           16.1375
# hum_int_max                96.2
# hum_int_min                88.2
# hum_int_mean          92.316667
# CO2_max                   979.0
# CO2_min                   399.0
# CO2_mean                 635.75
# st_max                     26.7
# st_min                      9.1
# st_mean                   15.35
# Name: 378, dtype: object
# 161 24
# date             2021.2.18 0:00
# temp_ex_max                 1.5
# temp_ex_min               -10.8
# temp_ex_mean          -4.741667
# s_am_max                   2.37
# s_am_min                   0.05
# s_am_mean                 0.655
# temp_int_max               25.5
# temp_int_min               10.5
# temp_int_mean             14.75
# hum_int_max                95.9
# hum_int_min                87.7
# hum_int_mean          91.995833
# CO2_max                  1340.0
# CO2_min                   347.0
# CO2_mean             570.270833
# st_max                     28.1
# st_min                      9.6
# st_mean                   14.45
# Name: 385, dtype: object
# 168 25
# date             2021.2.25 0:00
# temp_ex_max                 9.6
# temp_ex_min                -3.2
# temp_ex_mean                3.0
# s_am_max                   0.68
# s_am_min                   0.02
# s_am_mean              0.157083
# temp_int_max               20.2
# temp_int_min               11.4
# temp_int_mean           14.9375
# hum_int_max                95.0
# hum_int_min                88.4
# hum_int_mean            92.8125
# CO2_max                  1250.0
# CO2_min                   365.0
# CO2_mean             619.166667
# st_max                     19.7
# st_min                      9.4
# st_mean               13.691667
# Name: 392, dtype: object
# 175 26
# date             2021.3.4 0:00
# temp_ex_max               10.8
# temp_ex_min               -0.1
# temp_ex_mean             4.675
# s_am_max                  0.96
# s_am_min                  0.01
# s_am_mean             0.295417
# temp_int_max              23.1
# temp_int_min              11.8
# temp_int_mean          15.9375
# hum_int_max               95.1
# hum_int_min               90.9
# hum_int_mean         93.395833
# CO2_max                 1016.0
# CO2_min                  354.0
# CO2_mean                553.25
# st_max                    23.3
# st_min                    10.8
# st_mean              15.129167
# Name: 399, dtype: object
# 182 27
# date             2021.3.11 0:00
# temp_ex_max                18.8
# temp_ex_min                -0.8
# temp_ex_mean               8.85
# s_am_max                   2.63
# s_am_min                   0.01
# s_am_mean              0.691667
# temp_int_max               23.7
# temp_int_min               10.6
# temp_int_mean         16.508333
# hum_int_max                97.3
# hum_int_min                85.6
# hum_int_mean            93.0375
# CO2_max                  1345.0
# CO2_min                   437.0
# CO2_mean             681.041667
# st_max                     24.3
# st_min                      9.5
# st_mean               15.658333
# Name: 406, dtype: object
# 189 28
# date             2021.3.18 0:00
# temp_ex_max                20.1
# temp_ex_min                 0.0
# temp_ex_mean           9.779167
# s_am_max                    2.8
# s_am_min                   0.01
# s_am_mean              0.789583
# temp_int_max               25.0
# temp_int_min               10.3
# temp_int_mean         16.679167
# hum_int_max                96.0
# hum_int_min                88.8
# hum_int_mean               93.1
# CO2_max                   929.0
# CO2_min                   430.0
# CO2_mean             549.333333
# st_max                     26.0
# st_min                      9.3
# st_mean               15.945833
# Name: 413, dtype: object
# 196 29
# date             2021.3.25 0:00
# temp_ex_max                20.6
# temp_ex_min                 1.1
# temp_ex_mean             10.175
# s_am_max                   3.03
# s_am_min                   0.08
# s_am_mean              0.862083
# temp_int_max               28.1
# temp_int_min                7.4
# temp_int_mean         16.783333
# hum_int_max                96.4
# hum_int_min                85.6
# hum_int_mean          91.704167
# CO2_max                   564.0
# CO2_min                   393.0
# CO2_mean             502.041667
# st_max                     28.3
# st_min                      6.4
# st_mean               16.520833
# Name: 420, dtype: object
# 203 30
# date             2021.4.1 0:00
# temp_ex_max               21.9
# temp_ex_min                5.1
# temp_ex_mean         14.216667
# s_am_max                  2.36
# s_am_min                  0.02
# s_am_mean             0.671667
# temp_int_max              28.0
# temp_int_min               9.8
# temp_int_mean            17.65
# hum_int_max               95.9
# hum_int_min               86.8
# hum_int_mean         92.970833
# CO2_max                  584.0
# CO2_min                  417.0
# CO2_mean                498.25
# st_max                    26.5
# st_min                     7.8
# st_mean              16.316667
# Name: 427, dtype: object
# 210 31
# date             2021.4.8 0:00
# temp_ex_max               20.1
# temp_ex_min                2.6
# temp_ex_mean         10.679167
# s_am_max                  3.29
# s_am_min                  0.09
# s_am_mean             1.048333
# temp_int_max              25.9
# temp_int_min               7.0
# temp_int_mean           15.775
# hum_int_max               94.9
# hum_int_min               87.3
# hum_int_mean         91.266667
# CO2_max                  535.0
# CO2_min                  418.0
# CO2_mean            485.833333
# st_max                    24.3
# st_min                     5.6
# st_mean              14.566667
# Name: 434, dtype: object
# 217 32
# date             2021.4.15 0:00
# temp_ex_max                18.9
# temp_ex_min                -0.6
# temp_ex_mean           8.954167
# s_am_max                   3.35
# s_am_min                   0.14
# s_am_mean              1.006667
# temp_int_max               25.1
# temp_int_min                4.8
# temp_int_mean           14.3125
# hum_int_max                94.8
# hum_int_min                87.3
# hum_int_mean             91.325
# CO2_max                   507.0
# CO2_min                   413.0
# CO2_mean                 464.75
# st_max                     27.6
# st_min                      3.8
# st_mean               14.233333
# Name: 441, dtype: object
# 224 33
# date             2021.4.22 0:00
# temp_ex_max                29.1
# temp_ex_min                13.0
# temp_ex_mean             20.225
# s_am_max                   2.81
# s_am_min                   0.01
# s_am_mean               0.64375
# temp_int_max               30.1
# temp_int_min               14.9
# temp_int_mean         21.404167
# hum_int_max                96.2
# hum_int_min                90.8
# hum_int_mean              93.35
# CO2_max                   516.0
# CO2_min                   447.0
# CO2_mean             481.458333
# st_max                     29.4
# st_min                     13.8
# st_mean               20.604167
# Name: 448, dtype: object
# 231 34
# date             2021.4.29 0:00
# temp_ex_max                18.6
# temp_ex_min                 9.1
# temp_ex_mean             14.625
# s_am_max                   3.35
# s_am_min                   0.04
# s_am_mean              0.885417
# temp_int_max               24.5
# temp_int_min               13.0
# temp_int_mean         18.470833
# hum_int_max                95.7
# hum_int_min                87.9
# hum_int_mean          92.720833
# CO2_max                   608.0
# CO2_min                   425.0
# CO2_mean                510.125
# st_max                     25.3
# st_min                     11.9
# st_mean               17.470833
# Name: 455, dtype: object
# 238 35
# date             2021.5.6 0:00
# temp_ex_max               22.1
# temp_ex_min                3.7
# temp_ex_mean            13.325
# s_am_max                  2.61
# s_am_min                  0.01
# s_am_mean              0.91125
# temp_int_max              27.7
# temp_int_min               7.6
# temp_int_mean        17.220833
# hum_int_max               96.1
# hum_int_min               88.0
# hum_int_mean           92.3625
# CO2_max                  495.0
# CO2_min                  431.0
# CO2_mean            466.916667
# st_max                    27.2
# st_min                     6.5
# st_mean              16.620833
# Name: 462, dtype: object
# 245 36
# date             2021.5.13 0:00
# temp_ex_max                31.4
# temp_ex_min                12.8
# temp_ex_mean          21.695833
# s_am_max                   3.44
# s_am_min                   0.01
# s_am_mean              1.131667
# temp_int_max               33.8
# temp_int_min               14.6
# temp_int_mean           23.5875
# hum_int_max                96.8
# hum_int_min                89.3
# hum_int_mean          93.966667
# CO2_max                   536.0
# CO2_min                   463.0
# CO2_mean                 493.75
# st_max                     36.6
# st_min                     13.5
# st_mean                  22.925
# Name: 469, dtype: object
# 252 37
# date             2021.5.20 0:00
# temp_ex_max                20.4
# temp_ex_min                16.0
# temp_ex_mean          17.358824
# s_am_max                   0.82
# s_am_min                   0.04
# s_am_mean                  0.24
# temp_int_max               21.7
# temp_int_min               17.5
# temp_int_mean         19.394118
# hum_int_max                95.8
# hum_int_min                91.5
# hum_int_mean          93.647059
# CO2_max                   487.0
# CO2_min                   420.0
# CO2_mean             457.647059
# st_max                     21.2
# st_min                     16.2
# st_mean               18.311765
# Name: 476, dtype: object
# 0 1
# date             2020.9.13 0:00
# temp_ex_max                26.9
# temp_ex_min                18.7
# temp_ex_mean          21.579167
# s_am_max                   2.65
# s_am_min                   0.02
# s_am_mean               0.61375
# temp_int_max               27.4
# temp_int_min               19.9
# temp_int_mean         22.891667
# hum_int_max                94.7
# hum_int_min                65.3
# hum_int_mean          84.670833
# CO2_max                   476.0
# CO2_min                   389.0
# CO2_mean             426.916667
# st_max                     27.3
# st_min                     19.8
# st_mean               22.595833
# Name: 477, dtype: object
# 7 2
# date             2020.9.20 0:00
# temp_ex_max                25.8
# temp_ex_min                13.4
# temp_ex_mean            18.3875
# s_am_max                   2.52
# s_am_min                   0.03
# s_am_mean               0.75125
# temp_int_max               29.4
# temp_int_min               15.3
# temp_int_mean         20.254167
# hum_int_max                94.5
# hum_int_min                55.4
# hum_int_mean          81.108333
# CO2_max                   577.0
# CO2_min                   399.0
# CO2_mean             479.666667
# st_max                     29.4
# st_min                     15.8
# st_mean               20.495833
# Name: 484, dtype: object
# 14 3
# date             2020.9.27 0:00
# temp_ex_max                26.0
# temp_ex_min                12.9
# temp_ex_mean            19.0875
# s_am_max                   2.84
# s_am_min                   0.02
# s_am_mean               0.79875
# temp_int_max               29.5
# temp_int_min               13.6
# temp_int_mean         20.329167
# hum_int_max                93.6
# hum_int_min                55.0
# hum_int_mean          80.441667
# CO2_max                   607.0
# CO2_min                   387.0
# CO2_mean             482.083333
# st_max                     28.3
# st_min                     13.4
# st_mean               20.079167
# Name: 491, dtype: object
# 21 4
# date             2020.10.4 0:00
# temp_ex_max                20.4
# temp_ex_min                13.5
# temp_ex_mean          18.358333
# s_am_max                   0.64
# s_am_min                   0.09
# s_am_mean              0.164583
# temp_int_max               22.4
# temp_int_min               14.4
# temp_int_mean            19.375
# hum_int_max                96.1
# hum_int_min                77.6
# hum_int_mean          87.770833
# CO2_max                   559.0
# CO2_min                   417.0
# CO2_mean             470.791667
# st_max                     22.5
# st_min                     14.3
# st_mean               19.333333
# Name: 498, dtype: object
# 28 5
# date             2020.10.11 0:00
# temp_ex_max                 23.6
# temp_ex_min                 10.7
# temp_ex_mean           16.729167
# s_am_max                    2.19
# s_am_min                    0.02
# s_am_mean               0.519583
# temp_int_max                26.3
# temp_int_min                12.8
# temp_int_mean          18.458333
# hum_int_max                 96.1
# hum_int_min                 66.4
# hum_int_mean           85.216667
# CO2_max                    669.0
# CO2_min                    394.0
# CO2_mean                 493.625
# st_max                      26.3
# st_min                      12.5
# st_mean                18.304167
# Name: 505, dtype: object
# 35 6
# date             2020.10.18 0:00
# temp_ex_max                 20.7
# temp_ex_min                  2.9
# temp_ex_mean           11.370833
# s_am_max                    2.63
# s_am_min                    0.12
# s_am_mean                0.71125
# temp_int_max                26.0
# temp_int_min                11.1
# temp_int_mean               16.3
# hum_int_max                 96.1
# hum_int_min                 42.8
# hum_int_mean           78.858333
# CO2_max                    727.0
# CO2_min                    416.0
# CO2_mean              548.458333
# st_max                      27.0
# ...
# CO2_mean                 476.625
# st_max                      19.0
# st_min                      11.7
# st_mean                14.995833
# Name: 2808, dtype: object
# 189 28
# date             2020-12-10 0:00
# temp_ex_max                 12.3
# temp_ex_min                 -1.0
# temp_ex_mean              4.1625
# s_am_max                  0.0171
# s_am_min                  0.0001
# s_am_mean               0.002904
# temp_int_max                19.5
# temp_int_min                 9.0
# temp_int_mean          12.029167
# hum_int_max                 94.7
# hum_int_min                 53.1
# hum_int_mean           86.841667
# CO2_max                   1132.0
# CO2_min                    303.0
# CO2_mean              563.291667
# st_max                      16.6
# st_min                      11.8
# st_mean                13.570833
# Name: 2815, dtype: object
# 196 29
# date             2020-12-17 0:00
# temp_ex_max                  4.5
# temp_ex_min                 -3.6
# temp_ex_mean           -0.279167
# s_am_max                  0.0199
# s_am_min                  0.0001
# s_am_mean               0.004662
# temp_int_max                21.2
# temp_int_min                 7.4
# temp_int_mean          12.179167
# hum_int_max                 91.0
# hum_int_min                 56.9
# hum_int_mean           82.291667
# CO2_max                   1283.0
# CO2_min                    319.0
# CO2_mean              587.458333
# st_max                      20.2
# st_min                      11.1
# st_mean                15.008333
# Name: 2822, dtype: object
# 203 30
# date             2020-12-24 0:00
# temp_ex_max                 11.4
# temp_ex_min                 -2.0
# temp_ex_mean            3.716667
# s_am_max                  0.0182
# s_am_min                  0.0002
# s_am_mean               0.004046
# temp_int_max                20.8
# temp_int_min                 8.6
# temp_int_mean            12.9375
# hum_int_max                 95.1
# hum_int_min                 47.0
# hum_int_mean           83.995833
# CO2_max                   1242.0
# CO2_min                    307.0
# CO2_mean                   579.0
# st_max                      20.2
# st_min                      12.4
# st_mean                    15.85
# Name: 2829, dtype: object
# 210 31
# date             2020-12-31 0:00
# temp_ex_max                  2.4
# temp_ex_min                 -7.2
# temp_ex_mean           -2.670833
# s_am_max                  0.0208
# s_am_min                  0.0002
# s_am_mean               0.004625
# temp_int_max                23.9
# temp_int_min                 7.5
# temp_int_mean          13.333333
# hum_int_max                 94.3
# hum_int_min                 58.8
# hum_int_mean           82.729167
# CO2_max                   1311.0
# CO2_min                    338.0
# CO2_mean              659.208333
# st_max                      22.1
# st_min                      11.5
# st_mean                   16.075
# Name: 2836, dtype: object
# 217 32
# date             2021-01-07 0:00
# temp_ex_max                 -1.9
# temp_ex_min                -13.5
# temp_ex_mean           -6.891667
# s_am_max                  0.0223
# s_am_min                  0.0004
# s_am_mean                0.00525
# temp_int_max                22.3
# temp_int_min                 8.2
# temp_int_mean          11.891667
# hum_int_max                 97.0
# hum_int_min                 63.2
# hum_int_mean              86.125
# CO2_max                   1334.0
# CO2_min                    484.0
# CO2_mean              753.416667
# st_max                      21.4
# st_min                      12.2
# st_mean                  15.5375
# Name: 2843, dtype: object
# 224 33
# date             2021-01-14 0:00
# temp_ex_max                 13.0
# temp_ex_min                 -5.0
# temp_ex_mean            2.283333
# s_am_max                  0.0199
# s_am_min                  0.0006
# s_am_mean               0.004687
# temp_int_max                25.5
# temp_int_min                 8.1
# temp_int_mean          14.820833
# hum_int_max                 95.2
# hum_int_min                 50.0
# hum_int_mean              83.725
# CO2_max                   1373.0
# CO2_min                    364.0
# CO2_mean              801.770833
# st_max                      23.6
# st_min                      12.6
# st_mean                17.520833
# Name: 2850, dtype: object
# 231 34
# date             2021-01-21 0:00
# temp_ex_max                 12.3
# temp_ex_min                 -5.9
# temp_ex_mean            2.695833
# s_am_max                  0.0137
# s_am_min                  0.0001
# s_am_mean               0.002442
# temp_int_max                25.2
# temp_int_min                 8.1
# temp_int_mean          14.533333
# hum_int_max                 96.5
# hum_int_min                 76.3
# hum_int_mean           91.270833
# CO2_max                   1188.0
# CO2_min                    443.0
# CO2_mean              780.479167
# st_max                      21.9
# st_min                      12.9
# st_mean                17.116667
# Name: 2857, dtype: object
# 238 35
# date             2021-01-28 0:00
# temp_ex_max                 10.5
# temp_ex_min                 -3.3
# temp_ex_mean               0.975
# s_am_max                  0.0205
# s_am_min                  0.0007
# s_am_mean               0.003558
# temp_int_max                26.3
# temp_int_min                 9.8
# temp_int_mean          14.391667
# hum_int_max                 93.8
# hum_int_min                 44.6
# hum_int_mean                83.9
# CO2_max                   1371.0
# CO2_min                    361.0
# CO2_mean              721.083333
# st_max                      22.6
# st_min                      14.6
# st_mean                18.229167
# Name: 2864, dtype: object
# 245 36
# date             2021-02-04 0:00
# temp_ex_max                  7.8
# temp_ex_min                 -2.8
# temp_ex_mean               2.725
# s_am_max                  0.0254
# s_am_min                  0.0021
# s_am_mean               0.006454
# temp_int_max                26.2
# temp_int_min                10.3
# temp_int_mean            15.8125
# hum_int_max                 95.9
# hum_int_min                 45.0
# hum_int_mean           81.416667
# CO2_max                   1096.0
# CO2_min                    358.0
# CO2_mean                693.0625
# st_max                      24.7
# st_min                      14.3
# st_mean                18.816667
# Name: 2871, dtype: object
# 252 37
# date             2021-02-11 0:00
# temp_ex_max                 12.4
# temp_ex_min                 -2.4
# temp_ex_mean            4.233333
# s_am_max                  0.0185
# s_am_min                  0.0011
# s_am_mean               0.004179
# temp_int_max                22.0
# temp_int_min                 9.1
# temp_int_mean              13.75
# hum_int_max                 98.9
# hum_int_min                 47.9
# hum_int_mean           82.470833
# CO2_max                   1312.0
# CO2_min                    332.0
# CO2_mean                651.6875
# st_max                      19.3
# st_min                      13.9
# st_mean                16.895833
# Name: 2878, dtype: object
# 259 38
# date             2021-02-18 0:00
# temp_ex_max                  1.0
# temp_ex_min                 -5.9
# temp_ex_mean           -2.695833
# s_am_max                  0.0276
# s_am_min                  0.0001
# s_am_mean               0.007083
# temp_int_max                26.1
# temp_int_min                 8.4
# temp_int_mean              14.75
# hum_int_max                 98.7
# hum_int_min                 75.6
# hum_int_mean                91.3
# CO2_max                    802.0
# CO2_min                    325.0
# CO2_mean              539.166667
# st_max                      24.3
# st_min                      13.6
# st_mean                18.191667
# Name: 2885, dtype: object
# 266 39
# date             2021-02-25 0:00
# temp_ex_max                  8.3
# temp_ex_min                 -1.9
# temp_ex_mean            3.558333
# s_am_max                  0.0055
# s_am_min                  0.0007
# s_am_mean               0.001229
# temp_int_max                18.3
# temp_int_min                 7.9
# temp_int_mean          11.441667
# hum_int_max                 94.5
# hum_int_min                 78.8
# hum_int_mean           86.733333
# CO2_max                   1233.0
# CO2_min                    300.0
# CO2_mean              766.604167
# st_max                      17.9
# st_min                      13.0
# st_mean                  15.5375
# Name: 2892, dtype: object
# 273 40
# date             2021-03-04 0:00
# temp_ex_max                  9.2
# temp_ex_min                  0.6
# temp_ex_mean              4.8625
# s_am_max                  0.0178
# s_am_min                  0.0001
# s_am_mean               0.002675
# temp_int_max                18.8
# temp_int_min                 9.2
# temp_int_mean            12.0125
# hum_int_max                 96.7
# hum_int_min                 84.8
# hum_int_mean           93.045833
# CO2_max                   1182.0
# CO2_min                    306.0
# CO2_mean                 701.875
# st_max                      18.5
# st_min                      14.2
# st_mean                16.045833
# Name: 2899, dtype: object
# 280 41
# date             2021-03-11 0:00
# temp_ex_max                 17.4
# temp_ex_min                  0.5
# temp_ex_mean              8.5625
# s_am_max                  0.0254
# s_am_min                  0.0002
# s_am_mean               0.006412
# temp_int_max                25.3
# temp_int_min                 8.8
# temp_int_mean          15.258333
# hum_int_max                 98.6
# hum_int_min                 36.6
# hum_int_mean             76.3625
# CO2_max                    716.0
# CO2_min                    336.0
# CO2_mean                  514.75
# st_max                      22.7
# st_min                      13.4
# st_mean                   17.625
# Name: 2906, dtype: object
# 287 42
# date             2021-03-18 0:00
# temp_ex_max                 19.2
# temp_ex_min                  2.2
# temp_ex_mean           10.554167
# s_am_max                  0.0306
# s_am_min                  0.0006
# s_am_mean               0.008167
# temp_int_max                24.8
# temp_int_min                 9.7
# temp_int_mean          15.833333
# hum_int_max                 91.4
# hum_int_min                 44.1
# hum_int_mean           72.741667
# CO2_max                    606.0
# CO2_min                    336.0
# CO2_mean                  440.25
# st_max                      25.3
# st_min                      13.4
# st_mean                18.429167
# Name: 2913, dtype: object
# 294 43
# date             2021-03-25 0:00
# temp_ex_max                 21.8
# temp_ex_min                  1.6
# temp_ex_mean             11.4625
# s_am_max                  0.0321
# s_am_min                  0.0009
# s_am_mean               0.008913
# temp_int_max                26.9
# temp_int_min                 9.2
# temp_int_mean          16.433333
# hum_int_max                 98.1
# hum_int_min                 36.4
# hum_int_mean               77.35
# CO2_max                    543.0
# CO2_min                    346.0
# CO2_mean                  429.75
# st_max                      23.6
# st_min                      12.6
# st_mean                17.429167
# Name: 2920, dtype: object
# 301 44
# date             2021-04-01 0:00
# temp_ex_max                 19.9
# temp_ex_min                  5.7
# temp_ex_mean           13.266667
# s_am_max                  0.0294
# s_am_min                  0.0008
# s_am_mean               0.006521
# temp_int_max                23.9
# temp_int_min                 8.3
# temp_int_mean          15.720833
# hum_int_max                 94.1
# hum_int_min                 43.9
# hum_int_mean               67.15
# CO2_max                    417.0
# CO2_min                    320.0
# CO2_mean              364.333333
# st_max                      20.7
# st_min                      12.9
# st_mean                  16.9875
# Name: 2927, dtype: object
# 308 45
# date             2021-04-08 0:00
# temp_ex_max                 21.3
# temp_ex_min                  5.7
# temp_ex_mean                13.2
# s_am_max                  0.0354
# s_am_min                  0.0018
# s_am_mean               0.009917
# temp_int_max                25.8
# temp_int_min                 7.0
# temp_int_mean          15.483333
# hum_int_max                 93.4
# hum_int_min                 33.5
# hum_int_mean                65.6
# CO2_max                    373.0
# CO2_min                    313.0
# CO2_mean              345.333333
# st_max                      24.4
# st_min                      11.9
# st_mean                17.595833
# Name: 2934, dtype: object
# 315 46
# date             2021-04-15 0:00
# temp_ex_max                 17.9
# temp_ex_min                  0.7
# temp_ex_mean            9.858333
# s_am_max                   0.031
# s_am_min                  0.0022
# s_am_mean                 0.0083
# temp_int_max                24.1
# temp_int_min                 5.0
# temp_int_mean          14.179167
# hum_int_max                100.0
# hum_int_min                 80.1
# hum_int_mean           97.241667
# CO2_max                    413.0
# CO2_min                    322.0
# CO2_mean              375.416667
# st_max                      20.2
# st_min                      11.2
# st_mean                16.016667
# Name: 2941, dtype: object
# 322 47
# date             2021-04-22 0:00
# temp_ex_max                 24.7
# temp_ex_min                 11.6
# temp_ex_mean           17.883333
# s_am_max                  0.0272
# s_am_min                  0.0003
# s_am_mean                 0.0054
# temp_int_max                29.4
# temp_int_min                13.1
# temp_int_mean          19.220833
# hum_int_max                 91.5
# hum_int_min                 39.1
# hum_int_mean           70.379167
# CO2_max                    423.0
# CO2_min                    340.0
# CO2_mean                 378.875
# st_max                      22.1
# st_min                      16.3
# st_mean                19.395833
# Name: 2948, dtype: object
# 329 48
# date             2021-04-29 0:00
# temp_ex_max                 23.5
# temp_ex_min                 10.7
# temp_ex_mean           16.195833
# s_am_max                  0.0351
# s_am_min                  0.0017
# s_am_mean               0.009758
# temp_int_max                28.7
# temp_int_min                11.0
# temp_int_mean            17.8625
# hum_int_max                 88.5
# hum_int_min                 32.3
# hum_int_mean           64.041667
# CO2_max                    370.0
# CO2_min                    326.0
# CO2_mean              348.458333
# st_max                      23.8
# st_min                      14.8
# st_mean                18.883333
# Name: 2955, dtype: object
# 336 49
# date             2021-05-06 0:00
# temp_ex_max                 21.2
# temp_ex_min                  2.7
# temp_ex_mean             12.8375
# s_am_max                  0.0354
# s_am_min                  0.0001
# s_am_mean               0.008687
# temp_int_max                26.6
# temp_int_min                 4.3
# temp_int_mean          15.045833
# hum_int_max                 93.7
# hum_int_min                 41.9
# hum_int_mean           70.558333
# CO2_max                    379.0
# CO2_min                    270.0
# CO2_mean                   329.5
# st_max                      19.3
# st_min                      10.7
# st_mean                  15.7125
# Name: 2962, dtype: object
# 343 50
# date             2021-05-13 0:00
# temp_ex_max                 30.4
# temp_ex_min                 11.0
# temp_ex_mean              20.075
# s_am_max                  0.0344
# s_am_min                  0.0002
# s_am_mean               0.010117
# temp_int_max                34.2
# temp_int_min                11.6
# temp_int_mean               22.0
# hum_int_max                 96.0
# hum_int_min                 46.3
# hum_int_mean                74.8
# CO2_max                    410.0
# CO2_min                    335.0
# CO2_mean              362.208333
# st_max                      26.4
# st_min                      16.4
# st_mean                    21.35
# Name: 2969, dtype: object
# 350 51
# date             2021-05-20 0:00
# temp_ex_max                 16.7
# temp_ex_min                 15.3
# temp_ex_mean           15.966667
# s_am_max                  0.0048
# s_am_min                  0.0001
# s_am_mean               0.001246
# temp_int_max                21.6
# temp_int_min                16.3
# temp_int_mean          18.245833
# hum_int_max                 98.9
# hum_int_min                 85.4
# hum_int_mean           93.758333
# CO2_max                    431.0
# CO2_min                    327.0
# CO2_mean              374.458333
# st_max                      23.0
# st_min                      19.2
# st_mean                  20.3375
# Name: 2976, dtype: object

# %% [markdown]
# #### b case

# %%
df = pd.read_csv("2020/환경데이터_스무딩_완료.csv", encoding="ANSI")

df["s_am"] = df["s_am"]/100
df["as_am"] = df["as_am"]/100

# %%
df
# Out:
#                realTime  name  do city item  cul_time      Measure_time  \
# 0        2020.9.15 0:00    11  충남   부여   딸기         1    2020.9.15 0:00
# 1        2020.9.15 1:00    11  충남   부여   딸기         1    2020.9.15 1:00
# 2        2020.9.15 2:00    11  충남   부여   딸기         1    2020.9.15 2:00
# 3        2020.9.15 3:00    11  충남   부여   딸기         1    2020.9.15 3:00
# 4        2020.9.15 4:00    11  충남   부여   딸기         1    2020.9.15 4:00
# ...                 ...   ...  ..  ...  ...       ...               ...
# 71523   2021-05-26 7:00    52  경남   산청   딸기         1   2021-05-26 7:00
# 71524   2021-05-26 8:00    52  경남   산청   딸기         1   2021-05-26 8:00
# 71525   2021-05-26 9:00    52  경남   산청   딸기         1   2021-05-26 9:00
# 71526  2021-05-26 10:00    52  경남   산청   딸기         1  2021-05-26 10:00
# 71527  2021-05-26 11:00    52  경남   산청   딸기         1  2021-05-26 11:00
#
#        temp_ex    s_am   as_am  temp_int  hum_int    CO2         st
# 0         18.1  0.0000  0.0000      19.8     92.0  549.0  15.831841
# 1         18.2  0.0000  0.0000      19.6     93.0  520.0  15.831841
# 2         18.2  0.0000  0.0000      19.9     95.0  540.0  15.831841
# 3         18.4  0.0000  0.0000      20.0     96.0  531.0  15.831841
# 4         18.0  0.0000  0.0000      19.6     96.0  632.0  15.831841
# ...        ...     ...     ...       ...      ...    ...        ...
# 71523     12.7  0.0000  0.0000      14.2     81.5  333.0  15.500000
# 71524     13.4  0.0000  0.0000      17.6     76.6  346.0  15.600000
# 71525     16.3  0.0000  0.0000      18.9     64.5  355.0  16.000000
# 71526     18.2  0.0151  0.0151      22.2     55.6  352.0  16.600000
# 71527     19.6  0.0170  0.0321      23.4     53.9  376.0  17.600000
#
# [71528 rows x 14 columns]

# %%
## 일별

import pandas as pd

# 데이터
# df = pd.read_csv("2020/환경데이터_스무딩_완료.csv", encoding="ANSI")

# 선정한 변수
cols = ["realTime", "temp_ex", "s_am", "temp_int", "hum_int", "CO2", "st"]


# 일별 데이터 저장할 딕셔너리
data = {"id":[], "date":[],
        "temp_ex_day":[], "temp_ex_night":[],
        's_am_day':[], 's_am_night':[],
        "temp_int_day":[], "temp_int_night":[], 
        "hum_int_day":[], "hum_int_night":[],
        "CO2_day":[], "CO2_night":[], 
        "st_day":[], "st_night":[]}

# 농가 id
farm_id = df["name"].unique()

# 농가 별
for f in farm_id :
    farm_df = df[df["name"]==f][cols]

    # 일 별로
    for i in range(0, farm_df.shape[0], 24) :
        sub_df = farm_df.iloc[i : i + 24]
        date = sub_df["realTime"].tolist()[0]

        # 데이터 추가
        data[f"id"].append(f)
        data[f"date"].append(date)
        # data[f"week_start_date"].append(sub_df.iloc[0]["realTime"])
        
        day_df = sub_df[sub_df["s_am"] != 0]
        night_df = sub_df[sub_df["s_am"] == 0]

        # 변수 별
        for c in cols[1:] : # realTime 제외
            data[f"{c}_day"].append(day_df[c].mean())
            data[f"{c}_night"].append(night_df[c].mean())

date_df = pd.DataFrame.from_dict(data=data, orient='columns')
date_df.to_csv("2020/환경데이터_최최종_일별_b.csv", encoding="ANSI", index=False)

# %%
## 주별

import pandas as pd

# 데이터
df = pd.read_csv("2020/환경데이터_최최종_일별_b.csv", encoding="ANSI")

# 변수
cols = ["date", 
        'temp_ex_day', 'temp_ex_night',
        's_am_day', 's_am_night',
        'temp_int_day', 'temp_int_night',
        'hum_int_day', 'hum_int_night',
        'CO2_day', 'CO2_night',
        'st_day', 'st_night']

# 주별 데이터 저장할 딕셔너리
data = {"id":[], "week":[], "week_start_date":[],
        "temp_ex_day":[], "temp_ex_night":[],
        's_am_day':[], 's_am_night':[],
        "temp_int_day":[], "temp_int_night":[], 
        "hum_int_day":[], "hum_int_night":[],
        "CO2_day":[], "CO2_night":[], 
        "st_day":[], "st_night":[] }


# 농가 id
farm_id = df["id"].unique()

# 농가 별
for f in farm_id :
    farm_df = df[df["id"]==f][cols]
    week = 1

    # 주차 별
    for i in range(0, farm_df.shape[0], 7) :
        # 확인용 출력
        print(i, week)
        print(farm_df.iloc[i])
        # print(farm_df.iloc[i + 24 * 6 + 23])

        sub_df = farm_df.iloc[i : i + 7]

        # 데이터 추가
        data[f"id"].append(f)
        data[f"week"].append(week)
        data[f"week_start_date"].append(sub_df.iloc[0]["date"])

        # 변수 별
        for c in cols[1:] : # realTime 제외
            data[c].append(sub_df[c].mean())
    
        week += 1

week_df = pd.DataFrame.from_dict(data=data, orient='columns')
week_df.to_csv("2020/환경데이터_최최종_주별_b.csv", encoding="ANSI", index=False)
# Out:
# 0 1
# date              2020.9.15 0:00
# temp_ex_day            25.761538
# temp_ex_night               19.2
# s_am_day                1.338462
# s_am_night                   0.0
# temp_int_day           25.569231
# temp_int_night         20.336364
# hum_int_day            64.538462
# hum_int_night          89.090909
# CO2_day               514.692308
# CO2_night                  557.5
# st_day                 15.831841
# st_night               15.831841
# Name: 0, dtype: object
# 7 2
# date              2020.9.22 0:00
# temp_ex_day            21.276923
# temp_ex_night          14.818182
# s_am_day                1.392308
# s_am_night                   0.0
# temp_int_day            20.08284
# temp_int_night         19.458709
# hum_int_day            47.307692
# hum_int_night          77.727273
# CO2_day               520.076923
# CO2_night             595.727273
# st_day                 15.831841
# st_night               15.831841
# Name: 7, dtype: object
# 14 3
# date              2020.9.29 0:00
# temp_ex_day            21.766667
# temp_ex_night          13.808333
# s_am_day                1.176667
# s_am_night                   0.0
# temp_int_day           25.159007
# temp_int_night         25.195497
# hum_int_day                 28.0
# hum_int_night              73.25
# CO2_day                    522.0
# CO2_night                  625.0
# st_day                 15.831841
# st_night               15.831841
# Name: 14, dtype: object
# 21 4
# date              2020.10.6 0:00
# temp_ex_day            17.316667
# temp_ex_night          10.191667
# s_am_day                1.579167
# s_am_night                   0.0
# temp_int_day            22.09388
# temp_int_night          22.13037
# hum_int_day            31.916667
# hum_int_night              72.75
# CO2_day               649.916667
# CO2_night                  565.5
# st_day                 15.831841
# st_night               15.831841
# Name: 21, dtype: object
# 28 5
# date              2020.10.13 0:00
# temp_ex_day             16.263636
# temp_ex_night            7.946154
# s_am_day                 1.094545
# s_am_night                    0.0
# temp_int_day             19.01963
# temp_int_night          19.070155
# hum_int_day             37.727273
# hum_int_night           81.076923
# CO2_day                474.636364
# CO2_night              554.730769
# st_day                  15.831841
# st_night                15.831841
# Name: 28, dtype: object
# 35 6
# date              2020.10.20 0:00
# temp_ex_day             18.327273
# temp_ex_night            7.023077
# s_am_day                 1.244545
# s_am_night                    0.0
# temp_int_day                 22.1
# temp_int_night          13.884615
# hum_int_day             35.545455
# hum_int_night           75.692308
# CO2_day                597.954545
# CO2_night              661.615385
# st_day                  15.831841
# st_night                15.831841
# Name: 35, dtype: object
# 42 7
# date              2020.10.27 0:00
# temp_ex_day             17.427273
# temp_ex_night            6.807692
# s_am_day                 1.146364
# s_am_night                    0.0
# temp_int_day            21.772727
# temp_int_night          13.623077
# hum_int_day                  42.0
# hum_int_night           78.384615
# CO2_day                604.272727
# CO2_night              746.269231
# st_day                  15.831841
# st_night                15.831841
# Name: 42, dtype: object
# 49 8
# date              2020.11.3 0:00
# temp_ex_day             9.590909
# temp_ex_night           4.184615
# s_am_day                0.948182
# s_am_night                   0.0
# temp_int_day           20.536364
# temp_int_night         14.107692
# hum_int_day            43.909091
# hum_int_night          73.692308
# CO2_day                    453.0
# CO2_night             704.692308
# st_day                 15.831841
# st_night               15.831841
# Name: 49, dtype: object
# 56 9
# date              2020.11.10 0:00
# temp_ex_day             11.972727
# temp_ex_night            3.230769
# s_am_day                 1.226364
# s_am_night                    0.0
# temp_int_day            19.963636
# temp_int_night               12.3
# hum_int_day             42.545455
# hum_int_night           79.230769
# CO2_day                532.454545
# CO2_night                   599.0
# st_day                  17.790909
# st_night                14.761538
# Name: 56, dtype: object
# 63 10
# date              2020.11.17 0:00
# temp_ex_day                 16.63
# temp_ex_night           10.835714
# s_am_day                    0.496
# s_am_night                    0.0
# temp_int_day                20.14
# temp_int_night               15.6
# hum_int_day                  77.8
# hum_int_night           93.142857
# CO2_day                     505.2
# CO2_night              653.964286
# st_day                      18.69
# st_night                17.985714
# Name: 63, dtype: object
# 70 11
# date              2020.11.24 0:00
# temp_ex_day              8.622222
# temp_ex_night                2.64
# s_am_day                 0.928889
# s_am_night                    0.0
# temp_int_day            20.966667
# temp_int_night              13.42
# hum_int_day             61.777778
# hum_int_night                85.8
# CO2_day                926.296296
# CO2_night              643.322222
# st_day                  19.755556
# st_night                18.526667
# Name: 70, dtype: object
# 77 12
# date              2020.12.1 0:00
# temp_ex_day             4.454545
# temp_ex_night          -2.338462
# s_am_day                1.046364
# s_am_night                   0.0
# temp_int_day           18.945455
# temp_int_night         10.761538
# hum_int_day            59.454545
# hum_int_night          82.461538
# CO2_day                    696.0
# CO2_night             770.923077
# st_day                 19.472727
# st_night               17.353846
# Name: 77, dtype: object
# 84 13
# date              2020.12.8 0:00
# temp_ex_day                 3.76
# temp_ex_night              -2.55
# s_am_day                   1.057
# s_am_night                   0.0
# temp_int_day               17.28
# temp_int_night         10.464286
# hum_int_day                 48.1
# hum_int_night               88.5
# CO2_day                   749.48
# CO2_night                  775.8
# st_day                     18.24
# st_night               16.942857
# Name: 84, dtype: object
# 91 14
# date              2020.12.15 0:00
# temp_ex_day             -2.555556
# temp_ex_night               -7.78
# s_am_day                 1.155556
# s_am_night                    0.0
# temp_int_day            17.488889
# temp_int_night               9.54
# hum_int_day             60.888889
# hum_int_night                82.8
# CO2_day                638.333333
# CO2_night             1101.966667
# st_day                       18.2
# st_night                17.133333
# Name: 91, dtype: object
# 98 15
# date              2020.12.22 0:00
# temp_ex_day              4.855556
# temp_ex_night               -3.96
# s_am_day                 1.122222
# s_am_night                    0.0
# temp_int_day            18.711111
# temp_int_night               10.3
# hum_int_day             80.666667
# hum_int_night           94.066667
# CO2_day                933.888889
# CO2_night                 1037.44
# st_day                  18.044444
# st_night                17.433333
# Name: 98, dtype: object
# 105 16
# date              2020.12.29 0:00
# temp_ex_day              3.811111
# temp_ex_night               -0.28
# s_am_day                 0.178889
# s_am_night                    0.0
# temp_int_day            14.633333
# temp_int_night          10.853333
# hum_int_day             94.222222
# hum_int_night                99.0
# CO2_day                835.611111
# CO2_night                   819.8
# st_day                  16.822222
# st_night                17.393333
# Name: 105, dtype: object
# 112 17
# date              2021.1.5 0:00
# temp_ex_day               -0.52
# temp_ex_night         -3.485714
# s_am_day                  0.902
# s_am_night                  0.0
# temp_int_day              15.49
# temp_int_night         9.714286
# hum_int_day                83.2
# hum_int_night         97.142857
# CO2_day                  922.35
# CO2_night            916.278571
# st_day                    17.25
# st_night                   17.5
# Name: 112, dtype: object
# 119 18
# date              2021.1.12 0:00
# temp_ex_day             0.688889
# temp_ex_night          -4.066667
# s_am_day                0.934444
# s_am_night                   0.0
# temp_int_day           17.055556
# temp_int_night          8.513333
# hum_int_day            82.111111
# hum_int_night          98.666667
# CO2_day               888.812865
# CO2_night             958.708772
# st_day                 15.111111
# st_night               12.353333
# Name: 119, dtype: object
# 126 19
# date              2021.1.19 0:00
# temp_ex_day                -1.43
# temp_ex_night          -7.471429
# s_am_day                   1.183
# s_am_night                   0.0
# temp_int_day               19.46
# temp_int_night          7.785714
# hum_int_day                 75.2
# hum_int_night          93.857143
# CO2_day               867.666667
# CO2_night             934.523809
# st_day                     16.53
# st_night               12.521429
# Name: 126, dtype: object
# 133 20
# date              2021.1.26 0:00
# temp_ex_day               6.7625
# temp_ex_night            4.25625
# s_am_day                 0.35125
# s_am_night                   0.0
# temp_int_day              13.875
# temp_int_night           11.0875
# hum_int_day                98.25
# hum_int_night              100.0
# CO2_day                947.84375
# CO2_night             905.796875
# st_day                    14.075
# st_night                13.44375
# Name: 133, dtype: object
# 140 21
# date              2021.2.2 0:00
# temp_ex_day           -0.936364
# temp_ex_night         -1.992308
# s_am_day               1.278182
# s_am_night                  0.0
# temp_int_day          17.927273
# temp_int_night         9.053846
# hum_int_day           77.454545
# hum_int_night         98.538462
# CO2_day              722.506494
# CO2_night            751.725275
# st_day                16.227273
# st_night              13.269231
# Name: 140, dtype: object
# 147 22
# date              2021.2.9 0:00
# temp_ex_day            2.827273
# temp_ex_night         -5.761538
# s_am_day               1.379091
# s_am_night                  0.0
# temp_int_day          20.245455
# temp_int_night         8.838462
# hum_int_day           74.545455
# hum_int_night         94.923077
# CO2_day              757.025974
# CO2_night            730.824176
# st_day                16.445455
# st_night              13.276923
# Name: 147, dtype: object
# 154 23
# date              2021.2.16 0:00
# temp_ex_day            -0.645455
# temp_ex_night               -5.1
# s_am_day                0.696364
# s_am_night                   0.0
# temp_int_day           13.654545
# temp_int_night               8.9
# hum_int_day                 86.0
# hum_int_night          98.923077
# CO2_day               788.008081
# CO2_night             943.800855
# st_day                 14.009091
# st_night               12.369231
# Name: 154, dtype: object
# 161 24
# date              2021.2.23 0:00
# temp_ex_day             5.108333
# temp_ex_night          -1.133333
# s_am_day                    1.34
# s_am_night                   0.0
# temp_int_day           19.058333
# temp_int_night              9.65
# hum_int_day            73.666667
# hum_int_night          93.666667
# CO2_day               814.883333
# CO2_night                  718.2
# st_day                 16.216667
# st_night               13.641667
# Name: 161, dtype: object
# 168 25
# date              2021.3.2 0:00
# temp_ex_day               5.975
# temp_ex_night          3.014667
# s_am_day                   1.26
# s_am_night                  0.0
# temp_int_day          17.691667
# temp_int_night        10.083333
# hum_int_day                87.5
# hum_int_night         98.916667
# CO2_day                  679.25
# CO2_night                621.75
# st_day                15.416667
# st_night                  13.15
# Name: 168, dtype: object
# 175 26
# date              2021.3.9 0:00
# temp_ex_day                9.95
# temp_ex_night          3.266667
# s_am_day                  1.265
# s_am_night                  0.0
# temp_int_day               16.9
# temp_int_night         9.716667
# hum_int_day           75.333333
# hum_int_night         95.666667
# CO2_day              654.666667
# CO2_night            723.916667
# st_day                15.266667
# st_night                   13.4
# Name: 175, dtype: object
# 182 27
# date              2021.3.16 0:00
# temp_ex_day            13.433333
# temp_ex_night           9.166667
# s_am_day                1.749167
# s_am_night                   0.0
# temp_int_day           18.458333
# temp_int_night            11.925
# hum_int_day            44.583333
# hum_int_night          96.916667
# CO2_day               522.541667
# CO2_night                 676.75
# st_day                 16.541667
# st_night               15.016667
# Name: 182, dtype: object
# 189 28
# date              2021.3.23 0:00
# temp_ex_day                 12.3
# temp_ex_night           1.741667
# s_am_day                  1.7475
# s_am_night                   0.0
# temp_int_day           18.066667
# temp_int_night          9.816667
# hum_int_day            56.416667
# hum_int_night          94.583333
# CO2_day               559.208333
# CO2_night                786.375
# st_day                 15.283333
# st_night                  13.025
# Name: 189, dtype: object
# 196 29
# date              2021.3.30 0:00
# temp_ex_day            15.692308
# temp_ex_night           7.945455
# s_am_day                1.834615
# s_am_night                   0.0
# temp_int_day           20.553846
# temp_int_night         10.072727
# hum_int_day            37.384615
# hum_int_night          81.545455
# CO2_day               580.115385
# CO2_night             610.727273
# st_day                 16.407692
# st_night                    13.9
# Name: 196, dtype: object
# 203 30
# date              2021.4.6 0:00
# temp_ex_day           16.261538
# temp_ex_night          7.018182
# s_am_day               1.773846
# s_am_night                  0.0
# temp_int_day          21.576923
# temp_int_night        10.863636
# hum_int_day           55.846154
# hum_int_night         96.090909
# CO2_day                   501.0
# CO2_night            665.636364
# st_day                17.407692
# st_night              14.772727
# Name: 203, dtype: object
# 210 31
# date              2021.4.13 0:00
# temp_ex_day               13.525
# temp_ex_night          11.272778
# s_am_day                    1.97
# s_am_night                   0.0
# temp_int_day                18.9
# temp_int_night         12.466667
# hum_int_day            65.666667
# hum_int_night          97.166667
# CO2_day                    568.5
# CO2_night                542.875
# st_day                      17.0
# st_night                  15.425
# Name: 210, dtype: object
# 217 32
# date              2021.4.20 0:00
# temp_ex_day            19.707692
# temp_ex_night           8.445455
# s_am_day                1.775385
# s_am_night                   0.0
# temp_int_day           21.323077
# temp_int_night               9.8
# hum_int_day            45.230769
# hum_int_night          89.272727
# CO2_day               695.192308
# CO2_night             608.727273
# st_day                 15.961538
# st_night                    14.1
# Name: 217, dtype: object
# 0 1
# date              2020.9.10 0:00
# temp_ex_day             7.576641
# temp_ex_night           7.576641
# s_am_day                1.406923
# s_am_night                   0.0
# temp_int_day           17.466437
# temp_int_night         17.466437
# hum_int_day            91.932457
# hum_int_night          91.932457
# CO2_day               558.974926
# CO2_night             558.974926
# st_day                 16.667247
# st_night               16.667247
# Name: 224, dtype: object
# 7 2
# date              2020.9.17 0:00
# temp_ex_day             7.576641
# temp_ex_night           7.576641
# s_am_day                    0.65
# s_am_night                   0.0
# temp_int_day           17.466437
# temp_int_night         17.466437
# hum_int_day            91.932457
# hum_int_night          91.932457
# CO2_day               558.974926
# CO2_night             558.974926
# st_day                 16.667247
# st_night               16.667247
# Name: 231, dtype: object
# 14 3
# date              2020.9.24 0:00
# temp_ex_day            23.730769
# temp_ex_night          18.027273
# s_am_day                1.349231
# s_am_night                   0.0
# temp_int_day           27.392308
# temp_int_night         19.645455
# hum_int_day            93.453846
# hum_int_night          94.763636
# CO2_day               469.538462
# CO2_night             432.090909
# st_day                 28.515385
# st_night               18.154545
# Name: 238, dtype: object
# 21 4
# date              2020.10.1 0:00
# temp_ex_day            21.158333
# temp_ex_night          16.641667
# s_am_day                1.391667
# s_am_night                   0.0
# temp_int_day           25.858333
# temp_int_night            20.575
# hum_int_day                 93.6
# hum_int_night          95.166667
# CO2_day                    505.0
# CO2_night             551.666667
# st_day                 25.608333
# st_night               19.341667
# Name: 245, dtype: object
# 28 5
# date              2020.10.8 0:00
# temp_ex_day            19.569265
# temp_ex_night          19.609853
# s_am_day                   1.555
# s_am_night                   0.0
# temp_int_day           24.943824
# temp_int_night         24.956765
# hum_int_day            91.566912
# hum_int_night          91.593382
# CO2_day               472.488235
# CO2_night             472.417647
# st_day                   25.1425
# st_night                 25.1725
# Name: 252, dtype: object
# 35 6
# date              2020.10.15 0:00
# temp_ex_day             16.149706
# temp_ex_night           16.205905
# s_am_day                 1.248182
# s_am_night                    0.0
# temp_int_day            23.853529
# temp_int_night          23.871448
# hum_int_day             89.336765
# hum_int_night           89.373416
# CO2_day                478.435294
# CO2_night              478.337557
# st_day                     22.615
# st_night                22.656538
# Name: 259, dtype: object
# 42 7
# date              2020.10.22 0:00
# temp_ex_day             15.854545
# temp_ex_night           10.407692
# s_am_day                 1.068182
# s_am_night                    0.0
# temp_int_day            23.518182
# temp_int_night          17.638462
# hum_int_day             85.118182
# hum_int_night           89.369231
# CO2_day                     531.0
# CO2_night              556.153846
# st_day                  23.727273
# st_night                16.238462
# Name: 266, dtype: object
# 49 8
# date              2020.10.29 0:00
# temp_ex_day             12.554545
# temp_ex_night            2.892308
# s_am_day                 1.252727
# s_am_night                    0.0
# temp_int_day            23.781818
# temp_int_night          18.430769
# hum_int_day                  84.3
# hum_int_night           88.284615
# CO2_day                517.818182
# CO2_night              574.384615
# st_day                  24.463636
# st_night                17.276923
# Name: 273, dtype: object
# 56 9
# date              2020.11.5 0:00
# temp_ex_day                 11.5
# temp_ex_night           2.223077
# s_am_day                1.039091
# s_am_night                   0.0
# temp_int_day           22.654545
# temp_int_night         16.407692
# hum_int_day            87.018182
# hum_int_night          90.723077
# CO2_day               550.272727
# CO2_night             589.538462
# st_day                 22.627273
# st_night               15.230769
# Name: 280, dtype: object
# 63 10
# date              2020.11.12 0:00
# temp_ex_day                 13.89
# temp_ex_night            2.478571
# s_am_day                    1.261
# s_am_night                    0.0
# temp_int_day                21.89
# temp_int_night          15.914286
# hum_int_day                 88.08
# hum_int_night                91.2
# CO2_day                   705.775
# CO2_night              781.553571
# st_day                      22.27
# st_night                14.507143
# Name: 287, dtype: object
# 70 11
# date              2020.11.19 0:00
# temp_ex_day               16.8375
# temp_ex_night             16.5125
# s_am_day                     0.12
# s_am_night                    0.0
# temp_int_day               19.575
# temp_int_night             18.675
# hum_int_day                  93.6
# hum_int_night             94.5125
# CO2_day                    446.75
# CO2_night                635.3125
# st_day                    18.7875
# st_night                   17.675
# Name: 294, dtype: object
# 77 12
# date              2020.11.26 0:00
# temp_ex_day                  10.3
# temp_ex_night            3.485714
# s_am_day                    1.018
# s_am_night                    0.0
# temp_int_day                19.76
# temp_int_night          14.264286
# hum_int_day                 88.41
# hum_int_night                92.3
# CO2_day                     545.8
# CO2_night                   659.5
# st_day                      19.86
# st_night                12.914286
# Name: 301, dtype: object
# 84 13
# date              2020.12.3 0:00
# temp_ex_day                 4.58
# temp_ex_night          -2.014286
# s_am_day                   0.997
# s_am_night                   0.0
# temp_int_day               17.38
# temp_int_night         12.578571
# hum_int_day                89.92
# hum_int_night              91.15
# CO2_day                    448.0
# CO2_night                  785.5
# st_day                      17.3
# st_night               11.521429
# Name: 308, dtype: object
# 91 14
# date              2020.12.10 0:00
# temp_ex_day              8.144444
# temp_ex_night            3.313333
# s_am_day                 0.702222
# s_am_night                    0.0
# temp_int_day            20.455556
# temp_int_night               14.4
# hum_int_day             92.977778
# hum_int_night           93.373333
# CO2_day                459.555556
# CO2_night                   523.6
# st_day                  20.255556
# st_night                    13.24
# Name: 315, dtype: object
# 98 15
# date              2020.12.17 0:00
# temp_ex_day              0.411111
# temp_ex_night               -8.48
# s_am_day                 1.214444
# s_am_night                    0.0
# temp_int_day            19.088889
# temp_int_night          11.106667
# hum_int_day             92.488889
# hum_int_night           91.806667
# CO2_day                417.777778
# CO2_night              477.166667
# st_day                  18.622222
# st_night                     10.1
# Name: 322, dtype: object
# 105 16
# date              2020.12.24 0:00
# temp_ex_day              6.622222
# temp_ex_night               -0.54
# s_am_day                 1.005556
# s_am_night                    0.0
# temp_int_day            20.311111
# temp_int_night          12.253333
# hum_int_day             93.011111
# hum_int_night           92.933333
# CO2_day                718.222222
# CO2_night              626.733333
# st_day                  20.433333
# st_night                     10.9
# Name: 329, dtype: object
# 112 17
# date              2020.12.31 0:00
# temp_ex_day                 -4.96
# temp_ex_night          -10.792857
# s_am_day                    0.876
# s_am_night                    0.0
# temp_int_day                16.75
# temp_int_night          10.042857
# hum_int_day                 92.95
# hum_int_night                92.1
# CO2_day                     657.4
# CO2_night              620.714286
# st_day                      16.82
# st_night                 8.814286
# Name: 336, dtype: object
# 119 18
# date              2021.1.7 0:00
# temp_ex_day               -9.41
# temp_ex_night        -11.564286
# s_am_day                  1.026
# s_am_night                  0.0
# temp_int_day              11.94
# temp_int_night        10.321429
# hum_int_day               90.58
# hum_int_night         91.885714
# CO2_day                   860.8
# CO2_night            626.357143
# st_day                    10.15
# st_night               8.978571
# Name: 343, dtype: object
# 126 19
# date              2021.1.14 0:00
# temp_ex_day                  6.4
# temp_ex_night              -2.25
# s_am_day                   1.128
# s_am_night                   0.0
# temp_int_day                19.5
# temp_int_night         11.328571
# hum_int_day                92.98
# hum_int_night          92.371429
# CO2_day                   604.22
# CO2_night             663.771429
# st_day                     18.59
# st_night                9.928571
# Name: 350, dtype: object
# 133 20
# date              2021.1.21 0:00
# temp_ex_day             7.577778
# temp_ex_night               2.56
# s_am_day                0.356667
# s_am_night                   0.0
# temp_int_day           17.722222
# temp_int_night             12.34
# hum_int_day            92.611111
# hum_int_night          93.033333
# CO2_day               586.888889
# CO2_night             603.333333
# st_day                      16.5
# st_night               10.913333
# Name: 357, dtype: object
# 140 21
# date              2021.1.28 0:00
# temp_ex_day                 0.44
# temp_ex_night          -2.921429
# s_am_day                   0.577
# s_am_night                   0.0
# temp_int_day               15.21
# temp_int_night         12.128571
# hum_int_day                92.47
# hum_int_night          92.171429
# CO2_day               461.347619
# CO2_night              706.77551
# st_day                     14.08
# st_night               10.228571
# Name: 364, dtype: object
# 147 22
# date              2021.2.4 0:00
# temp_ex_day            3.214286
# temp_ex_night          3.095604
# s_am_day                   1.37
# s_am_night                  0.0
# temp_int_day          25.578571
# temp_int_night        25.756593
# hum_int_day           92.734286
# hum_int_night         92.726374
# CO2_day              525.614286
# CO2_night             523.28022
# st_day                26.177143
# st_night              26.367033
# Name: 371, dtype: object
# 154 23
# date              2021.2.11 0:00
# temp_ex_day             8.290909
# temp_ex_night          -0.246154
# s_am_day                1.045455
# s_am_night                   0.0
# temp_int_day           20.345455
# temp_int_night         12.576923
# hum_int_day            92.336364
# hum_int_night               92.3
# CO2_day               592.327273
# CO2_night             672.492308
# st_day                      19.9
# st_night                    11.5
# Name: 378, dtype: object
# 161 24
# date              2021.2.18 0:00
# temp_ex_day            -1.590909
# temp_ex_night          -7.407692
# s_am_day                1.429091
# s_am_night                   0.0
# temp_int_day           18.681818
# temp_int_night         11.423077
# hum_int_day            91.772727
# hum_int_night          92.184615
# CO2_day               421.318182
# CO2_night             696.307692
# st_day                 19.209091
# st_night               10.423077
# Name: 385, dtype: object
# 168 25
# date              2021.2.25 0:00
# temp_ex_day             6.154545
# temp_ex_night           0.330769
# s_am_day                0.342727
# s_am_night                   0.0
# temp_int_day           16.954545
# temp_int_night         13.230769
# hum_int_day            92.263636
# hum_int_night          93.276923
# CO2_day               643.545455
# CO2_night             598.538462
# st_day                 15.818182
# st_night               11.892308
# Name: 392, dtype: object
# 175 26
# date              2021.3.4 0:00
# temp_ex_day                 7.8
# temp_ex_night              1.55
# s_am_day               0.590833
# s_am_night                  0.0
# temp_int_day          18.133333
# temp_int_night        13.741667
# hum_int_day              93.275
# hum_int_night         93.516667
# CO2_day              532.416667
# CO2_night            574.083333
# st_day                17.616667
# st_night              12.641667
# Name: 399, dtype: object
# 182 27
# date              2021.3.11 0:00
# temp_ex_day            14.058333
# temp_ex_night           3.641667
# s_am_day                1.383333
# s_am_night                   0.0
# temp_int_day              19.975
# temp_int_night         13.041667
# hum_int_day            93.033333
# hum_int_night          93.041667
# CO2_day               520.392857
# CO2_night             841.690476
# st_day                 19.608333
# st_night               11.708333
# Name: 406, dtype: object
# 189 28
# date              2021.3.18 0:00
# temp_ex_day            15.183333
# temp_ex_night              4.375
# s_am_day                1.579167
# s_am_night                   0.0
# temp_int_day              20.825
# temp_int_night         12.533333
# hum_int_day            93.483333
# hum_int_night          92.716667
# CO2_day               513.833333
# CO2_night             584.833333
# st_day                 20.483333
# st_night               11.408333
# Name: 413, dtype: object
# 196 29
# date              2021.3.25 0:00
# temp_ex_day                 15.7
# temp_ex_night               4.65
# s_am_day                1.724167
# s_am_night                   0.0
# temp_int_day           22.466667
# temp_int_night              11.1
# hum_int_day            92.458333
# hum_int_night              90.95
# CO2_day               482.833333
# CO2_night                 521.25
# st_day                     22.85
# st_night               10.191667
# Name: 420, dtype: object
# 203 30
# date              2021.4.1 0:00
# temp_ex_day           18.023077
# temp_ex_night          9.718182
# s_am_day                   1.24
# s_am_night                  0.0
# temp_int_day          21.323077
# temp_int_night        13.309091
# hum_int_day           93.123077
# hum_int_night         92.790909
# CO2_day              467.307692
# CO2_night            534.818182
# st_day                19.938462
# st_night              12.036364
# Name: 427, dtype: object
# 210 31
# date              2021.4.8 0:00
# temp_ex_day           14.411111
# temp_ex_night          6.268687
# s_am_day               1.935385
# s_am_night                  0.0
# temp_int_day          20.090598
# temp_int_night        10.674747
# hum_int_day           92.178632
# hum_int_night         90.188889
# CO2_day              476.239316
# CO2_night            497.171717
# st_day                18.881197
# st_night               9.467677
# Name: 434, dtype: object
# 217 32
# date              2021.4.15 0:00
# temp_ex_day            13.769231
# temp_ex_night           3.263636
# s_am_day                1.858462
# s_am_night                   0.0
# temp_int_day           19.715385
# temp_int_night          7.927273
# hum_int_day            91.976923
# hum_int_night          90.554545
# CO2_day               478.076923
# CO2_night                  449.0
# st_day                 20.276923
# st_night                7.090909
# Name: 441, dtype: object
# 224 33
# date              2021.4.22 0:00
# temp_ex_day            23.107692
# temp_ex_night          16.818182
# s_am_day                1.188462
# s_am_night                   0.0
# temp_int_day           24.961538
# temp_int_night              17.2
# hum_int_day            93.676923
# hum_int_night          92.963636
# CO2_day               489.307692
# CO2_night             472.181818
# st_day                 24.415385
# st_night                    16.1
# Name: 448, dtype: object
# 231 34
# date              2021.4.29 0:00
# temp_ex_day            16.507692
# temp_ex_night               12.4
# s_am_day                1.634615
# s_am_night                   0.0
# temp_int_day           21.115385
# temp_int_night         15.345455
# hum_int_day            92.461538
# hum_int_night          93.027273
# CO2_day               476.461538
# CO2_night             549.909091
# st_day                 20.284615
# st_night               14.145455
# Name: 455, dtype: object
# 238 35
# date              2021.5.6 0:00
# temp_ex_day                17.9
# temp_ex_night              6.92
# s_am_day               1.562143
# s_am_night                  0.0
# temp_int_day          22.307143
# temp_int_night             10.1
# hum_int_day           93.357143
# hum_int_night             90.97
# CO2_day              474.857143
# CO2_night                 455.8
# st_day                22.042857
# st_night                   9.03
# Name: 462, dtype: object
# 245 36
# date              2021.5.13 0:00
# temp_ex_day                25.08
# temp_ex_night          16.055556
# s_am_day                1.810667
# s_am_night                   0.0
# temp_int_day           27.273333
# temp_int_night         17.444444
# hum_int_day                 94.0
# hum_int_night          93.911111
# CO2_day                    495.4
# CO2_night                  491.0
# st_day                 26.966667
# st_night               16.188889
# Name: 469, dtype: object
# 252 37
# date              2021.5.20 0:00
# temp_ex_day                17.98
# temp_ex_night          16.471429
# s_am_day                   0.408
# s_am_night                   0.0
# temp_int_day                20.6
# temp_int_night         17.671429
# hum_int_day                94.11
# hum_int_night          92.985714
# CO2_day                    441.6
# CO2_night             480.571429
# st_day                     19.67
# st_night               16.371429
# Name: 476, dtype: object
# 0 1
# date              2020.9.13 0:00
# temp_ex_day            23.246154
# temp_ex_night          19.609091
# s_am_day                1.133077
# s_am_night                   0.0
# temp_int_day           24.692308
# temp_int_night         20.763636
# hum_int_day            77.569231
# hum_int_night          93.063636
# CO2_day               405.538462
# CO2_night             452.181818
# st_day                 24.392308
# st_night               20.472727
# Name: 477, dtype: object
# 7 2
# date              2020.9.20 0:00
# temp_ex_day            21.523077
# temp_ex_night          14.681818
# s_am_day                1.386923
# s_am_night                   0.0
# temp_int_day           23.853846
# temp_int_night              16.0
# hum_int_day            71.953846
# hum_int_night          91.927273
# CO2_day               432.692308
# CO2_night             535.181818
# st_day                 23.892308
# st_night               16.481818
# Name: 484, dtype: object
# 14 3
# date              2020.9.27 0:00
# temp_ex_day            22.515385
# temp_ex_night          15.036364
# s_am_day                1.474615
# s_am_night                   0.0
# temp_int_day           24.315385
# temp_int_night         15.618182
# hum_int_day                 70.3
# hum_int_night          92.427273
# CO2_day               422.384615
# CO2_night             552.636364
# st_day                 23.992308
# st_night               15.454545
# Name: 491, dtype: object
# 21 4
# date              2020.10.4 0:00
# temp_ex_day            19.590909
# temp_ex_night          17.315385
# s_am_day                0.359091
# s_am_night                   0.0
# temp_int_day           21.036364
# temp_int_night         17.969231
# hum_int_day            83.454545
# hum_int_night          91.423077
# CO2_day               442.818182
# CO2_night             494.461538
# st_day                 21.072727
# st_night               17.861538
# Name: 498, dtype: object
# 28 5
# date              2020.10.11 0:00
# temp_ex_day                19.825
# temp_ex_night           13.633333
# s_am_day                 1.039167
# s_am_night                    0.0
# temp_int_day            21.958333
# temp_int_night          14.958333
# hum_int_day                 75.45
# hum_int_night           94.983333
# CO2_day                439.416667
# CO2_night              547.833333
# st_day                  21.941667
# st_night                14.666667
# Name: 505, dtype: object
# 35 6
# date              2020.10.18 0:00
# temp_ex_day             16.463636
# temp_ex_night            7.061538
# s_am_day                 1.551818
# s_am_night                    0.0
# temp_int_day            20.954545
# temp_int_night          12.361538
# hum_int_day             60.836364
# hum_int_night           94.107692
# CO2_day                468.545455
# CO2_night              616.076923
# st_day                  20.945455
# st_night                11.830769
# Name: 512, dtype: object
# 42 7
# date              2020.10.25 0:00
# temp_ex_day                  15.9
# temp_ex_night            6.407692
# s_am_day                     1.32
# s_am_night                    0.0
# temp_int_day            20.863636
# temp_int_night          11.446154
# hum_int_day             68.763636
# hum_int_night           94.346154
# CO2_day                452.545455
# CO2_night              610.923077
# st_day                       20.5
# st_night                10.769231
# Name: 519, dtype: object
# 49 8
# date              2020.11.1 0:00
# temp_ex_day            12.272727
# temp_ex_night          11.938462
# s_am_day                    0.21
# s_am_night                   0.0
# temp_int_day           16.109091
# temp_int_night         15.076923
# hum_int_day            91.745455
# hum_int_night          95.653846
# CO2_day               585.545455
# CO2_night                  670.0
# st_day                 15.990909
# st_night               14.846154
# Name: 526, dtype: object
# 56 9
# date              2020.11.8 0:00
# temp_ex_day            11.927273
# temp_ex_night           5.246154
# s_am_day                1.205455
# s_am_night                   0.0
# temp_int_day           19.245455
# temp_int_night         12.323077
# hum_int_day            70.236364
# hum_int_night          94.438462
# CO2_day               519.181818
# CO2_night             651.769231
# st_day                 18.627273
# st_night                    12.1
# Name: 533, dtype: object
# 63 10
# date              2020.11.15 0:00
# temp_ex_day             14.772727
# temp_ex_night            6.492308
# s_am_day                 1.058182
# s_am_night                    0.0
# temp_int_day            20.845455
# temp_int_night               13.0
# hum_int_day                  77.6
# hum_int_night           95.223077
# CO2_day                523.454545
# CO2_night              657.769231
# st_day                  20.736364
# st_night                13.023077
# Name: 540, dtype: object
# 70 11
# date              2020.11.22 0:00
# temp_ex_day                   9.7
# temp_ex_night                8.05
# s_am_day                    0.148
# s_am_night                    0.0
# temp_int_day                14.88
# temp_int_night          12.942857
# hum_int_day                 90.71
# hum_int_night           94.821429
# CO2_day                     622.4
# CO2_night              606.071429
# st_day                      14.75
# st_night                13.035714
# Name: 547, dtype: object
# 77 12
# date              2020.11.29 0:00
# temp_ex_day              4.418182
# temp_ex_night                 2.3
# s_am_day                 0.429091
# s_am_night                    0.0
# temp_int_day            13.909091
# temp_int_night          10.838462
# hum_int_day             88.881818
# hum_int_night           95.376923
# CO2_day                560.454545
# CO2_night              577.230769
# st_day                  13.872727
# st_night                10.838462
# Name: 554, dtype: object
# 84 13
# date              2020.12.6 0:00
# temp_ex_day             6.145455
# temp_ex_night          -0.784615
# s_am_day                0.898182
# s_am_night                   0.0
# temp_int_day           17.727273
# temp_int_night          9.415385
# hum_int_day                 84.8
# hum_int_night          94.892308
# CO2_day               576.727273
# CO2_night             653.923077
# st_day                      17.6
# st_night                9.576923
# Name: 561, dtype: object
# 91 14
# date              2020.12.13 0:00
# temp_ex_day                  5.55
# temp_ex_night           -0.314286
# s_am_day                    0.243
# s_am_night                    0.0
# temp_int_day                13.02
# temp_int_night                9.9
# hum_int_day                 91.93
# hum_int_night           95.292857
# CO2_day                     677.2
# CO2_night              628.428571
# st_day                      13.02
# st_night                 9.957143
# Name: 568, dtype: object
# 98 15
# date              2020.12.20 0:00
# temp_ex_day              0.681818
# temp_ex_night           -4.615385
# s_am_day                 0.913636
# s_am_night                    0.0
# temp_int_day            17.409091
# temp_int_night           9.907692
# hum_int_day             85.481818
# hum_int_night           94.253846
# CO2_day                     583.0
# CO2_night                   604.0
# st_day                  17.236364
# st_night                 9.838462
# Name: 575, dtype: object
# 105 16
# date              2020.12.27 0:00
# temp_ex_day                  5.11
# temp_ex_night            0.685714
# s_am_day                    0.303
# s_am_night                    0.0
# temp_int_day                13.28
# temp_int_night              10.15
# hum_int_day                 91.86
# hum_int_night           94.942857
# CO2_day                     632.0
# CO2_night              657.214286
# st_day                       13.3
# st_night                10.357143
# Name: 582, dtype: object
# 112 17
# date              2021.1.3 0:00
# temp_ex_day               -0.56
# temp_ex_night         -4.828571
# s_am_day                  0.685
# s_am_night                  0.0
# temp_int_day              13.91
# temp_int_night         9.635714
# hum_int_day               89.57
# hum_int_night         94.278571
# CO2_day                   532.0
# CO2_night            583.571429
# st_day                    13.97
# st_night               9.628571
# Name: 589, dtype: object
# 119 18
# date              2021.1.10 0:00
# temp_ex_day            -4.763636
# temp_ex_night         -12.453846
# s_am_day                0.690909
# s_am_night                   0.0
# temp_int_day           15.145455
# temp_int_night          9.084615
# hum_int_day            88.345455
# hum_int_night          92.746154
# CO2_day               596.909091
# CO2_night             576.692308
# st_day                 15.154545
# st_night                8.884615
# Name: 596, dtype: object
# 126 19
# date              2021.1.17 0:00
# temp_ex_day            -1.509091
# temp_ex_night          -3.346154
# s_am_day                    1.12
# s_am_night                   0.0
# temp_int_day           17.936364
# temp_int_night         10.323077
# hum_int_day            85.327273
# hum_int_night          94.907692
# CO2_day               579.818182
# CO2_night             557.769231
# st_day                 17.836364
# st_night               10.215385
# Name: 603, dtype: object
# 133 20
# date              2021.1.24 0:00
# temp_ex_day                 10.2
# temp_ex_night           5.538462
# s_am_day                1.014545
# s_am_night                   0.0
# temp_int_day           19.827273
# temp_int_night         10.830769
# hum_int_day            84.509091
# hum_int_night          95.253846
# CO2_day               537.909091
# CO2_night             577.615385
# st_day                 19.945455
# st_night               11.069231
# Name: 610, dtype: object
# 140 21
# date              2021.1.31 0:00
# temp_ex_day             7.581818
# temp_ex_night           1.961538
# s_am_day                0.946364
# s_am_night                   0.0
# temp_int_day           19.445455
# temp_int_night         11.253846
# hum_int_day            85.881818
# hum_int_night          95.046154
# CO2_day               534.090909
# CO2_night             582.692308
# st_day                 19.481818
# st_night               11.092308
# Name: 617, dtype: object
# 147 22
# date              2021.2.7 0:00
# temp_ex_day            7.236364
# temp_ex_night          4.076923
# s_am_day               0.898182
# s_am_night                  0.0
# temp_int_day          19.190909
# temp_int_night        12.030769
# hum_int_day           83.109091
# hum_int_night              94.3
# CO2_day              547.727273
# CO2_night            573.692308
# st_day                18.863636
# st_night              12.038462
# Name: 624, dtype: object
# 154 23
# date              2021.2.14 0:00
# temp_ex_day            12.272727
# temp_ex_night           4.338462
# s_am_day                     0.6
# s_am_night                   0.0
# temp_int_day           18.345455
# temp_int_night         10.961538
# hum_int_day            73.418182
# hum_int_night          91.946154
# CO2_day               544.636364
# CO2_night                  615.0
# st_day                 18.245455
# st_night               10.961538
# Name: 631, dtype: object
# 161 24
# date              2021.2.21 0:00
# temp_ex_day            18.183333
# temp_ex_night           8.641667
# s_am_day                   1.345
# s_am_night                   0.0
# temp_int_day           22.308333
# temp_int_night         10.983333
# hum_int_day            62.866667
# hum_int_night          87.316667
# CO2_day               519.333333
# CO2_night             605.416667
# st_day                 22.091667
# st_night               10.933333
# Name: 638, dtype: object
# 168 25
# date              2021.2.28 0:00
# temp_ex_day             8.309091
# temp_ex_night           4.692308
# s_am_day                0.457273
# s_am_night                   0.0
# temp_int_day           16.518182
# temp_int_night         10.461538
# hum_int_day            83.672727
# hum_int_night          91.523077
# CO2_day               499.909091
# CO2_night             585.153846
# st_day                 16.427273
# st_night               10.723077
# Name: 645, dtype: object
# 175 26
# date              2021.3.7 0:00
# temp_ex_day            9.133333
# temp_ex_night          6.166667
# s_am_day                 0.7975
# s_am_night                  0.0
# temp_int_day          18.408333
# temp_int_night        11.958333
# hum_int_day               73.15
# hum_int_night             92.65
# CO2_day                   510.5
# CO2_night            624.583333
# st_day                18.116667
# st_night              11.708333
# Name: 652, dtype: object
# 182 27
# date              2021.3.14 0:00
# temp_ex_day                 10.4
# temp_ex_night           4.391667
# s_am_day                1.294167
# s_am_night                   0.0
# temp_int_day           21.108333
# temp_int_night         12.258333
# hum_int_day               82.425
# hum_int_night              94.75
# CO2_day               554.666667
# CO2_night             700.083333
# st_day                 20.508333
# st_night               11.808333
# Name: 659, dtype: object
# 189 28
# date              2021.3.21 0:00
# temp_ex_day             7.292308
# temp_ex_night           5.345455
# s_am_day                1.016923
# s_am_night                   0.0
# temp_int_day           17.107692
# temp_int_night         11.436364
# hum_int_day            79.315385
# hum_int_night          95.345455
# CO2_day               556.153846
# CO2_night             624.727273
# st_day                 16.507692
# st_night               11.281818
# Name: 666, dtype: object
# 196 29
# date              2021.3.28 0:00
# temp_ex_day             9.930769
# temp_ex_night          10.954545
# s_am_day                     0.3
# s_am_night                   0.0
# temp_int_day           15.315385
# temp_int_night         12.881818
# hum_int_day                 85.9
# hum_int_night          92.972727
# CO2_day               510.153846
# CO2_night             621.818182
# st_day                 15.184615
# st_night               12.863636
# Name: 673, dtype: object
# 203 30
# date              2021.4.4 0:00
# temp_ex_day                12.0
# temp_ex_night         10.363636
# s_am_day               0.408462
# s_am_night                  0.0
# temp_int_day          16.384615
# temp_int_night        12.981818
# hum_int_day           84.453846
# hum_int_night         92.218182
# CO2_day              463.923077
# CO2_night            524.636364
# st_day                16.376923
# st_night              12.854545
# Name: 680, dtype: object
# 210 31
# date              2021.4.11 0:00
# temp_ex_day            17.353846
# temp_ex_night           7.981818
# s_am_day                1.786154
# s_am_night                   0.0
# temp_int_day           22.630769
# temp_int_night         11.809091
# hum_int_day            58.438462
# hum_int_night          92.354545
# CO2_day               483.538462
# CO2_night             646.909091
# st_day                 22.923077
# st_night               11.963636
# Name: 687, dtype: object
# 217 32
# date              2021.4.18 0:00
# temp_ex_day            12.092857
# temp_ex_night               7.42
# s_am_day                1.732143
# s_am_night                   0.0
# temp_int_day           20.228571
# temp_int_night              9.36
# hum_int_day                 63.0
# hum_int_night              92.16
# CO2_day               452.857143
# CO2_night                  624.6
# st_day                     19.45
# st_night                    9.13
# Name: 694, dtype: object
# 224 33
# date              2021.4.25 0:00
# temp_ex_day            20.123077
# temp_ex_night          11.409091
# s_am_day                1.936923
# s_am_night                   0.0
# temp_int_day           24.723077
# temp_int_night         12.818182
# hum_int_day            58.830769
# hum_int_night          88.318182
# CO2_day               451.846154
# CO2_night             583.181818
# st_day                 24.823077
# st_night               12.645455
# Name: 701, dtype: object
# 0 1
# date              2020.9.8 0:00
# temp_ex_day                 NaN
# temp_ex_night               NaN
# s_am_day               0.645455
# s_am_night                  0.0
# temp_int_day                NaN
# temp_int_night              NaN
# hum_int_day                 NaN
# hum_int_night               NaN
# CO2_day                     NaN
# CO2_night                   NaN
# st_day                      NaN
# st_night                    NaN
# Name: 705, dtype: object
# 7 2
# date              2020.9.15 0:00
# temp_ex_day                  NaN
# temp_ex_night                NaN
# s_am_day                1.515385
# s_am_night                   0.0
# temp_int_day                 NaN
# temp_int_night               NaN
# hum_int_day                  NaN
# hum_int_night                NaN
# CO2_day                      NaN
# CO2_night                    NaN
# st_day                       NaN
# st_night                     NaN
# Name: 712, dtype: object
# 14 3
# ...
# temp_int_day                 27.7
# temp_int_night          17.128571
# hum_int_day                 63.97
# hum_int_night           94.157143
# CO2_day                     354.1
# CO2_night              371.071429
# st_day                      22.67
# st_night                18.985714
# Name: 2745, dtype: object
# 126 19
# date              2020-10-08 0:00
# temp_ex_day             20.322222
# temp_ex_night           16.246667
# s_am_day                 0.016078
# s_am_night                    0.0
# temp_int_day            27.333333
# temp_int_night          16.773333
# hum_int_day             58.211111
# hum_int_night                87.8
# CO2_day                351.222222
# CO2_night                   337.2
# st_day                  23.766667
# st_night                    19.08
# Name: 2752, dtype: object
# 133 20
# date              2020-10-15 0:00
# temp_ex_day                  18.9
# temp_ex_night           10.713333
# s_am_day                 0.018044
# s_am_night                    0.0
# temp_int_day            28.055556
# temp_int_night          14.166667
# hum_int_day                  53.8
# hum_int_night           92.326667
# CO2_day                358.777778
# CO2_night              353.866667
# st_day                       24.1
# st_night                17.413333
# Name: 2759, dtype: object
# 140 21
# date              2020-10-22 0:00
# temp_ex_day             17.944444
# temp_ex_night           13.646667
# s_am_day                 0.009589
# s_am_night                    0.0
# temp_int_day                 26.2
# temp_int_night              16.18
# hum_int_day             87.766667
# hum_int_night           97.613333
# CO2_day                374.222222
# CO2_night              493.533333
# st_day                  23.322222
# st_night                     18.5
# Name: 2766, dtype: object
# 147 22
# date              2020-10-29 0:00
# temp_ex_day             16.622222
# temp_ex_night            8.613333
# s_am_day                 0.015967
# s_am_night                    0.0
# temp_int_day            26.988889
# temp_int_night              12.26
# hum_int_day             70.311111
# hum_int_night                96.2
# CO2_day                365.222222
# CO2_night              436.533333
# st_day                  23.633333
# st_night                16.786667
# Name: 2773, dtype: object
# 154 23
# date              2020-11-05 0:00
# temp_ex_day             13.844444
# temp_ex_night            2.326667
# s_am_day                 0.014056
# s_am_night                    0.0
# temp_int_day            23.677778
# temp_int_night          10.906667
# hum_int_day             83.733333
# hum_int_night               93.44
# CO2_day                450.444444
# CO2_night              514.133333
# st_day                  21.255556
# st_night                15.533333
# Name: 2780, dtype: object
# 161 24
# date              2020-11-12 0:00
# temp_ex_day             15.466667
# temp_ex_night            2.066667
# s_am_day                 0.014178
# s_am_night                    0.0
# temp_int_day            20.833333
# temp_int_night              10.48
# hum_int_day             82.211111
# hum_int_night               93.94
# CO2_day                375.888889
# CO2_night              581.666667
# st_day                  19.555556
# st_night                    15.02
# Name: 2787, dtype: object
# 168 25
# date              2020-11-19 0:00
# temp_ex_day             21.077778
# temp_ex_night           18.366667
# s_am_day                 0.002122
# s_am_night                    0.0
# temp_int_day            21.977778
# temp_int_night              18.24
# hum_int_day             94.155556
# hum_int_night                95.9
# CO2_day                349.222222
# CO2_night                   345.8
# st_day                  21.544444
# st_night                    19.12
# Name: 2794, dtype: object
# 175 26
# date              2020-11-26 0:00
# temp_ex_day                  11.2
# temp_ex_night                 5.2
# s_am_day                    0.011
# s_am_night                    0.0
# temp_int_day                 18.3
# temp_int_night              10.52
# hum_int_day             91.933333
# hum_int_night           97.326667
# CO2_day                471.555556
# CO2_night                   453.6
# st_day                  17.388889
# st_night                13.926667
# Name: 2801, dtype: object
# 182 27
# date              2020-12-03 0:00
# temp_ex_day              7.822222
# temp_ex_night            3.166667
# s_am_day                 0.011367
# s_am_night                    0.0
# temp_int_day            18.544444
# temp_int_night          10.506667
# hum_int_day             94.133333
# hum_int_night               96.96
# CO2_day                415.888889
# CO2_night              513.066667
# st_day                  17.088889
# st_night                    13.74
# Name: 2808, dtype: object
# 189 28
# date              2020-12-10 0:00
# temp_ex_day              8.677778
# temp_ex_night            1.453333
# s_am_day                 0.007744
# s_am_night                    0.0
# temp_int_day            15.266667
# temp_int_night          10.086667
# hum_int_day             76.722222
# hum_int_night           92.913333
# CO2_day                     594.0
# CO2_night              544.866667
# st_day                  14.655556
# st_night                    12.92
# Name: 2815, dtype: object
# 196 29
# date              2020-12-17 0:00
# temp_ex_day                   2.9
# temp_ex_night           -2.186667
# s_am_day                 0.012433
# s_am_night                    0.0
# temp_int_day            17.777778
# temp_int_night               8.82
# hum_int_day             70.811111
# hum_int_night               89.18
# CO2_day                553.222222
# CO2_night                   608.0
# st_day                  18.166667
# st_night                13.113333
# Name: 2822, dtype: object
# 203 30
# date              2020-12-24 0:00
# temp_ex_day              8.988889
# temp_ex_night            0.553333
# s_am_day                 0.010789
# s_am_night                    0.0
# temp_int_day            17.655556
# temp_int_night          10.106667
# hum_int_day             68.244444
# hum_int_night           93.446667
# CO2_day                510.222222
# CO2_night              620.266667
# st_day                  18.444444
# st_night                14.293333
# Name: 2829, dtype: object
# 210 31
# date              2020-12-31 0:00
# temp_ex_day              0.444444
# temp_ex_night               -4.54
# s_am_day                 0.012333
# s_am_night                    0.0
# temp_int_day            19.388889
# temp_int_night                9.7
# hum_int_day             72.977778
# hum_int_night               88.58
# CO2_day                637.777778
# CO2_night              672.066667
# st_day                  19.433333
# st_night                    14.06
# Name: 2836, dtype: object
# 217 32
# date              2021-01-07 0:00
# temp_ex_day             -6.922222
# temp_ex_night           -6.873333
# s_am_day                    0.014
# s_am_night                    0.0
# temp_int_day            16.322222
# temp_int_night           9.233333
# hum_int_day             75.522222
# hum_int_night           92.486667
# CO2_day                     869.0
# CO2_night              684.066667
# st_day                  18.622222
# st_night                13.686667
# Name: 2843, dtype: object
# 224 33
# date              2021-01-14 0:00
# temp_ex_day              9.444444
# temp_ex_night           -2.013333
# s_am_day                   0.0125
# s_am_night                    0.0
# temp_int_day            21.911111
# temp_int_night          10.566667
# hum_int_day             69.677778
# hum_int_night           92.153333
# CO2_day                505.388889
# CO2_night                   979.6
# st_day                  20.966667
# st_night                15.453333
# Name: 2850, dtype: object
# 231 34
# date              2021-01-21 0:00
# temp_ex_day                   9.2
# temp_ex_night           -1.206667
# s_am_day                 0.006511
# s_am_night                    0.0
# temp_int_day            20.511111
# temp_int_night          10.946667
# hum_int_day             87.877778
# hum_int_night           93.306667
# CO2_day                567.166667
# CO2_night              908.466667
# st_day                       19.9
# st_night                15.446667
# Name: 2857, dtype: object
# 238 35
# date              2021-01-28 0:00
# temp_ex_day              5.155556
# temp_ex_night           -1.533333
# s_am_day                 0.009489
# s_am_night                    0.0
# temp_int_day            20.022222
# temp_int_night          11.013333
# hum_int_day             70.122222
# hum_int_night           92.166667
# CO2_day                617.777778
# CO2_night              783.066667
# st_day                  20.711111
# st_night                    16.74
# Name: 2864, dtype: object
# 245 36
# date              2021-02-04 0:00
# temp_ex_day              5.988889
# temp_ex_night            0.766667
# s_am_day                 0.017211
# s_am_night                    0.0
# temp_int_day                 22.7
# temp_int_night              11.68
# hum_int_day             61.333333
# hum_int_night           93.466667
# CO2_day                487.388889
# CO2_night              816.466667
# st_day                  21.455556
# st_night                17.233333
# Name: 2871, dtype: object
# 252 37
# date              2021-02-11 0:00
# temp_ex_day                  10.1
# temp_ex_night            0.713333
# s_am_day                 0.011144
# s_am_night                    0.0
# temp_int_day            18.144444
# temp_int_night          11.113333
# hum_int_day             62.077778
# hum_int_night           94.706667
# CO2_day                468.944444
# CO2_night              761.333333
# st_day                  18.455556
# st_night                    15.96
# Name: 2878, dtype: object
# 259 38
# date              2021-02-18 0:00
# temp_ex_day                 -0.64
# temp_ex_night           -4.164286
# s_am_day                    0.017
# s_am_night                    0.0
# temp_int_day                20.89
# temp_int_night          10.364286
# hum_int_day                 83.04
# hum_int_night                97.2
# CO2_day                     469.3
# CO2_night              589.071429
# st_day                      21.03
# st_night                16.164286
# Name: 2885, dtype: object
# 266 39
# date              2021-02-25 0:00
# temp_ex_day              6.866667
# temp_ex_night            1.573333
# s_am_day                 0.003278
# s_am_night                    0.0
# temp_int_day            13.822222
# temp_int_night          10.013333
# hum_int_day             84.555556
# hum_int_night               88.04
# CO2_day                599.777778
# CO2_night                   866.7
# st_day                  17.055556
# st_night                14.626667
# Name: 2892, dtype: object
# 273 40
# date              2021-03-04 0:00
# temp_ex_day                  7.51
# temp_ex_night            2.971429
# s_am_day                  0.00642
# s_am_night                    0.0
# temp_int_day                14.16
# temp_int_night          10.478571
# hum_int_day                 89.51
# hum_int_night           95.571429
# CO2_day                     613.7
# CO2_night              764.857143
# st_day                      17.22
# st_night                15.207143
# Name: 2899, dtype: object
# 280 41
# date              2021-03-11 0:00
# temp_ex_day                 14.44
# temp_ex_night            4.364286
# s_am_day                  0.01539
# s_am_night                    0.0
# temp_int_day                20.74
# temp_int_night          11.342857
# hum_int_day                 53.46
# hum_int_night           92.721429
# CO2_day                     367.8
# CO2_night              619.714286
# st_day                      19.93
# st_night                15.978571
# Name: 2906, dtype: object
# 287 42
# date              2021-03-18 0:00
# temp_ex_day                 16.62
# temp_ex_night            6.221429
# s_am_day                   0.0196
# s_am_night                    0.0
# temp_int_day                21.57
# temp_int_night          11.735714
# hum_int_day                 51.73
# hum_int_night               87.75
# CO2_day                     356.0
# CO2_night              500.428571
# st_day                      21.75
# st_night                16.057143
# Name: 2913, dtype: object
# 294 43
# date              2021-03-25 0:00
# temp_ex_day                 19.37
# temp_ex_night            5.814286
# s_am_day                  0.02139
# s_am_night                    0.0
# temp_int_day                23.05
# temp_int_night          11.707143
# hum_int_day                 53.47
# hum_int_night           94.407143
# CO2_day                     370.2
# CO2_night              472.285714
# st_day                      20.44
# st_night                15.278571
# Name: 2920, dtype: object
# 301 44
# date              2021-04-01 0:00
# temp_ex_day                 18.16
# temp_ex_night            9.771429
# s_am_day                  0.01565
# s_am_night                    0.0
# temp_int_day                20.73
# temp_int_night          12.142857
# hum_int_day                 49.23
# hum_int_night               79.95
# CO2_day                     350.7
# CO2_night              374.071429
# st_day                      19.04
# st_night                15.521429
# Name: 2927, dtype: object
# 308 45
# date              2021-04-08 0:00
# temp_ex_day                 19.52
# temp_ex_night            8.685714
# s_am_day                   0.0238
# s_am_night                    0.0
# temp_int_day                22.85
# temp_int_night          10.221429
# hum_int_day                 38.97
# hum_int_night           84.621429
# CO2_day                     358.2
# CO2_night              336.142857
# st_day                      20.56
# st_night                15.478571
# Name: 2934, dtype: object
# 315 46
# date              2021-04-15 0:00
# temp_ex_day                 16.11
# temp_ex_night            5.392857
# s_am_day                  0.01992
# s_am_night                    0.0
# temp_int_day                21.04
# temp_int_night           9.278571
# hum_int_day                 98.98
# hum_int_night                96.0
# CO2_day                     349.8
# CO2_night              393.714286
# st_day                      18.09
# st_night                14.535714
# Name: 2941, dtype: object
# 322 47
# date              2021-04-22 0:00
# temp_ex_day                 22.56
# temp_ex_night           14.542857
# s_am_day                  0.01296
# s_am_night                    0.0
# temp_int_day                24.78
# temp_int_night              15.25
# hum_int_day                 52.26
# hum_int_night           83.321429
# CO2_day                     364.4
# CO2_night              389.214286
# st_day                      20.93
# st_night                     18.3
# Name: 2948, dtype: object
# 329 48
# date              2021-04-29 0:00
# temp_ex_day                  21.6
# temp_ex_night           12.335714
# s_am_day                  0.02342
# s_am_night                    0.0
# temp_int_day                 25.0
# temp_int_night          12.764286
# hum_int_day                 41.45
# hum_int_night           80.178571
# CO2_day                     359.2
# CO2_night              340.785714
# st_day                      20.77
# st_night                17.535714
# Name: 2955, dtype: object
# 336 49
# date              2021-05-06 0:00
# temp_ex_day             19.072727
# temp_ex_night            7.561538
# s_am_day                 0.018955
# s_am_night                    0.0
# temp_int_day            22.190909
# temp_int_night                9.0
# hum_int_day             53.572727
# hum_int_night           84.930769
# CO2_day                360.454545
# CO2_night              303.307692
# st_day                  17.509091
# st_night                14.192308
# Name: 2962, dtype: object
# 343 50
# date              2021-05-13 0:00
# temp_ex_day             26.363636
# temp_ex_night           14.753846
# s_am_day                 0.022073
# s_am_night                    0.0
# temp_int_day                 29.5
# temp_int_night          15.653846
# hum_int_day             57.545455
# hum_int_night                89.4
# CO2_day                369.272727
# CO2_night              356.230769
# st_day                  23.636364
# st_night                19.415385
# Name: 2969, dtype: object
# 350 51
# date              2021-05-20 0:00
# temp_ex_day             15.981818
# temp_ex_night           15.953846
# s_am_day                 0.002718
# s_am_night                    0.0
# temp_int_day                 19.4
# temp_int_night          17.269231
# hum_int_day             90.945455
# hum_int_night           96.138462
# CO2_day                339.909091
# CO2_night              403.692308
# st_day                  20.190909
# st_night                20.461538
# Name: 2976, dtype: object
